# %% [markdown]
# # Project 3 - Books

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import pycountry
pd.options.display.max_colwidth = 200

# Import the API key
from config import api_key

# %%
#Creating dataframes from csv files to read the data
books_df = pd.read_csv('./Resources/books.csv')
users_df = pd.read_csv('./Resources/users.csv')
ratings_df = pd.read_csv('./Resources/ratings.csv')

# %%
books_df.head()
# Out:
#         ISBN           Book-Title         Book-Author  Year-Of-Publication  \
# 0  195153448  Classical Mythology  Mark P. O. Morford                 2002
# 1        133             sdf4stgv             34f5tgd                 1444
#
#            Publisher
# 0  Oxford University
# 1          dfgdrgdrh

# %%
users_df.head()
# Out:
#    User-ID Location  Age
# 0        1      USA   12
# 1        2   Mexico   34

# %%
ratings_df.head()
# Out:
#    User-ID       ISBN  Book-Rating
# 0        1  195153448            2
# 1        2        133            5

# %%
#Finding the size of each dataframe
print(books_df.shape)
print(users_df.shape)
print(ratings_df.shape)
# Out:
# (2, 5)
# (2, 3)
# (2, 3)

# %%
#Following code has steps to get co-ordinate information of the unique countries in the dataset

# %%
#Reading the cleanCountries csv file and adding it to countries dataframe
column_name=['Country']
countries_df = pd.read_csv("./Resources/cleanCountries.csv",header=None, names=column_name)
countries_df.head()
# Out:
#        Country
# 0  afghanistan
# 1      albania
# 2      algeria
# 3      andorra
# 4       angola

# %%
#Finding the unique countries 
countries_unique=countries_df['Country'].unique()

# %%
#Transforming the data into list
countries_data=countries_unique.tolist()

# %%
countries_data
# Out:
# ['afghanistan',
#  'albania',
#  'algeria',
#  'andorra',
#  'angola',
#  'antigua and barbuda',
#  'argentina',
#  'armenia',
#  'australia',
#  'austria',
#  'azerbaijan',
#  'bahamas',
#  'bahrain',
#  'bangladesh',
#  'barbados',
#  'belgium',
#  'belize',
#  'benin',
#  'bermuda',
#  'bhutan',
#  'bolivia',
#  'bosnia and herzegovina',
#  'botswana',
#  'brazil',
#  'brunei',
#  'bulgaria',
#  'burkina faso',
#  'burma',
#  'cameroon',
#  'canada',
#  'cape verde',
#  'chile',
#  'china',
#  'colombia',
#  'connecticut',
#  'costa rica',
#  'cote d`ivoire',
#  'Country',
#  'croatia',
#  'cuba',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'dominica',
#  'dominican republic',
#  'east africa',
#  'ecuador',
#  'egypt',
#  'england',
#  'equatorial geuinea',
#  'eritrea',
#  'estonia',
#  'ethiopia',
#  'faroe islands',
#  'fernando de la mora',
#  'fiji',
#  'finland',
#  'florida',
#  'france',
#  'gabon',
#  'gambia',
#  'georgia',
#  'germany',
#  'ghana',
#  'greece',
#  'grenada',
#  'guatemala',
#  'guinea-bissau',
#  'guyana',
#  'haiti',
#  'honduras',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iowa',
#  'iran',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'kyrgyzstan',
#  'laos',
#  'latvia',
#  'lebanon',
#  'lesotho',
#  'lithuania',
#  'luxembourg',
#  'macedonia',
#  'madagascar',
#  'malaysia',
#  'maldives',
#  'mali',
#  'malta',
#  'mauritania',
#  'mauritius',
#  'mexico',
#  'micronesia',
#  'moldova',
#  'monaco',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'mozambique',
#  'namibia',
#  'nepal',
#  'netherlands',
#  'new zealand',
#  'nicaragua',
#  'nigeria',
#  'north korea',
#  'northern ireland',
#  'norway',
#  'oman',
#  'pakistan',
#  'panama',
#  'papua new guinea',
#  'paraguay',
#  'pennsylvania',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'puerto rico',
#  'qatar',
#  'romania',
#  'russia',
#  'rwanda',
#  'saint kitts and nevis',
#  'saint lucia',
#  'saint vincent and the grenadines',
#  'samoa',
#  'sao tome and principe',
#  'saudi arabia',
#  'scotland',
#  'senegal',
#  'serbia & montenegro',
#  'sierra leone',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'somalia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'sudan',
#  'suriname',
#  'sweden',
#  'switzerland',
#  'syria',
#  'taiwan',
#  'tajikistan',
#  'tanzania',
#  'thailand',
#  'the gambia',
#  'trinidad',
#  'trinidad and tobago',
#  'tunisia',
#  'turkey',
#  'ukraine',
#  'united arab emirates',
#  'united kingdom',
#  'united states',
#  'uruguay',
#  'uzbekistan',
#  'venezuela',
#  'vietnam',
#  'wales',
#  'yemen',
#  'zambia',
#  'zimbabwe']

# %%
 #!pip install pycountry

# %%
#Using openweathermap API to get latitude and longitude for each country code(obtained from pycountry)
url = "http://api.openweathermap.org/geo/1.0/direct?"
new_query_url = url + "appid=" + api_key + "&q="

# Set up empty lists to hold the API response
latitude = []
longitude = []
country_codes=[]
countries_names=[]
response_api=[]
for country in countries_data:
        # Convert country name to ISO country code
    try:
        country_code = pycountry.countries.get(name=country).alpha_2
         # Make API request
        country_codes.append(country_code)
        countries_names.append(country)
        print(country_code)
    except AttributeError:
        print(f"Could not find ISO code for {country}")
        continue
# Out:
# AF
# AL
# DZ
# AD
# AO
# AG
# AR
# AM
# AU
# AT
# AZ
# BS
# BH
# BD
# BB
# BE
# BZ
# BJ
# BM
# BT
# Could not find ISO code for bolivia
# BA
# BW
# BR
# Could not find ISO code for brunei
# BG
# BF
# Could not find ISO code for burma
# CM
# CA
# Could not find ISO code for cape verde
# CL
# CN
# CO
# Could not find ISO code for connecticut
# CR
# Could not find ISO code for cote d`ivoire
# Could not find ISO code for Country
# HR
# CU
# CY
# Could not find ISO code for czech republic
# DK
# DM
# DO
# Could not find ISO code for east africa
# EC
# EG
# Could not find ISO code for england
# Could not find ISO code for equatorial geuinea
# ER
# EE
# ET
# FO
# Could not find ISO code for fernando de la mora
# FJ
# FI
# Could not find ISO code for florida
# FR
# GA
# GM
# GE
# DE
# GH
# GR
# GD
# GT
# GW
# GY
# HT
# HN
# HK
# HU
# IS
# IN
# ID
# Could not find ISO code for iowa
# Could not find ISO code for iran
# IQ
# IE
# IL
# IT
# JM
# JP
# JO
# KZ
# KE
# KW
# KG
# Could not find ISO code for laos
# LV
# LB
# LS
# LT
# LU
# Could not find ISO code for macedonia
# MG
# MY
# MV
# ML
# MT
# MR
# MU
# MX
# Could not find ISO code for micronesia
# Could not find ISO code for moldova
# MC
# MN
# ME
# MA
# MZ
# NA
# NP
# NL
# NZ
# NI
# NG
# Could not find ISO code for north korea
# Could not find ISO code for northern ireland
# NO
# OM
# PK
# PA
# PG
# PY
# Could not find ISO code for pennsylvania
# PE
# PH
# PL
# PT
# PR
# QA
# RO
# Could not find ISO code for russia
# RW
# KN
# LC
# VC
# WS
# ST
# SA
# Could not find ISO code for scotland
# SN
# Could not find ISO code for serbia & montenegro
# SL
# SG
# SK
# SI
# SO
# ZA
# Could not find ISO code for south korea
# ES
# LK
# SD
# SR
# SE
# CH
# Could not find ISO code for syria
# Could not find ISO code for taiwan
# TJ
# Could not find ISO code for tanzania
# TH
# Could not find ISO code for the gambia
# Could not find ISO code for trinidad
# TT
# TN
# TR
# UA
# AE
# GB
# US
# UY
# UZ
# Could not find ISO code for venezuela
# Could not find ISO code for vietnam
# Could not find ISO code for wales
# YE
# ZM
# ZW

# %%
#Sending API request to get response
for c in country_codes:
    response = requests.get(f"{new_query_url}{c}").json()
    response_api.append(response)

# %%
response_api
# Out:
# [[{'name': 'Isle of Man',
#    'local_names': {'ru': 'О́стров Мэн',
#     'kk': 'Мэн',
#     'el': 'νησί του Μαν',
#     'qu': "Man wat'a",
#     'ar': 'جزيرة مان',
#     'ky': 'Мэн аралы',
#     'ml': 'ഐൽ ഒഫ് മാൻ',
#     'ca': 'Man',
#     'cs': 'Ostrov Man',
#     'sh': 'Ostrvo Man',
#     'sw': 'Isle of Man',
#     'oc': 'Illa de Man',
#     'ha': 'Isle of Man',
#     'tl': 'Pulo ng Man',
#     'uk': 'Острів Мен',
#     'hr': 'Otok Man',
#     'yo': 'Erékùṣù ilẹ̀ Man',
#     'ko': '맨 섬',
#     'bn': 'আইল অফ ম্যান',
#     'af': 'Man',
#     'th': 'เกาะแมน',
#     'rw': 'Ikirwa cya Man',
#     'fi': 'Mansaari',
#     'ia': 'Insula de Man',
#     'pt': 'Ilha de Man',
#     'sl': 'Otok Man',
#     'nl': 'Man',
#     'ja': 'マン島',
#     'cy': 'Ynys Manaw',
#     'id': 'Pulau Man',
#     'eo': 'Manksinsulo',
#     'sv': 'Isle of Man',
#     'cv': 'Мэн утравĕ',
#     'li': 'Eiland Man',
#     'ur': 'آئل آف مین',
#     'ro': 'Insula Man',
#     'lt': 'Meno sala',
#     'jv': 'Pulo Man',
#     'sq': 'Ishulli i Njeriut',
#     'es': 'isla de Man',
#     'su': 'Pulo Man',
#     'fr': 'île de Man',
#     'de': 'Isle of Man',
#     'ms': 'Pulau Man',
#     'mi': 'Motu o Man',
#     'bg': 'Ман',
#     'sc': 'ìsula de Man',
#     'eu': 'Man',
#     'ka': 'კუნძული მენი',
#     'no': 'Man',
#     'fo': 'Isle of Man',
#     'sk': 'Ostrov Man',
#     'pl': 'Wyspa Man',
#     'da': 'Isle of Man',
#     'ta': 'மாண் தீவு',
#     'gl': 'Illa de Man',
#     'se': 'Mannin',
#     'tt': 'Мэн утравы',
#     'et': 'Man',
#     'la': 'Monapia',
#     'os': 'Мэны сакъадах',
#     'sr': 'Острво Мен',
#     'io': 'Man',
#     'en': 'Isle of Man',
#     'is': 'Mön',
#     'bs': 'Ostrvo Man',
#     'br': 'Manav',
#     'nn': 'Man',
#     'fa': 'جزیرهٔ مَن',
#     'gv': 'Mannin',
#     'az': 'Men adası',
#     'kw': 'Manow',
#     'be': 'Востраў Мэн',
#     'hu': 'Man',
#     'dv': 'އައިޒަލް އޮފް މޭން',
#     'mk': 'Ман',
#     'zh': '马恩岛',
#     'ga': 'Manainn',
#     'mr': 'आईल ऑफ मान',
#     'gd': 'Eilean Mhanainn',
#     'vi': 'Đảo Man',
#     'lv': 'Menas Sala',
#     'it': 'Isola di Man',
#     'fy': 'Man',
#     'hi': 'मनुष्य का टापू',
#     'tr': 'Man Adası',
#     'pa': 'ਆਇਲ ਆਫ਼ ਮੈਨ',
#     'an': 'Isla de Man',
#     'he': 'האי מאן',
#     'hy': 'Մեն կղզի'},
#    'lat': 54.23592075,
#    'lon': -4.514766902315387,
#    'country': 'IM'}],
#  [{'name': 'Al',
#    'local_names': {'fa': 'آل', 'en': 'Al'},
#    'lat': 36.7172018,
#    'lon': 59.6661311,
#    'country': 'IR',
#    'state': 'Razavi Khorasan'}],
#  [{'name': 'Dzilth-Na-O-Dith-Hle',
#    'local_names': {'en': 'Dzilth-Na-O-Dith-Hle'},
#    'lat': 36.3921169,
#    'lon': -107.834908,
#    'country': 'US',
#    'state': 'New Mexico'}],
#  [{'name': 'Dioșod',
#    'local_names': {'hu': 'Diósad', 'ro': 'Dioșod', 'uk': 'Діошод'},
#    'lat': 47.2923759,
#    'lon': 23.0209883,
#    'country': 'RO'}],
#  [{'name': 'Yao',
#    'local_names': {'ko': '야오시',
#     'pl': 'Yao',
#     'es': 'Yao',
#     'zh': '八尾市',
#     'uk': 'Яо',
#     'fr': 'Yao',
#     'ru': 'Яо',
#     'en': 'Yao',
#     'de': 'Yao',
#     'ja': '八尾市',
#     'ar': 'ياو، أوساكا'},
#    'lat': 34.626275,
#    'lon': 135.605845,
#    'country': 'JP',
#    'state': 'Osaka Prefecture'}],
#  [{'name': 'Ág',
#    'local_names': {'ru': 'Аг', 'hu': 'Ág'},
#    'lat': 46.2959997,
#    'lon': 18.204151,
#    'country': 'HU'}],
#  [{'name': 'Junction City',
#    'lat': 33.021446100000006,
#    'lon': -92.72446250787544,
#    'country': 'US',
#    'state': 'Arkansas'}],
#  [{'name': 'Iam',
#    'local_names': {'hu': 'Jám', 'ro': 'Iam', 'uk': 'Ям'},
#    'lat': 45.0100943,
#    'lon': 21.4012452,
#    'country': 'RO'}],
#  [{'name': 'Lauw',
#    'local_names': {'de': 'Au', 'fr': 'Lauw'},
#    'lat': 47.7563917,
#    'lon': 7.0194428,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'Ath',
#    'local_names': {'nl': 'Aat', 'wa': 'Ate', 'fr': 'Ath', 'la': 'Athum'},
#    'lat': 50.6288684,
#    'lon': 3.785318027789082,
#    'country': 'BE',
#    'state': 'Hainaut'}],
#  [{'name': 'Iaz',
#    'local_names': {'hu': 'Jász', 'ro': 'Iaz', 'uk': 'Яз'},
#    'lat': 45.4650871,
#    'lon': 22.2338393,
#    'country': 'RO'}],
#  [{'name': 'Bs',
#    'local_names': {'ascii': 'Bs',
#     'feature_name': 'Bs',
#     'en': 'Bs',
#     'mk': "Б'с"},
#    'lat': 42.1877996,
#    'lon': 22.3876518,
#    'country': 'MK',
#    'state': 'Northeastern Region'}],
#  [{'name': 'Belo Horizonte',
#    'local_names': {'sv': 'Belo Horizonte',
#     'eo': 'Bel-Horizonto',
#     'tr': 'Belo Horizonte',
#     'kn': 'ಬೇಲೊಹೋರಿಜೊಂತೆ',
#     'kk': 'Белу-Оризонти',
#     'sr': 'Бело Оризонте',
#     'hy': 'Բելու Օրիզոնտի',
#     'pl': 'Belo Horizonte',
#     'bg': 'Бело Оризонти',
#     'es': 'Belo Horizonte',
#     'oc': 'Belo Horizonte',
#     'ta': 'பெலோ அரிசாஞ்ச்',
#     'pa': 'ਬੈਲੋ ਓਰੀਜ਼ੋਂਤੀ',
#     'ja': 'ベロオリゾンテ',
#     'de': 'Belo Horizonte',
#     'ko': '벨루오리존치',
#     'tg': 'Белу-Оризонти',
#     'la': 'Pulchri Horizontis',
#     'ce': 'Белу-Оризонти',
#     'ka': 'ბელუ-ორიზონტი',
#     'mr': 'बेलो होरिझोन्ते',
#     'ar': 'بيلو هوريزونتي',
#     'en': 'Belo Horizonte',
#     'uk': 'Белу-Оризонті',
#     'zh': '贝洛奥里藏特',
#     'mk': 'Бело Хоризонте',
#     'mn': 'Бе́лу-Оризо́нти',
#     'uz': 'Belu-Orizonti',
#     'el': 'Μπέλο Οριζόντε',
#     'pt': 'Belo Horizonte',
#     'he': 'בלו הוריזונטה',
#     'lt': 'Belo Horizontė',
#     'os': 'Белу-Оризонти',
#     'it': 'Belo Horizonte',
#     'fa': 'بلو هوریزونته',
#     'nl': 'Belo Horizonte',
#     'be': 'Белу-Арызонты',
#     'lv': 'Belu Orizonti',
#     'th': 'เบโลโอรีซอนชี',
#     'fr': 'Belo Horizonte',
#     'ru': 'Белу-Оризонти'},
#    'lat': -19.9227318,
#    'lon': -43.9450948,
#    'country': 'BR',
#    'state': 'Minas Gerais'}],
#  [{'name': 'Budi',
#    'local_names': {'en': 'Budi', 'th': 'บุดี'},
#    'lat': 6.5193503,
#    'lon': 101.3177069,
#    'country': 'TH',
#    'state': 'Yala Province'}],
#  [{'name': 'ББ', 'lat': 42.8677615, 'lon': 74.5874803, 'country': 'KG'}],
#  [{'name': 'Berlin',
#    'local_names': {'sh': 'Berlin',
#     'yi': 'בערלין',
#     'gl': 'Berlín',
#     'lb': 'Berlin',
#     'th': 'เบอร์ลิน',
#     'is': 'Berlín',
#     'io': 'Berlin',
#     'sr': 'Берлин',
#     'en': 'Berlin',
#     'az': 'Berlin',
#     'ga': 'Beirlín',
#     'kk': 'Берлин',
#     'wo': 'Berlin',
#     'no': 'Berlin',
#     'ka': 'ბერლინი',
#     'gn': 'Berlin',
#     'sk': 'Berlín',
#     'ps': 'برلين',
#     'ro': 'Berlin',
#     'mk': 'Берлин',
#     'de': 'Berlin',
#     'sq': 'Berlini',
#     'hy': 'Բեռլին',
#     'co': 'Berlinu',
#     'gv': 'Berleen',
#     'he': 'ברלין',
#     'sc': 'Berlinu',
#     'pl': 'Berlin',
#     'eo': 'Berlino',
#     'id': 'Berlin',
#     'oc': 'Berlin',
#     'rm': 'Berlin',
#     'nn': 'Berlin',
#     'hi': 'बर्लिन',
#     'be': 'Берлін',
#     'sl': 'Berlin',
#     'uz': 'Berlin',
#     'ml': 'ബെര്\u200dലിന്',
#     'cu': 'Берлинъ',
#     'fa': 'برلین',
#     'cs': 'Berlín',
#     'ko': '베를린',
#     'ky': 'Берлин',
#     'af': 'Berlyn',
#     'tg': 'Берлин',
#     'br': 'Berlin',
#     'ia': 'Berlin',
#     'ab': 'Берлин',
#     'fr': 'Berlin',
#     'yo': 'Berlin',
#     'fo': 'Berlin',
#     'tt': 'Берлин',
#     'os': 'Берлин',
#     'ar': 'برلين',
#     'ja': 'ベルリン',
#     'it': 'Berlino',
#     'sw': 'Berlin',
#     'mg': 'Berlin',
#     'an': 'Berlín',
#     'ht': 'Bèlen',
#     'qu': 'Berlin',
#     'ln': 'Berlin',
#     'bn': 'বার্লিন',
#     'lg': 'Berlin',
#     'uk': 'Берлін',
#     'ms': 'Berlin',
#     'ca': 'Berlín',
#     'mi': 'Pearīni',
#     'zh': '柏林',
#     'ie': 'Berlin',
#     'da': 'Berlin',
#     'su': 'Berliini',
#     'el': 'Βερολίνο',
#     'mr': 'बर्लिन',
#     'ku': 'Berlîn',
#     'bo': 'པེ་ལིང་',
#     'am': 'በርሊን',
#     'vi': 'Berlin',
#     'ur': 'برلن',
#     'lt': 'Berlynas',
#     'zu': 'Berlin',
#     'hu': 'Berlin',
#     'mn': 'Берлин',
#     'bs': 'Berlin',
#     'kn': 'ಬೆರ್ಲಿನ್',
#     'et': 'Berliin',
#     'kv': 'Берлин',
#     'ba': 'Берлин',
#     'te': 'బెర్లిన్',
#     'gd': 'Berlin',
#     'bg': 'Берлин',
#     'li': 'Berlien',
#     'my': 'ဘာလင်မြို့',
#     'ug': 'Bérlin',
#     'se': 'Berlin',
#     'sv': 'Berlin',
#     'ru': 'Берлин',
#     'iu': 'ᐱᕐᓖᓐ',
#     'cv': 'Берлин',
#     'ta': 'பெர்லின்',
#     'ty': 'Berlin',
#     'nl': 'Berlijn',
#     'pt': 'Berlim',
#     'so': 'Berlin',
#     'la': 'Berolinum',
#     'tl': 'Berlin',
#     'fi': 'Berliini',
#     'jv': 'Berlin',
#     'bi': 'Berlin',
#     'eu': 'Berlin',
#     'cy': 'Berlin',
#     'fy': 'Berlyn',
#     'es': 'Berlín',
#     'si': 'බර්ලිනය',
#     'lv': 'Berlīne',
#     'na': 'Berlin',
#     'tr': 'Berlin',
#     'kw': 'Berlin',
#     'hr': 'Berlin',
#     'mt': 'Berlin'},
#    'lat': 52.5170365,
#    'lon': 13.3888599,
#    'country': 'DE'}],
#  [{'name': 'Brzesko',
#    'local_names': {'uk': 'Бжеско',
#     'pl': 'Brzesko',
#     'he': "בז'סקו",
#     'ru': 'Бжеско'},
#    'lat': 49.9678396,
#    'lon': 20.6068496,
#    'country': 'PL',
#    'state': 'Lesser Poland Voivodeship'}],
#  [{'name': 'BJ Block',
#    'local_names': {'bn': 'বিজে ব্লক', 'en': 'BJ Block'},
#    'lat': 22.5902239,
#    'lon': 88.4267468,
#    'country': 'IN',
#    'state': 'West Bengal'}],
#  [{'name': 'Bam',
#    'local_names': {'en': 'Bam',
#     'fr': 'Bam',
#     'ko': '밤',
#     'es': 'Bam',
#     'ru': 'Бам',
#     'ja': 'バム',
#     'ml': 'ബം',
#     'ar': 'بم',
#     'et': 'Bam',
#     'hi': 'बम',
#     'fa': 'شهر بم',
#     'de': 'Bam',
#     'uk': 'Бам'},
#    'lat': 29.1059864,
#    'lon': 58.3565663,
#    'country': 'IR',
#    'state': 'Kerman Province'}],
#  [{'name': 'Bath',
#    'local_names': {'fy': 'Bath',
#     'jv': 'Bath',
#     'kk': 'Бат',
#     'is': 'Bath',
#     'cs': 'Bath',
#     'id': 'Bath',
#     'uk': 'Бат',
#     'fi': 'Bath',
#     'ko': '바스',
#     'hy': 'Բաթ',
#     'ka': 'ბათი',
#     'nl': 'Bath',
#     'sd': 'باٿ شھر',
#     'sl': 'Bath',
#     'it': 'Bath',
#     'no': 'Bath',
#     'sk': 'Bath',
#     'he': "באת'",
#     'es': 'Bath',
#     'da': 'Bath',
#     'zh': '巴斯',
#     'tr': 'Bath',
#     'be': 'Бат',
#     'nn': 'Bath',
#     'cy': 'Caerfaddon',
#     'pt': 'Bath',
#     'bn': 'বাথ',
#     'gl': 'Bath',
#     'la': 'Aquae Sulis',
#     'ja': 'バース',
#     'hr': 'Bath',
#     'ru': 'Бат',
#     'fa': 'باث',
#     'ur': 'باتھ',
#     'mk': 'Бат',
#     'hu': 'Bath',
#     'sc': 'Bath',
#     'th': 'บาธ',
#     'br': 'Bath',
#     'sv': 'Bath',
#     'de': 'Bath',
#     'et': 'Bath',
#     'eu': 'Bath',
#     'ro': 'Bath',
#     'lv': 'Bāta',
#     'el': 'Μπαθ',
#     'ku': 'Bath',
#     'vo': 'Bath',
#     'sr': 'Бат',
#     'ga': 'Bath',
#     'eo': 'Bath',
#     'ca': 'Bath',
#     'tl': 'Bath',
#     'sh': 'Bath',
#     'af': 'Bath',
#     'bg': 'Бат',
#     'lb': 'Bath',
#     'az': 'Bat',
#     'qu': 'Bath',
#     'en': 'Bath',
#     'ar': 'باث',
#     'pl': 'Bath',
#     'tt': 'Бас',
#     'io': 'Bath',
#     'vi': 'Bath',
#     'fr': 'Bath',
#     'lt': 'Batas'},
#    'lat': 51.3813864,
#    'lon': -2.3596963,
#    'country': 'GB',
#    'state': 'England'}],
#  [{'name': 'Banan',
#    'local_names': {'vi': 'Ba Nam', 'zh': '巴南区', 'en': 'Banan', 'fr': 'Banan'},
#    'lat': 29.4043601,
#    'lon': 106.5368478,
#    'country': 'CN',
#    'state': 'Chongqing'}],
#  [{'name': 'Pau',
#    'local_names': {'ar': 'بو',
#     'ru': 'По',
#     'eo': 'Paŭo',
#     'oc': 'Pau',
#     'hu': 'Pau',
#     'fr': 'Pau',
#     'eu': 'Paue',
#     'zh': '波城',
#     'lt': 'Po',
#     'uk': 'По',
#     'sr': 'По',
#     'br': 'Pau',
#     'ja': 'ポー',
#     'el': 'Πω',
#     'la': 'Palum',
#     'ca': 'Pau'},
#    'lat': 43.2957547,
#    'lon': -0.3685668,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'Bar',
#    'local_names': {'eu': 'Bar',
#     'ca': 'Bar',
#     'fa': 'بار',
#     'fi': 'Bar',
#     'hu': 'Bar',
#     'tr': 'Bar',
#     'en': 'Bar',
#     'ko': '바르',
#     'sr': 'Бар',
#     'it': 'Antivari',
#     'es': 'Bar',
#     'kl': 'Bar',
#     'ur': 'بار',
#     'oc': 'Bar',
#     'ka': 'ბარი',
#     'ro': 'Bar',
#     'ce': 'Бар',
#     'lt': 'Baras',
#     'bg': 'Бар',
#     'sv': 'Bar',
#     'nl': 'Bar',
#     'fo': 'Bar',
#     'fr': 'Bar',
#     'et': 'Bar',
#     'de': 'Bar',
#     'ja': 'バール',
#     'is': 'Bar',
#     'ru': 'Бар',
#     'sq': 'Tivar',
#     'la': 'Antibarium',
#     'be': 'Бар',
#     'pt': 'Bar',
#     'sh': 'Bar',
#     'sk': 'Bar',
#     'sl': 'Bar',
#     'nn': 'Bar',
#     'cs': 'Bar',
#     'uk': 'Бар',
#     'bs': 'Bar',
#     'he': 'בר',
#     'ar': 'بار',
#     'pl': 'Bar',
#     'mk': 'Бар',
#     'el': 'Μπαρ',
#     'da': 'Bar',
#     'id': 'Bar',
#     'hr': 'Bar',
#     'nb': 'Bar'},
#    'lat': 42.0979745,
#    'lon': 19.0954528,
#    'country': 'ME'}],
#  [{'name': 'Bergamo',
#    'local_names': {'ca': 'Bèrgam',
#     'hu': 'Bergamo',
#     'it': 'Bergamo',
#     'el': 'Μπέργκαμο',
#     'uk': 'Бергамо',
#     'la': 'Bergomum',
#     'zh': '贝尔加莫',
#     'pt': 'Bérgamo',
#     'bg': 'Бергамо',
#     'fr': 'Bergame',
#     'en': 'Bergamo',
#     'es': 'Bérgamo',
#     'ru': 'Бергамо'},
#    'lat': 45.6944947,
#    'lon': 9.6698727,
#    'country': 'IT',
#    'state': 'Lombardy'}],
#  [{'name': 'BF Homes Caloocan',
#    'lat': 14.7321052,
#    'lon': 121.0237227,
#    'country': 'PH'}],
#  [{'name': 'Bujumbura',
#    'local_names': {'bg': 'Бужумбура',
#     'ps': 'بوجومبورا',
#     'ca': 'Mbabane',
#     'wo': 'Bujumbura',
#     'qu': 'Bujumbura',
#     'ga': 'Bujumbura',
#     'na': 'Bujumbura',
#     'nl': 'Bujumbura',
#     'be': 'Бужумбура',
#     'so': 'Bujumbura',
#     'tg': 'Буҷумбура',
#     'cy': 'Bujumbura',
#     'sn': 'Bujumbura',
#     'mk': 'Буџумбура',
#     'de': 'Bujumbura',
#     'sh': 'Bujumbura',
#     'ka': 'ბუჟუმბურა',
#     'fr': 'Bujumbura',
#     'rn': 'Bujumbura',
#     'uk': 'Бужумбура',
#     'fi': 'Bujumbura',
#     'uz': 'Bujumbura',
#     'mg': 'Bujumbura',
#     'sr': 'Буџумбура',
#     'id': 'Bujumbura',
#     'mr': 'बुजुंबुरा',
#     'eo': 'Buĵumburo',
#     'he': "בוג'ומבורה",
#     'zh': '布琼布拉',
#     'ce': 'Бужумбура',
#     'pl': 'Bużumbura',
#     'yo': 'Bujumbura',
#     'bs': 'Bujumbura',
#     'sv': 'Bujumbura',
#     'hu': 'Bujumbura',
#     'kw': 'Bujumbura',
#     'yi': 'בוזשומבורע',
#     'ru': 'Бужумбура',
#     'tr': 'Bujumbura',
#     'am': 'ቡጁምቡራ',
#     'ml': 'ബുജുംബുറ',
#     'sk': 'Bujumbura',
#     'ie': 'Bujumbura',
#     'lb': 'Bujumbura',
#     'hr': 'Bujumbura',
#     'zu': 'Bujumbura',
#     'fa': 'بوجومبورا',
#     'ny': 'Bujumbura',
#     'mn': 'Бужумбура',
#     'jv': 'Bujumbura',
#     'la': 'Bujumbura',
#     'tl': 'Bujumbura',
#     'sw': 'Bujumbura',
#     'lv': 'Bužumbura',
#     'hy': 'Բուժումբուրա',
#     'is': 'Bújúmbúra',
#     'da': 'Bujumbura',
#     'fy': 'Bûjûmbûra',
#     'ms': 'Bujumbura',
#     'et': 'Bujumbura',
#     'ja': 'ブジュンブラ',
#     'ko': '부줌부라',
#     'lt': 'Bužumbūra',
#     'pa': 'ਬੁਜੁੰਬੁਰਾ',
#     'vi': 'Bujumbura',
#     'ro': 'Bujumbura',
#     'ky': 'Бужумбура',
#     'gd': 'Bujumbura',
#     'az': 'Bujumbura',
#     'ht': 'Boujoumboura',
#     'nn': 'Bujumbura',
#     'ku': 'Bujumbura',
#     'kg': 'Bujumbura',
#     'en': 'Bujumbura',
#     'ar': 'بوجومبورا',
#     'sq': 'Buzhumbura',
#     'ta': 'புசும்புரா',
#     'pt': 'Bujumbura',
#     'an': 'Buyumbura',
#     'el': 'Μπουζουμπούρα',
#     'kk': 'Бужумбура',
#     'cs': 'Bujumbura',
#     'eu': 'Bujumbura',
#     'af': 'Bujumbura',
#     'sl': 'Bujumbura',
#     'it': 'Bujumbura',
#     'ur': 'بوجومبرا',
#     'rw': 'Bujumbura',
#     'no': 'Bujumbura',
#     'ha': 'Bujumbura',
#     'br': 'Bujumbura',
#     'oc': 'Bujumbura',
#     'ln': 'Bujumbúra',
#     'gl': 'Bujumbura',
#     'io': 'Bujumbura',
#     'es': 'Buyumbura',
#     'bo': 'བུ་ཇུམ་བུ་ར།',
#     'th': 'บูจุมบูรา'},
#    'lat': -3.3638125,
#    'lon': 29.3675028,
#    'country': 'BI',
#    'state': 'Bujumbura Mairie'}],
#  [{'name': 'Companhia',
#    'lat': -22.1822689,
#    'lon': -44.68776,
#    'country': 'BR',
#    'state': 'Minas Gerais'}],
#  [{'name': 'Close',
#    'local_names': {'ga': 'An Clós'},
#    'lat': 51.6901245,
#    'lon': -9.5131483,
#    'country': 'IE'}],
#  [{'name': 'Chun',
#    'local_names': {'en': 'Chun', 'th': 'จุน'},
#    'lat': 19.3091175,
#    'lon': 100.1647501,
#    'country': 'TH',
#    'state': 'Phayao Province'}],
#  [{'name': 'Co',
#    'lat': 60.29492475,
#    'lon': 26.0047019985007,
#    'country': 'FI'}],
#  [{'name': 'Crescent',
#    'lat': 41.3650699,
#    'lon': -95.858422,
#    'country': 'US',
#    'state': 'Iowa'}],
#  [{'name': 'Huraa',
#    'local_names': {'dv': 'ހުރާ', 'en': 'Huraa'},
#    'lat': 4.3337710000000005,
#    'lon': 73.60197749346682,
#    'country': 'MV',
#    'state': 'Malé Atoll'}],
#  [{'name': 'Chișinău Municipality',
#    'local_names': {'ro': 'Municipiul Chișinău',
#     'ru': 'Муниципалитет Кишинёв',
#     'uk': 'Муніципій Кишинів',
#     'fr': 'Municipalité de Chișinău',
#     'mo': 'Municipiul Chișinău',
#     'de': 'Munizip Kischinau',
#     'en': 'Chișinău Municipality'},
#    'lat': 47.00740025,
#    'lon': 28.843146600415984,
#    'country': 'MD'}],
#  [{'name': 'Denbigh',
#    'local_names': {'cy': 'Dinbych', 'en': 'Denbigh', 'ur': 'ڈنبی'},
#    'lat': 53.1853776,
#    'lon': -3.4178289,
#    'country': 'GB',
#    'state': 'Wales'}],
#  [{'name': 'Doha',
#    'local_names': {'ku': 'Doha',
#     'tk': 'Doha',
#     'sn': 'Doha',
#     'id': 'Doha',
#     'ie': 'Doha',
#     'ba': 'Доһа',
#     'kl': 'Doha',
#     'hy': 'Դոհա',
#     'ms': 'Doha',
#     'yo': 'Doha',
#     'oc': 'Doha',
#     'ht': 'Doha',
#     'ps': 'دوحه',
#     'sc': 'Doha',
#     'pa': 'ਦੋਹਾ',
#     'lt': 'Doha',
#     'pl': 'Doha',
#     'bn': 'দোহা',
#     'sd': 'دوحہ',
#     'no': 'Doha',
#     'el': 'Ντόχα',
#     'tg': 'Дуҳа',
#     'fa': 'دوحه',
#     'ru': 'Доха',
#     'tt': 'Doha',
#     'ne': 'दोहा',
#     'da': 'Doha',
#     'os': 'Дохæ',
#     'ur': 'دوحہ',
#     'eu': 'Doha',
#     'ta': 'தோகா',
#     'sk': 'Dauha',
#     'gr': 'Δοχή',
#     'nn': 'Doha',
#     'lb': 'Doha',
#     'af': 'Doha',
#     'mg': 'Doha',
#     'an': 'Doha',
#     'kn': 'ದೊಹಾ',
#     'ml': 'ദോഹ',
#     'hi': 'दोहा, क़तर',
#     'km': 'ដូហា',
#     'cs': 'Dauhá',
#     'ca': 'Doha',
#     'ky': 'Доха',
#     'ga': 'Doha',
#     'vi': 'Doha',
#     'eo': 'Doho',
#     'lv': 'Doha',
#     'sw': 'Doha',
#     'az': 'Doha',
#     'hu': 'Doha',
#     'cy': 'Doha',
#     'kk': 'Доһа',
#     'uz': 'Doʻha',
#     'en': 'Doha',
#     'he': 'דוחה',
#     'sq': 'Doha',
#     'uk': 'Доха',
#     'fr': 'Doha',
#     'ar': 'الدوحة',
#     'be': 'Доха',
#     'rw': 'Doha',
#     'sv': 'Doha',
#     'sh': 'Doha',
#     'my': 'ဒိုဟာမြို့',
#     'so': 'Dooxa',
#     'tl': 'Doha',
#     'ia': 'Doha',
#     'yi': 'דאכא',
#     'hr': 'Doha',
#     'ka': 'დოჰა',
#     'fy': 'Doha',
#     'ha': 'Doha',
#     'de': 'Doha',
#     'io': 'Doha',
#     'gn': 'Doha',
#     'bs': 'Doha',
#     'mn': 'Доха',
#     'mr': 'दोहा',
#     'am': 'ዶሃ',
#     'vo': 'Däuha',
#     'zh': '多哈',
#     'nl': 'Doha',
#     'is': 'Doha',
#     'ro': 'Doha',
#     'ce': 'Духьа',
#     'ko': '도하',
#     'ja': 'ドーハ',
#     'bg': 'Доха',
#     'bo': 'དྷོ་ཧ།',
#     'th': 'โดฮา',
#     'es': 'Doha',
#     'tr': 'Doha',
#     'la': 'Doha',
#     'jv': 'Doha',
#     'gu': 'દોહા',
#     'mk': 'Доха',
#     'et': 'Doha',
#     'br': 'Doha',
#     'pt': 'Doha',
#     'fi': 'Doha',
#     'gd': 'Doha',
#     'ug': 'دوھا',
#     'it': 'Doha',
#     'sr': 'Доха',
#     'sl': 'Doha',
#     'gl': 'Doha'},
#    'lat': 25.2856329,
#    'lon': 51.5264162,
#    'country': 'QA'}],
#  [{'name': 'Majowe',
#    'local_names': {'pl': 'Majowe'},
#    'lat': 53.3759661,
#    'lon': 14.6659283,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Do',
#    'lat': 42.9000719,
#    'lon': 18.0298066,
#    'country': 'BA',
#    'state': 'Republika Srpska'}],
#  [{'name': 'Opatowiec',
#    'local_names': {'pl': 'Opatowiec', 'ru': 'Опатовец', 'uk': "Опатов'єц"},
#    'lat': 50.2425871,
#    'lon': 20.7237798,
#    'country': 'PL',
#    'state': 'Świętokrzyskie Voivodeship'}],
#  [{'name': 'Eigg',
#    'local_names': {'en': 'Eigg', 'gd': 'Eige', 'mk': 'Ег'},
#    'lat': 56.907925399999996,
#    'lon': -6.160063788529316,
#    'country': 'GB',
#    'state': 'Scotland'}],
#  [{'name': 'Err',
#    'local_names': {'ca': 'Er', 'fr': 'Err'},
#    'lat': 42.4406621,
#    'lon': 2.0328526,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Ee',
#    'local_names': {'nl': 'Ee', 'fy': 'Ie'},
#    'lat': 53.3300561,
#    'lon': 6.1040747,
#    'country': 'NL',
#    'state': 'Frisia'}],
#  [{'name': 'Eth',
#    'local_names': {'ru': 'Эт', 'fr': 'Eth'},
#    'lat': 50.3260433,
#    'lon': 3.6671281,
#    'country': 'FR',
#    'state': 'Hauts-de-France'}],
#  [{'name': 'Faux',
#    'local_names': {'sr': 'Фо',
#     'kk': 'Фо',
#     'uk': 'Фо',
#     'be': 'Фо',
#     'fr': 'Faux',
#     'mk': 'Фо',
#     'bg': 'Фо',
#     'ru': 'Фо',
#     'zh': '福村'},
#    'lat': 49.5374982,
#    'lon': 4.5001619,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'FJ Kato Village',
#    'lat': 7.0682339,
#    'lon': 125.5825322,
#    'country': 'PH'}],
#  [{'name': 'Fing',
#    'local_names': {'fr': 'Fing'},
#    'lat': 14.0685426,
#    'lon': -5.4854786,
#    'country': 'ML',
#    'state': 'Ségou Region'}],
#  [{'name': 'Schönberg/Schoenberg',
#    'local_names': {'de': 'Schönberg', 'fr': 'Schoenberg'},
#    'lat': 46.8101241,
#    'lon': 7.171828,
#    'country': 'CH',
#    'state': 'Fribourg'}],
#  [{'name': 'Town of Gates',
#    'local_names': {'en': 'Town of Gates'},
#    'lat': 43.1514226,
#    'lon': -77.7130004,
#    'country': 'US',
#    'state': 'New York'}],
#  [{'name': 'GM',
#    'lat': 37.36827785,
#    'lon': -121.88408532799455,
#    'country': 'US',
#    'state': 'California'}],
#  [{'name': 'Geapa',
#    'local_names': {'en': 'Geapa'},
#    'lat': 6.453333,
#    'lon': -8.998056,
#    'country': 'LR',
#    'state': 'Nimba County'}],
#  [{'name': 'Daix',
#    'local_names': {'fr': 'Daix', 'ja': 'デ'},
#    'lat': 47.3521149,
#    'lon': 5.0008333,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Qal`eh Gah-e Karkar',
#    'local_names': {'en': 'Qal`eh Gah-e Karkar', 'fa': 'قلعه گه کرکر'},
#    'lat': 36.159,
#    'lon': 46.6714,
#    'country': 'IR',
#    'state': 'Kurdistan Province'}],
#  [{'name': 'Graben',
#    'lat': 48.1890811,
#    'lon': 10.8220308,
#    'country': 'DE',
#    'state': 'Bavaria'}],
#  [{'name': 'Goidhoo',
#    'local_names': {'dv': 'ގޮއިދޫ', 'en': 'Goidhoo'},
#    'lat': 4.87108555,
#    'lon': 72.99771789715751,
#    'country': 'MV',
#    'state': 'Maalhosmadulu Dhekunuburi'}],
#  [{'name': 'Gat',
#    'local_names': {'en': 'Gat', 'fr': 'Gat', 'he': 'גת'},
#    'lat': 31.6268616,
#    'lon': 34.7951088,
#    'country': 'IL',
#    'state': 'South District'}],
#  [{'name': 'Baharan',
#    'local_names': {'en': 'Baharan', 'fa': 'بهاران'},
#    'lat': 25.3562859,
#    'lon': 60.8477664,
#    'country': 'IR',
#    'state': 'Sistan and Baluchestan Province'}],
#  [{'name': 'Gy',
#    'local_names': {'fr': 'Gy', 'uk': 'Жі'},
#    'lat': 47.4068,
#    'lon': 5.8146609,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Heights',
#    'lat': 37.2112612,
#    'lon': -77.4072045,
#    'country': 'US',
#    'state': 'Virginia'}],
#  [{'name': 'Əhən',
#    'local_names': {'az': 'Əhən'},
#    'lat': 40.8525767,
#    'lon': 48.4162128,
#    'country': 'AZ',
#    'state': 'Mountainous Shirvan'}],
#  [{'name': 'Hek',
#    'local_names': {'en': 'Hek', 'fa': 'هک'},
#    'lat': 31.0869054,
#    'lon': 53.3006387,
#    'country': 'IR',
#    'state': 'Yazd Province'}],
#  [{'name': 'Shanghai',
#    'local_names': {'oc': 'Shanghai',
#     'ky': 'Шанхай',
#     'sw': 'Shanghai',
#     'tk': 'Şanhaý',
#     'eu': 'Shanghai',
#     'jv': 'Shanghai',
#     'feature_name': 'Shanghai',
#     'ie': 'Shanghai',
#     'th': 'เซี่ยงไฮ้',
#     'bo': 'ཧྲང་ཧའེ་གྲོང་ཁྱེར།',
#     'cv': 'Шанхай',
#     'ba': 'Шанхай',
#     'sv': 'Shanghai',
#     'be': 'Шанхай',
#     'tn': 'Shanghai',
#     'zu': 'Shanghai',
#     'yi': 'שאנכיי',
#     'qu': 'Shanghai',
#     'nl': 'Shanghai',
#     'gl': 'Shanghai',
#     'lt': 'Šanchajus',
#     'eo': 'Ŝanhajo',
#     'zh': '上海市',
#     'vo': 'Shanghai',
#     'tl': 'Shanghai',
#     'fj': 'Shaghai',
#     'ug': 'شاڭخەي شەھىرى',
#     'ga': 'Shang-hai',
#     'hy': 'Շանհայ',
#     'as': 'ছাংহাই',
#     'ar': 'شانغهاي',
#     'pa': 'ਸ਼ੰਘਾਈ',
#     'uz': 'Shanxay',
#     'tt': 'Şanxay',
#     'za': 'Sanghaij',
#     'bi': 'Shanghai',
#     'fo': 'Shanghai',
#     'hu': 'Sanghaj',
#     'kk': 'Шанхай',
#     'lo': 'ຊຽງໄຮ້',
#     'pl': 'Szanghaj',
#     'la': 'Sciamhaevum',
#     'mg': 'Shanghai',
#     'id': 'Shanghai',
#     'ki': 'Shanghai',
#     'ne': 'शाङ्घाई',
#     'kg': 'Shanghai',
#     'nn': 'Shanghai',
#     'ku': 'Şanghay',
#     'ps': 'شانگهای',
#     'sk': 'Šanghaj',
#     'ru': 'Шанхай',
#     'fr': 'Shanghai',
#     'su': 'Shanghai',
#     'gv': 'Shanghai',
#     'hi': 'शंघाई',
#     'de': 'Shanghai',
#     'it': 'Shanghai',
#     'mk': 'Шангај',
#     'lb': 'Shanghai',
#     'mn': 'Шанхай',
#     'te': 'షాంఘై',
#     'io': 'Shanghai',
#     'hr': 'Šangaj',
#     'kl': 'Shanghai',
#     'an': 'Xangai',
#     'mr': 'शांघाय',
#     'ro': 'Shanghai',
#     'fy': 'Shanghai',
#     'rm': 'Schanghai',
#     'ka': 'შანხაი',
#     'om': 'Shaangaayi',
#     'tw': 'Shangai',
#     'bg': 'Шанхай',
#     'es': 'Shanghái',
#     'am': 'ሻንግሃይ',
#     'fi': 'Shanghai',
#     'ta': 'சாங்காய்',
#     'sq': 'Shangai',
#     'ht': 'Shanghai',
#     'ja': '上海市',
#     'ln': 'Shanghai',
#     'bs': 'Šangaj',
#     'si': 'ෂැංහයි',
#     'kw': 'Shanghai',
#     'kn': 'ಶಾಂಘೈ',
#     'os': 'Шанхай',
#     'ny': 'Shanghai',
#     'ml': 'ഷാങ്ഹായ്',
#     'fa': 'شانگهای',
#     'ms': 'Shanghai',
#     'cy': 'Shanghai',
#     'pt': 'Xangai',
#     'et': 'Shanghai',
#     'sr': 'Шангај',
#     'gn': 'Changái',
#     'ko': '상하이',
#     'ha': 'Shanghai',
#     'bn': 'সাংহাই',
#     'vi': 'Thượng Hải',
#     'uk': 'Шанхай',
#     'sl': 'Šanghaj',
#     'el': 'Σαγκάη',
#     'tg': 'Шанхай',
#     'he': 'שאנגחאי',
#     'lv': 'Šanhaja',
#     'ay': 'Shanghai',
#     'my': 'ရှန်ဟိုင်းမြို့',
#     'ascii': 'Shanghai',
#     'ce': 'Шанхай',
#     'ia': 'Shanghai',
#     'en': 'Shanghai',
#     'mi': 'Hangahai',
#     'kv': 'Шанхай',
#     'tr': 'Şanghay',
#     'wo': 'Shanghai',
#     'ur': 'شنگھائی',
#     'gd': 'Shanghai',
#     'no': 'Shanghai',
#     'af': 'Sjanghai',
#     'br': 'Shanghai',
#     'is': 'Sjanghæ',
#     'li': 'Sjanghai',
#     'az': 'Şanxay',
#     'bm': 'Shanghai',
#     'cs': 'Šanghaj',
#     'da': 'Shanghai',
#     'ca': 'Xangai'},
#    'lat': 31.2322758,
#    'lon': 121.4692071,
#    'country': 'CN'}],
#  [{'name': 'Islamabad',
#    'local_names': {'pt': 'Islamabade',
#     'th': 'อิสลามาบัด',
#     'ps': 'اسلام آباد',
#     'kk': 'Исламабад',
#     'ks': 'اِسلام آبادٖ',
#     'ka': 'ისლამაბადი',
#     'nn': 'Islamabad',
#     'sq': 'Islamabadi',
#     'he': 'איסלמבד',
#     'pa': 'ਇਸਲਾਮਾਬਾਦ',
#     'eu': 'Islamabad',
#     'sv': 'Islamabad',
#     'oc': 'Islamabad',
#     'tr': 'İslamabad',
#     'lt': 'Islamabadas',
#     'nl': 'Islamabad',
#     'yi': 'איסלאמאבאד',
#     'cs': 'Islámábád',
#     'bo': 'ཨི་སི་ལམ་བོ།',
#     'ja': 'イスラーマーバード首都圏;イスラマバード',
#     'hu': 'Iszlámábád',
#     'os': 'Исламабад',
#     'it': 'Islamabad',
#     'be': 'Ісламабад',
#     'en': 'Islamabad',
#     'ug': 'ئىسلامئاباد',
#     'gu': 'ઇસ્લામાબાદ',
#     'es': 'Islamabad',
#     'zh': '伊斯蘭堡',
#     'am': 'ኢስላማባድ',
#     'bg': 'Исламабад',
#     'et': 'Islāmābād',
#     'gr': 'Ἰσλαμαβάδη',
#     'ru': 'Исламабад',
#     'la': 'Islamabada',
#     'vi': 'Islamabad',
#     'dv': 'އިސްލާމްއާބާދު',
#     'lv': 'Islāmābāda',
#     'hi': 'इस्लामाबाद',
#     'ar': 'إسلام آباد',
#     'el': 'Ισλαμαμπάντ',
#     'az': 'İslamabad',
#     'mr': 'इस्लामाबाद',
#     'sd': 'اسلام آباد',
#     'tg': 'Исламабад',
#     'sk': 'Islamabad',
#     'ta': 'இஸ்லாமாபாத்',
#     'mn': 'Исламабад',
#     'ko': '이슬라마바드',
#     'pl': 'Islamabad',
#     'is': 'Islamabad',
#     'eo': 'Islamabado',
#     'hy': 'Իսլամաբադ',
#     'sr': 'Исламабад',
#     'fr': 'Islamabad',
#     'ku': 'Îslamabad',
#     'no': 'Islamabad',
#     'mk': 'Исламабад',
#     'ur': 'اسلام آباد',
#     'kn': 'ಇಸ್ಲಾಮಾಬಾದ್',
#     'ml': 'ഇസ്ലാമബാദ്',
#     'te': 'ఇస్లామాబాద్',
#     'uk': 'Ісламабад',
#     'bn': 'ইসলামাবাদ',
#     'de': 'Islamabad',
#     'fa': 'اسلام\u200cآباد'},
#    'lat': 33.6938118,
#    'lon': 73.0651511,
#    'country': 'PK',
#    'state': 'Islamabad Capital Territory'}],
#  [{'name': 'Innermedøya',
#    'lat': 66.8789958,
#    'lon': 13.44650821244402,
#    'country': 'NO'}],
#  [{'name': 'Narman',
#    'local_names': {'tt': 'Нарман',
#     'fa': 'نارمان',
#     'ku': 'Narman',
#     'ru': 'Нарман',
#     'ce': 'Нарман',
#     'ur': 'نارمان',
#     'hy': 'Նառիման',
#     'ka': 'ნარიმანი',
#     'tr': 'Narman'},
#    'lat': 40.3452003,
#    'lon': 41.871138,
#    'country': 'TR'}],
#  [{'name': 'Hadaiq el Qubbah',
#    'local_names': {'ascii': 'Ḩadā’iq al Qubbah, Hadaiq al Qubbah, Garden City, Qubba Gardens',
#     'feature_name': 'Ḩadā’iq al Qubbah, Hadaiq al Qubbah, Garden City, Qubba Gardens',
#     'ar': 'حدائق القبة',
#     'de': 'Hadaiq el Qubbah',
#     'en': 'Hadaiq el Qubbah',
#     'fr': 'Hadaiq el Qubbah'},
#    'lat': 30.0821784,
#    'lon': 31.2825387,
#    'country': 'EG',
#    'state': 'Cairo'}],
#  [{'name': 'Ie',
#    'local_names': {'fr': 'Ie',
#     'uk': 'Іє',
#     'en': 'Ie',
#     'zh': '伊江村',
#     'ja': '伊江村',
#     'ru': 'Иэ'},
#    'lat': 26.721715,
#    'lon': 127.786429,
#    'country': 'JP'}],
#  [{'name': 'Isle',
#    'local_names': {'oc': 'Isla (de Vinhana)', 'uk': 'Іль', 'fr': 'Isle'},
#    'lat': 45.8055591,
#    'lon': 1.2238259,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'It',
#    'lat': 45.6628887,
#    'lon': 10.118138,
#    'country': 'IT',
#    'state': 'Lombardy'}],
#  [{'name': 'Jam',
#    'local_names': {'ru': 'Джем',
#     'de': 'Dscham',
#     'en': 'Jam',
#     'fa': 'جم',
#     'fr': 'Jam',
#     'hi': 'जम',
#     'ja': 'ジャム'},
#    'lat': 27.8262811,
#    'lon': 52.3263597,
#    'country': 'IR',
#    'state': 'Bushehr Province'}],
#  [{'name': 'Tokyo',
#    'local_names': {'sv': 'Tokyo',
#     'ta': 'டோக்கியோ',
#     'de': 'Tokio',
#     'eo': 'Tokio',
#     'pl': 'Tokio',
#     'lt': 'Tokijas',
#     'sl': 'Tokio',
#     'nl': 'Tokio',
#     'zh': '东京都/東京都',
#     'kn': 'ಟೋಕ್ಯೊ',
#     'ko': '도쿄도',
#     'tg': 'Токио',
#     'bg': 'Токио',
#     'et': 'Tōkyō',
#     'lb': 'Tokio',
#     'sr': 'Токио',
#     'da': 'Tokyo',
#     'en': 'Tokyo',
#     'mi': 'Tōkio',
#     'tr': 'Tokyo',
#     'fa': 'توکیو',
#     'la': 'Tokium',
#     'ia': 'Tokyo',
#     'cs': 'Tokio',
#     'th': 'โตเกียว',
#     'io': 'Tokyo',
#     'hr': 'Tokio',
#     'is': 'Tókýó',
#     'ku': 'Tokyo',
#     'ru': 'Токио',
#     'uk': 'Токіо',
#     'hu': 'Tokió',
#     'sk': 'Tokio',
#     'it': 'Tokyo',
#     'lv': 'Tokija',
#     'he': 'טוקיו',
#     'ca': 'Tòquio',
#     'be': 'Токіа',
#     'cy': 'Tokyo',
#     'ja': '東京都',
#     'oc': 'Tòquio',
#     'mr': 'तोक्यो',
#     'fi': 'Tokio',
#     'vi': 'Tokyo',
#     'es': 'Tokio',
#     'pt': 'Tóquio',
#     'fr': 'Tokyo',
#     'ar': 'طوكيو',
#     'el': 'Τόκιο'},
#    'lat': 35.6828387,
#    'lon': 139.7594549,
#    'country': 'JP'}],
#  [{'name': 'Jo',
#    'local_names': {'en': 'Jo'},
#    'lat': 27.248611,
#    'lon': 66.630556,
#    'country': 'PK',
#    'state': 'Balochistan'}],
#  [{'name': 'Križ',
#    'local_names': {'hr': 'Križ', 'hu': 'Obedszentkereszt'},
#    'lat': 45.6632061,
#    'lon': 16.5204571,
#    'country': 'HR'}],
#  [{'name': 'Ke',
#    'lat': 4.454561,
#    'lon': 6.915462,
#    'country': 'NG',
#    'state': 'Rivers State'}],
#  [{'name': 'Acre',
#    'local_names': {'it': 'Acri',
#     'eo': 'Akko',
#     'en': 'Acre',
#     'ja': 'アッコ',
#     'fi': 'Akko',
#     'eu': 'Akre',
#     'fa': 'عکا',
#     'et': 'Akko',
#     'af': 'Akko',
#     'es': 'Acre',
#     'da': 'Akko',
#     'bg': 'Акра',
#     'ar': 'عكا',
#     'am': 'ዓኮ',
#     'ku': 'Eka',
#     'ca': 'Acre',
#     'ml': 'ഏക്കർ',
#     'ru': 'Акко',
#     'he': 'עכו',
#     'cy': 'Acre',
#     'lt': 'Akas',
#     'ur': 'عکا',
#     'cs': 'Akko',
#     'el': 'Άκρα',
#     'fr': 'Acre',
#     'de': 'Akko',
#     'hi': 'एकर'},
#    'lat': 32.9281731,
#    'lon': 35.0756378,
#    'country': 'IL',
#    'state': 'North District'}],
#  [{'name': 'Kogel',
#    'local_names': {'de': 'Kogel'},
#    'lat': 53.4672206,
#    'lon': 10.9199709,
#    'country': 'DE',
#    'state': 'Mecklenburg-Vorpommern'}],
#  [{'name': 'Riga',
#    'local_names': {'fi': 'Riika',
#     'en': 'Riga',
#     'sw': 'Riga',
#     'hu': 'Riga',
#     'se': 'Riga',
#     'gd': 'Riga',
#     'kk': 'Рига',
#     'pt': 'Riga',
#     'cs': 'Riga',
#     'sl': 'Riga',
#     'qu': 'Riga',
#     'fa': 'ریگا',
#     'my': 'ရီဂါမြို့',
#     'eo': 'Rigo',
#     'lv': 'Rīga',
#     'lt': 'Ryga',
#     'hy': 'Ռիգա',
#     'mg': 'Riga',
#     'hi': 'रीगा',
#     'an': 'Riga',
#     'tt': 'Рига',
#     'el': 'Ρίγα',
#     'na': 'Riga',
#     'eu': 'Riga',
#     'kw': 'Rīga',
#     'et': 'Riia',
#     'be': 'Рыга',
#     'ht': 'Riga',
#     'fr': 'Riga',
#     'ro': 'Riga',
#     'uz': 'Riga',
#     'io': 'Riga',
#     'nn': 'Riga',
#     'nv': 'Wiiga',
#     'sr': 'Рига',
#     'lb': 'Rīga',
#     'mt': 'Riga',
#     'jv': 'Riga',
#     'feature_name': 'Riga',
#     'cy': 'Riga',
#     'ur': 'ریگا',
#     'ky': 'Рига',
#     'mi': 'Riga',
#     'fy': 'Riga',
#     'bn': 'রিগা',
#     'ie': 'Riga',
#     'ka': 'რიგა',
#     'ascii': 'Riga',
#     'la': 'Riga',
#     'cu': 'Рига',
#     'ku': 'Rîga',
#     'mk': 'Рига',
#     'hr': 'Riga',
#     'bg': 'Рига',
#     'id': 'Riga',
#     'ko': '리가',
#     'nl': 'Riga',
#     'vo': 'Rīga',
#     'ca': 'Riga',
#     'bo': 'རི་ག',
#     'cv': 'Рига',
#     'fo': 'Riga',
#     'bs': 'Riga',
#     'kl': 'Riga',
#     'oc': 'Riga',
#     'da': 'Riga',
#     'zu': 'IRiga',
#     'ja': 'リガ',
#     'gl': 'Riga',
#     'tr': 'Riga',
#     'zh': '里加',
#     'de': 'Riga',
#     'is': 'Ríga',
#     'pl': 'Ryga',
#     'it': 'Riga',
#     'he': 'ריגה',
#     'th': 'รีกา',
#     'ar': 'ريغا',
#     'os': 'Ригæ',
#     'af': 'Riga',
#     'vi': 'Riga',
#     'az': 'Riqa',
#     'br': 'Riga',
#     'tg': 'Рига',
#     'st': 'Riga',
#     'pa': 'ਰੀਗਾ',
#     'sk': 'Riga',
#     'ln': 'Riga',
#     'gv': 'Rīga',
#     'es': 'Riga',
#     'no': 'Riga',
#     'ug': 'رىگا',
#     'kv': 'Рига',
#     'ga': 'Ríge',
#     'am': 'ሪጋ',
#     'ee': 'Riga',
#     'ta': 'ரீகா',
#     'tl': 'Riga',
#     'yi': 'ריגע',
#     'sv': 'Riga',
#     'yo': 'Riga',
#     'mr': 'रिगा',
#     'wo': 'Riga',
#     'uk': 'Рига',
#     'ru': 'Рига',
#     'ms': 'Riga',
#     'sq': 'Riga'},
#    'lat': 56.9493977,
#    'lon': 24.1051846,
#    'country': 'LV',
#    'state': 'Vidzeme'}],
#  [{'name': 'Elba',
#    'local_names': {'ca': "Illa d'Elba",
#     'no': 'Elba',
#     'su': 'Elba',
#     'lv': 'Elba',
#     'be': 'Востраў Эльба',
#     'eu': 'Elba',
#     'af': 'Elba',
#     'hr': 'Elba',
#     'et': 'Elba',
#     'cy': 'Ynys Elba',
#     'de': 'Elba',
#     'lt': 'Elba',
#     'nl': 'Elba',
#     'zh': '厄尔巴岛',
#     'sk': 'Elba',
#     'es': 'Isla de Elba',
#     'is': 'Elba',
#     'hy': 'Էլբա',
#     'gl': 'Illa de Elba',
#     'vi': 'Elba',
#     'br': 'Elba',
#     'pt': 'Ilha de Elba',
#     'pl': 'Elba',
#     'sv': 'Elba',
#     'tr': 'Elba',
#     'sl': 'Elba',
#     'sr': 'Елба',
#     'el': 'Έλβα',
#     'ka': 'ელბა',
#     'ml': 'എൽബ',
#     'ko': '엘바 섬',
#     'mr': 'एल्बा',
#     'en': 'Elba',
#     'ga': 'Elba',
#     'eo': 'Elbo',
#     'ja': 'エルバ島',
#     'gd': 'Elba',
#     'fr': "Île d'Elbe",
#     'yi': 'עלבע',
#     'ta': 'எல்பா',
#     'ro': 'Elba',
#     'bg': 'Елба',
#     'nn': 'Elba',
#     'la': 'Ilva',
#     'ar': 'إلبا',
#     'da': 'Elba',
#     'uk': 'Ельба',
#     'co': "Isula d'Elba",
#     'fi': 'Elba',
#     'id': 'Elba',
#     'th': 'เกาะเอลบา',
#     'ru': 'Эльба',
#     'cs': 'Elba',
#     'mk': 'Елба',
#     'lb': 'Elba'},
#    'lat': 42.790216599999994,
#    'lon': 10.340278678735025,
#    'country': 'IT',
#    'state': 'Tuscany'}],
#  [{'name': 'Awlus',
#    'local_names': {'ar': 'علص',
#     'de': 'Awlus',
#     'en': 'Awlus',
#     'fr': 'Awlus',
#     'ascii': '`Allas, `Allās, Awlūs',
#     'feature_name': '`Allas, `Allās, Awlūs'},
#    'lat': 35.7129221,
#    'lon': 37.3643315,
#    'country': 'SY',
#    'state': 'Aleppo Governorate'}],
#  [{'name': '`Alt',
#    'local_names': {'ascii': '‘Alt',
#     'feature_name': '‘Alt',
#     'ar': 'علط',
#     'de': '`Alt',
#     'en': '`Alt',
#     'fr': '`Alt'},
#    'lat': 15.544005,
#    'lon': 48.0239718,
#    'country': 'YE',
#    'state': 'Hadramaut Governorate'}],
#  [{'name': 'Lu',
#    'local_names': {'zh': '泸县', 'en': 'Lu', 'fr': 'Lu', 'vi': 'Lô'},
#    'lat': 29.1539219,
#    'lon': 105.3788947,
#    'country': 'CN',
#    'state': 'Sichuan'}],
#  [{'name': 'Majuro',
#    'local_names': {'it': 'Majuro',
#     'no': 'Majuro',
#     'io': 'Majuro',
#     'en': 'Majuro',
#     'da': 'Majuro',
#     'ko': '마주로',
#     'tr': 'Majuro',
#     'mk': 'Маџуро',
#     'pt': 'Majuro',
#     'ty': 'Majuro',
#     'sh': 'Majuro',
#     'hr': 'Majuro',
#     'sq': 'Majuro',
#     'hu': 'Majuro',
#     'la': 'Madzurum',
#     'az': 'Macuro',
#     'gd': 'Majuro',
#     'is': 'Majúró',
#     'id': 'Majuro',
#     'vi': 'Majuro',
#     'ie': 'Majuro',
#     'es': 'Majuro',
#     'ht': 'Majouro',
#     'ka': 'მაჯურო',
#     'ml': 'മാജുറോ',
#     'cy': 'Majuro',
#     'lb': 'Majuro',
#     'ru': 'Маджуро',
#     'gl': 'Majuro',
#     'bg': 'Маджуро',
#     'ny': 'Majuro',
#     'fr': 'Majuro',
#     'uk': 'Маджуро',
#     'eo': 'Majuro',
#     'am': 'ማጁሮ',
#     'ar': 'ماجورو',
#     'fy': 'Majuro',
#     'af': 'Majuro',
#     'ur': 'ماجورو',
#     'tl': 'Majuro',
#     'lt': 'Madžūras',
#     'ms': 'Majuro',
#     'sc': 'Majuro',
#     'be': 'Маджура',
#     'nl': 'Majuro',
#     'bs': 'Majuro',
#     'eu': 'Majuro',
#     'ro': 'Majuro',
#     'br': 'Majuro',
#     'feature_name': 'Majuro',
#     'ca': 'Majuro',
#     'bo': 'མ་ཇུ་རོ།',
#     'tg': 'Маҷуро',
#     'ba': 'Маджуро',
#     'oc': 'Majuro',
#     'el': 'Ματζούρο',
#     'pa': 'ਮਾਜੁਰੋ',
#     'ky': 'Мажeро',
#     'cs': 'Majuro',
#     'et': 'Majuro atoll',
#     'mr': 'माजुरो',
#     'sw': 'Majuro',
#     'fa': 'ماجورو',
#     'sv': 'Majuro',
#     'de': 'Majuro',
#     'os': 'Маджуро',
#     'ta': 'மாசூரோ',
#     'hi': 'माजुरो',
#     'ascii': 'Majuro',
#     'lv': 'Madžuro',
#     'pl': 'Majuro',
#     'th': 'มาจูโร',
#     'mh': 'Mājro',
#     'zh': '马朱罗',
#     'sl': 'Majuro',
#     'kk': 'Маджуро',
#     'uz': 'Majuro',
#     'sk': 'Dalap-Uliga-Darrit',
#     'ja': 'マジュロ',
#     'nn': 'Majuro',
#     'sr': 'Маџуро',
#     'rw': 'Majuro',
#     'bn': 'মাজুরো',
#     'hy': 'Մաջուրո',
#     'fi': 'Majuro',
#     'sn': 'Majuro',
#     'ps': 'ماجورو',
#     'he': "מג'ורו",
#     'gn': 'Majuro'},
#    'lat': 7.0909924,
#    'lon': 171.3816354,
#    'country': 'MH'}],
#  [{'name': 'Mei County',
#    'local_names': {'vi': 'My', 'en': 'Mei County', 'zh': '眉县'},
#    'lat': 34.130278,
#    'lon': 107.835,
#    'country': 'CN',
#    'state': 'Shaanxi'}],
#  [{'name': 'Malé',
#    'local_names': {'dv': 'މާލެ',
#     'ta': 'மாலே',
#     'nl': 'Malé',
#     'zh': '马累',
#     'hu': 'Malé',
#     'hi': 'माले',
#     'mr': 'मले',
#     'oc': 'Male',
#     'pl': 'Male',
#     'sv': 'Malé',
#     'fr': 'Malé',
#     'ml': 'മാലി',
#     'cs': 'Male',
#     'de': 'Malé',
#     'et': 'Male',
#     'en': 'Malé'},
#    'lat': 4.1779879,
#    'lon': 73.5107387,
#    'country': 'MV'}],
#  [{'name': 'Melilla',
#    'local_names': {'cs': 'Melilla',
#     'lv': 'Melilja',
#     'kk': 'Мелилья',
#     'ja': 'メリリャ',
#     'uk': 'Мелілья',
#     'ta': 'மெலில்லா',
#     'th': 'เมลียา',
#     'be': 'Мелілья',
#     'bg': 'Мелиля',
#     'ar': 'مليلية',
#     'ko': '멜리야',
#     'es': 'Melilla',
#     'os': 'Мелилья',
#     'sr': 'Мелиља',
#     'zh': '梅利利亚',
#     'ru': 'Мелилья',
#     'lt': 'Melilja',
#     'he': 'מלייה',
#     'zu': 'IMelilla',
#     'pl': 'Melilla',
#     'la': 'Rusadir',
#     'ka': 'მელილია',
#     'eo': 'Melilo',
#     'su': 'Mélilya',
#     'mk': 'Мелилја',
#     'el': 'Μελίγια',
#     'sk': 'Melilla',
#     'fa': 'ملیلیه',
#     'mr': 'मेलिया',
#     'en': 'Melilla',
#     'hy': 'Մելիլյա'},
#    'lat': 35.2918698,
#    'lon': -2.9409026,
#    'country': 'ES',
#    'state': 'Melilla'}],
#  [{'name': 'Mont',
#    'lat': 46.6260356,
#    'lon': 3.8306675,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Aomar',
#    'local_names': {'fr': 'Aomar',
#     'ur': 'عمر',
#     'ar': 'عمر',
#     'en': 'Aomar',
#     'fa': 'عمر'},
#    'lat': 36.492393,
#    'lon': 3.7711939,
#    'country': 'DZ',
#    'state': 'Bouira'}],
#  [{'name': 'Moult',
#    'local_names': {'fr': 'Moult', 'ru': 'Муль', 'uk': 'Му'},
#    'lat': 49.115483,
#    'lon': -0.1657186,
#    'country': 'FR',
#    'state': 'Normandy'}],
#  [{'name': 'Mexico',
#    'local_names': {'ar': 'المكسيك', 'en': 'Mexico', 'es': 'México'},
#    'lat': 25.20193915,
#    'lon': 55.15419672678571,
#    'country': 'AE',
#    'state': 'Dubai'}],
#  [{'name': 'Monte-Carlo',
#    'local_names': {'et': 'Monte Carlo',
#     'fr': 'Monte-Carlo',
#     'mk': 'Монте Карло',
#     'da': 'Monte Carlo'},
#    'lat': 43.7402961,
#    'lon': 7.426559,
#    'country': 'MC'}],
#  [{'name': 'Amman',
#    'local_names': {'bn': 'আম্মান',
#     'it': 'Amman',
#     'en': 'Amman',
#     'uk': 'Амман',
#     'kk': 'Амман',
#     'da': 'Amman',
#     'yi': 'אמאן',
#     'hr': 'Amman',
#     'am': 'አማን',
#     'hi': 'अम्मान',
#     'sr': 'Аман',
#     'kn': 'ಅಮ್ಮಾನ್',
#     'mk': 'Аман',
#     'bg': 'Аман',
#     'zh': '安曼',
#     'cs': 'Ammán',
#     'ku': 'Amman',
#     'ur': 'عمان',
#     'tt': 'Амман',
#     'tr': 'Amman',
#     'pl': 'Amman',
#     'os': 'Амман',
#     'bo': 'ཨམ་མན།',
#     'hu': 'Ammán',
#     'fa': 'امان',
#     'mn': 'Амман',
#     'es': 'Amán',
#     'cv': 'Амман',
#     'sl': 'Aman',
#     'sk': 'Ammán',
#     'te': 'అమ్మాన్',
#     'gl': 'Amán - عمان',
#     'ka': 'ამანი',
#     'th': 'อัมมาน',
#     'ar': 'عمان',
#     'ja': 'アンマン',
#     'el': 'Αμμάν',
#     'de': 'Amman',
#     'ug': 'ئاممان',
#     'fi': 'Amman',
#     'oc': 'Amman',
#     'ko': '암만',
#     'no': 'Amman',
#     'pt': 'Amã',
#     'lv': 'Ammāna',
#     'ta': 'அம்மான்',
#     'nl': 'Amman',
#     'ru': 'Амман',
#     'fr': 'Amman',
#     'lt': 'Amanas',
#     'sv': 'Amman',
#     'eu': 'Amman',
#     'be': 'Аман',
#     'mr': 'अम्मान',
#     'tg': 'Аммон',
#     'is': 'Amman',
#     'ml': 'അമ്മാൻ',
#     'hy': 'Ամման',
#     'eo': 'Amano',
#     'et': 'Amman',
#     'bs': 'Aman',
#     'ks': 'عمان',
#     'ht': 'Amàn',
#     'he': 'רבת עמון',
#     'ascii': 'Amman',
#     'feature_name': 'Amman'},
#    'lat': 31.9515694,
#    'lon': 35.9239625,
#    'country': 'JO',
#    'state': 'Amman'}],
#  [{'name': 'Kiamika',
#    'lat': 46.4188742,
#    'lon': -75.3799932,
#    'country': 'CA',
#    'state': 'Quebec'}],
#  [{'name': 'Mau',
#    'local_names': {'mr': 'मऊ',
#     'pa': 'ਮਊ',
#     'he': 'מאו',
#     'ml': 'മൗ',
#     'ar': 'ماو',
#     'hi': 'मऊ',
#     'kn': 'ಮಾಹು'},
#    'lat': 25.9391096,
#    'lon': 83.5716125,
#    'country': 'IN',
#    'state': 'Uttar Pradesh'}],
#  [{'name': 'Metz',
#    'local_names': {'br': 'Metz',
#     'lt': 'Mecas',
#     'be': 'Мец',
#     'zh': '梅斯',
#     'uk': 'Мец',
#     'el': 'Μετς',
#     'ru': 'Мец',
#     'yi': 'מעץ',
#     'jv': 'Métz',
#     'la': 'Mettis',
#     'ta': 'மெட்சு',
#     'ka': 'მეცი',
#     'sr': 'Мец',
#     'fr': 'Metz',
#     'lv': 'Meca',
#     'ko': '메스',
#     'ja': 'メス',
#     'bg': 'Мец',
#     'mr': 'मेस',
#     'kk': 'Мец',
#     'bo': 'མེ་ཊི་ཛི།',
#     'hu': 'Metz',
#     'ur': 'میتز',
#     'fa': 'متز',
#     'lb': 'Metz',
#     'hy': 'Մեց',
#     'th': 'แม็ส',
#     'oc': 'Mètz',
#     'cs': 'Mety',
#     'ar': 'متز',
#     'he': 'מץ',
#     'mk': 'Мец',
#     'am': 'መትዝ'},
#    'lat': 49.1196964,
#    'lon': 6.1763552,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'NA',
#    'lat': -51.3184588,
#    'lon': -59.741689897506845,
#    'country': 'FK'}],
#  [{'name': 'National Park',
#    'lat': 39.865968,
#    'lon': -75.1796351,
#    'country': 'US',
#    'state': 'New Jersey'}],
#  [{'name': 'نعل کنان',
#    'lat': 31.7428456,
#    'lon': 50.1793258,
#    'country': 'IR',
#    'state': 'Khuzestan Province'}],
#  [{'name': '`Anaz',
#    'local_names': {'fr': '`Anaz',
#     'ascii': 'Aanaz, `Anaz',
#     'feature_name': 'Aanaz, `Anaz',
#     'ar': 'عنز',
#     'de': '`Anaz',
#     'en': '`Anaz'},
#    'lat': 34.7360048,
#    'lon': 36.3011029,
#    'country': 'SY',
#    'state': 'Homs Governorate'}],
#  [{'name': 'Ni',
#    'local_names': {'en': 'Ni', 'ja': 'ニ'},
#    'lat': 35.72047,
#    'lon': 140.6298436,
#    'country': 'JP'}],
#  [{'name': 'ng',
#    'lat': -3.3669467500000003,
#    'lon': 36.67738947024446,
#    'country': 'TZ',
#    'state': 'Arusha'}],
#  [{'name': 'Nou',
#    'local_names': {'ro': 'Nou',
#     'de': 'Neudorf bei Hermannstadt',
#     'ru': 'Но',
#     'hu': 'Szászújfalu',
#     'uk': 'Ноу'},
#    'lat': 45.8299398,
#    'lon': 24.2830582,
#    'country': 'RO'}],
#  [{'name': 'Omps',
#    'local_names': {'uk': 'Ом', 'fr': 'Omps', 'oc': 'Omps'},
#    'lat': 44.8779952,
#    'lon': 2.2761709,
#    'country': 'FR',
#    'state': 'Auvergne-Rhône-Alpes'}],
#  [{'name': 'Park',
#    'lat': 39.112507,
#    'lon': -100.358747,
#    'country': 'US',
#    'state': 'Kansas'}],
#  [{'name': 'Pay',
#    'local_names': {'en': 'Pay', 'hi': 'पाय'},
#    'lat': 23.1361652,
#    'lon': 68.9346579,
#    'country': 'IN',
#    'state': 'Gujarat'}],
#  [{'name': 'Golęcino-Gocław',
#    'local_names': {'de': 'Frauendorf-Gotzlow', 'pl': 'Golęcino-Gocław'},
#    'lat': 53.4711354,
#    'lon': 14.5976516,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Py',
#    'local_names': {'ca': 'Pi de Conflent', 'fr': 'Py'},
#    'lat': 42.49576,
#    'lon': 2.3506675,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Pey',
#    'local_names': {'uk': 'Пе', 'fr': 'Pey', 'oc': 'Pei'},
#    'lat': 43.6302615,
#    'lon': -1.2015629,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [],
#  [{'name': 'Plains',
#    'lat': 33.1892387,
#    'lon': -102.827274,
#    'country': 'US',
#    'state': 'Texas'}],
#  [{'name': 'Opatów',
#    'local_names': {'pl': 'Opatów',
#     'he': 'אפטא',
#     'ru': 'Опатув',
#     'uk': 'Опатув'},
#    'lat': 50.8017661,
#    'lon': 21.4238281,
#    'country': 'PL',
#    'state': 'Świętokrzyskie Voivodeship'}],
#  [{'name': 'Prague',
#    'local_names': {'id': 'Praha',
#     'be': 'Прага',
#     'mn': 'Прага',
#     'ka': 'პრაღა',
#     'os': 'Прагæ',
#     'my': 'ပရက်ဂ်မြို့',
#     'lv': 'Prāga',
#     'sh': 'Prag',
#     'fa': 'پراگ',
#     'ta': 'பிராகா',
#     'kw': 'Praha',
#     'is': 'Prag',
#     'ml': 'പ്രാഗ്',
#     'tg': 'Прага',
#     'hr': 'Prag',
#     'uz': 'Praga',
#     'gv': 'Praag',
#     'hy': 'Պրահա',
#     'mk': 'Прага',
#     'bn': 'প্রাগ',
#     'la': 'Praga',
#     'ie': 'Praha',
#     'tt': 'Прага',
#     'et': 'Praha',
#     'an': 'Praga',
#     'ga': 'Prág',
#     'sc': 'Praga',
#     'pl': 'Miasto Stołeczne Praga',
#     'gd': 'Pràg',
#     'af': 'Praag',
#     'sv': 'Prag',
#     'ug': 'پراگا',
#     'fo': 'Prag',
#     'bg': 'Прага',
#     'eo': 'Ĉefurba regiono Prago',
#     'kk': 'Прага',
#     'ee': 'Prague',
#     'bs': 'Prag',
#     'br': 'Praha',
#     'he': 'פראג',
#     'cy': 'Prag',
#     'li': 'Praag',
#     'it': 'Praga',
#     'qu': 'Praha',
#     'nl': 'Praag',
#     'na': 'Praha',
#     'ia': 'Praga',
#     'en': 'Prague',
#     'sl': 'Praga',
#     'th': 'ปราก',
#     'no': 'Praha',
#     'ar': 'براغ',
#     'cs': 'Hlavní město Praha',
#     'kn': 'ಪ್ರಾಗ',
#     'ku': 'Prag',
#     'ak': 'Prague',
#     'de': 'Hauptstadt Prag',
#     'oc': 'Praga',
#     'cv': 'Прага',
#     'fy': 'Praach',
#     'ru': 'Столица Прага',
#     'eu': 'Praga',
#     'mr': 'प्राग',
#     'es': 'Praga',
#     'hi': 'प्राग',
#     'kl': 'Praha',
#     'nn': 'Praha',
#     'vi': 'Praha',
#     'ms': 'Praha',
#     'jv': 'Praha',
#     'ky': 'Прага',
#     'tl': 'Praga',
#     'mt': 'Praga',
#     'lb': 'Prag',
#     'sw': 'Praha',
#     'ja': 'プラハ',
#     'cu': 'Прага',
#     'bo': 'པུ་ལ་ཁེ།',
#     'ur': 'پراگ',
#     'tr': 'Prag',
#     'mi': 'Prague',
#     'da': 'Prag',
#     'el': 'Πράγα',
#     'se': 'Praha',
#     'ca': 'Praga',
#     'co': 'Praga',
#     'hu': 'Prága főváros',
#     'sq': 'Praga',
#     'kv': 'Прага',
#     'uk': 'Прага',
#     'yi': 'פראג',
#     'yo': 'Prague',
#     'ro': 'Praga',
#     'zu': 'IPraha',
#     'sr': 'Праг',
#     'fi': 'Praha',
#     'io': 'Praha',
#     'ps': 'پراګ',
#     'fr': 'Prague',
#     'sk': 'Praha',
#     'ko': '프라하',
#     'az': 'Praqa',
#     'am': 'ፕራግ',
#     'gl': 'Praga',
#     'zh': '布拉格',
#     'pt': 'Praga',
#     'lt': 'Praha'},
#    'lat': 50.0874654,
#    'lon': 14.4212535,
#    'country': 'CZ',
#    'state': 'Prague'}],
#  [{'name': 'Doha',
#    'local_names': {'kl': 'Doha',
#     'ar': 'الدوحة',
#     'pa': 'ਦੋਹਾ',
#     'am': 'ዶሃ',
#     'yi': 'דאכא',
#     'ka': 'დოჰა',
#     'da': 'Doha',
#     'de': 'Doha',
#     'jv': 'Doha',
#     'sq': 'Doha',
#     'ps': 'دوحه',
#     'ru': 'Доха',
#     'eu': 'Doha',
#     'nn': 'Doha',
#     'ne': 'दोहा',
#     'sl': 'Doha',
#     'ta': 'தோகா',
#     'gn': 'Doha',
#     'bs': 'Doha',
#     'no': 'Doha',
#     'ga': 'Doha',
#     'et': 'Doha',
#     'af': 'Doha',
#     'gd': 'Doha',
#     'fr': 'Doha',
#     'pl': 'Doha',
#     'ku': 'Doha',
#     'zh': '多哈',
#     'ml': 'ദോഹ',
#     'gl': 'Doha',
#     'ug': 'دوھا',
#     'tl': 'Doha',
#     'uk': 'Доха',
#     'os': 'Дохæ',
#     'gr': 'Δοχή',
#     'tt': 'Doha',
#     'be': 'Доха',
#     'pt': 'Doha',
#     'mg': 'Doha',
#     'lv': 'Doha',
#     'fi': 'Doha',
#     'km': 'ដូហា',
#     'lt': 'Doha',
#     'id': 'Doha',
#     'so': 'Dooxa',
#     'hr': 'Doha',
#     'cy': 'Doha',
#     'br': 'Doha',
#     'is': 'Doha',
#     'sv': 'Doha',
#     'el': 'Ντόχα',
#     'ia': 'Doha',
#     'es': 'Doha',
#     'kk': 'Доһа',
#     'mr': 'दोहा',
#     'ce': 'Духьа',
#     'tg': 'Дуҳа',
#     'sk': 'Dauha',
#     'vo': 'Däuha',
#     'ca': 'Doha',
#     'fy': 'Doha',
#     'sd': 'دوحہ',
#     'kn': 'ದೊಹಾ',
#     'eo': 'Doho',
#     'mk': 'Доха',
#     'th': 'โดฮา',
#     'ur': 'دوحہ',
#     'sh': 'Doha',
#     'gu': 'દોહા',
#     'en': 'Doha',
#     'la': 'Doha',
#     'sc': 'Doha',
#     'bg': 'Доха',
#     'ja': 'ドーハ',
#     'bn': 'দোহা',
#     'vi': 'Doha',
#     'sw': 'Doha',
#     'it': 'Doha',
#     'tk': 'Doha',
#     'ht': 'Doha',
#     'ro': 'Doha',
#     'rw': 'Doha',
#     'ms': 'Doha',
#     'hy': 'Դոհա',
#     'yo': 'Doha',
#     'ba': 'Доһа',
#     'hu': 'Doha',
#     'uz': 'Doʻha',
#     'ky': 'Доха',
#     'hi': 'दोहा, क़तर',
#     'az': 'Doha',
#     'ko': '도하',
#     'io': 'Doha',
#     'mn': 'Доха',
#     'lb': 'Doha',
#     'my': 'ဒိုဟာမြို့',
#     'cs': 'Dauhá',
#     'oc': 'Doha',
#     'an': 'Doha',
#     'tr': 'Doha',
#     'ha': 'Doha',
#     'nl': 'Doha',
#     'sn': 'Doha',
#     'ie': 'Doha',
#     'he': 'דוחה',
#     'fa': 'دوحه',
#     'bo': 'དྷོ་ཧ།',
#     'sr': 'Доха'},
#    'lat': 25.2856329,
#    'lon': 51.5264162,
#    'country': 'QA'}],
#  [{'name': 'Ro',
#    'lat': 44.9466518,
#    'lon': 11.7626169,
#    'country': 'IT',
#    'state': 'Emilia-Romagna'}],
#  [],
#  [{'name': 'Aachen',
#    'local_names': {'io': 'Aachen',
#     'ur': 'آخن',
#     'zh': '亚琛',
#     'fa': 'آخن',
#     'eu': 'Akisgran',
#     'ky': 'Ахен',
#     'lt': 'Achenas',
#     'en': 'Aachen',
#     'nn': 'Aachen',
#     'uz': 'Axen',
#     'fy': 'Aken',
#     'ca': 'Aquisgrà',
#     'sv': 'Aachen',
#     'sr': 'Ахен',
#     'kk': 'Ахен',
#     'nl': 'Aken',
#     'uk': 'Аа́хен',
#     'ta': 'ஆஃகன்',
#     'ml': 'ആഹ്ഹൻ',
#     'cy': 'Aachen',
#     'sl': 'Aachen',
#     'nb': 'Aachen',
#     'bs': 'Aachen',
#     'hy': 'Աախեն',
#     'is': 'Aachen',
#     'tg': 'А́хен',
#     'ku': 'Aachen',
#     'am': 'አኽን',
#     'az': 'Aaxen',
#     'an': 'Aquisgrán',
#     'sh': 'Aachen',
#     'wa': 'Åxhe',
#     'de': 'Aachen',
#     'hi': 'आखन',
#     'tr': 'Aachen',
#     'pt': 'Aquisgrão',
#     'la': 'Aquisgranum',
#     'br': 'Aachen',
#     'ru': 'Ахен',
#     'af': 'Aken',
#     'et': 'Aachen',
#     'tl': 'Aachen',
#     'ms': 'Aachen',
#     'hr': 'Aachen',
#     'lb': 'Oochen',
#     'ps': 'آخن',
#     'es': 'Aquisgrán',
#     'hu': 'Aachen',
#     'no': 'Aachen',
#     'th': 'อาเคิน',
#     'sk': 'Aachen',
#     'el': 'Άαχεν',
#     'li': 'Aoke',
#     'da': 'Aachen',
#     'cs': 'Cáchy',
#     'tt': 'Ахен',
#     'lv': 'Āhene',
#     'mk': 'Ахен',
#     'ce': 'Ахен',
#     'ko': '아헨',
#     'ar': 'آخن',
#     'fi': 'Aachen',
#     'gd': 'Aachen',
#     'id': 'Aachen',
#     'sw': 'Aachen',
#     'mn': 'Аахен',
#     'vo': 'Aachen',
#     'co': 'Aquisgrana',
#     'pl': 'Akwizgran',
#     'fr': 'Aix-la-Chapelle',
#     'ja': 'アーヘン',
#     'ga': 'Aachen',
#     'oc': 'Aquisgran',
#     'mr': 'आखन',
#     'ka': 'აახენი',
#     'bg': 'А̀хен',
#     'it': 'Aquisgrana',
#     'eo': 'Aachen',
#     'ie': 'Aachen',
#     'qu': 'Aachen',
#     'ia': 'Aquisgrano',
#     'he': 'אַאכֶן',
#     'vi': 'Aachen',
#     'gl': 'Aquisgrán',
#     'be': 'А́хен',
#     'ro': 'Aachen'},
#    'lat': 50.776351,
#    'lon': 6.083862,
#    'country': 'DE',
#    'state': 'North Rhine-Westphalia'}],
#  [{'name': 'Lac',
#    'local_names': {'eu': 'Lac',
#     'id': 'Region Lac',
#     'fr': 'Lac',
#     'no': 'Lac',
#     'ko': '라크주',
#     'nl': 'Lac',
#     'lt': 'Ežero regionas',
#     'hi': 'लाक',
#     'ur': 'لاک علاقہ',
#     'es': 'Lac',
#     'fa': 'بخش بحیره',
#     'ja': 'ラク州',
#     'fi': 'Lac',
#     'tr': 'Lac',
#     'da': 'Lac',
#     'ro': 'Regiunea Lac',
#     'en': 'Lac',
#     'bg': 'Лак',
#     'et': 'Laci piirkond',
#     'ru': 'Лак',
#     'de': 'Region See',
#     'ar': 'البحيرة',
#     'ka': 'ლაკის რეგიონი',
#     'pl': 'Lac',
#     'uk': 'Лак',
#     'zh': '湖區',
#     'it': 'Regione del Lago'},
#    'lat': 13.5820827,
#    'lon': 14.3788329,
#    'country': 'TD'}],
#  [{'name': 'Chancelade',
#    'local_names': {'fr': 'Chancelade', 'oc': 'Chancelada'},
#    'lat': 45.2063889,
#    'lon': 0.6661111,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'Auch',
#    'local_names': {'oc': 'Aush',
#     'uk': 'Ош',
#     'ca': 'Aush',
#     'ru': 'Ош',
#     'la': 'Augusta-Auscorum',
#     'fr': 'Auch',
#     'he': 'אוש',
#     'zh': '欧什',
#     'an': 'Aush',
#     'br': 'Aush',
#     'sr': 'Ош',
#     'ja': 'オーシュ',
#     'bg': 'Ош'},
#    'lat': 43.6463558,
#    'lon': 0.5850507,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Street',
#    'lat': 51.1267494,
#    'lon': -2.7397217,
#    'country': 'GB',
#    'state': 'England'}],
#  [{'name': 'Shah Alam',
#    'local_names': {'zh': '莎亚南',
#     'ko': '샤알람',
#     'ms': 'Shah Alam',
#     'ar': 'شاه عالم',
#     'my': 'ရှားအလမ်မြို့',
#     'en': 'Shah Alam',
#     'ja': 'シャー・アラム',
#     'th': 'ชะฮ์อาลัม',
#     'ru': 'Шах-Алам',
#     'ta': 'ஷா ஆலாம்'},
#    'lat': 3.0733644,
#    'lon': 101.5195149,
#    'country': 'MY',
#    'state': 'Selangor'}],
#  [{'name': 'Essen',
#    'local_names': {'de': 'Essen',
#     'lv': 'Esene',
#     'fa': 'اسن',
#     'ru': 'Эссен',
#     'la': 'Assindia',
#     'he': 'אסן',
#     'ur': 'ایسن',
#     'hu': 'Essen',
#     'ja': 'エッセン',
#     'li': 'Esse',
#     'sr': 'Есен',
#     'lt': 'Esenas',
#     'zh': '埃森',
#     'ar': 'إسن',
#     'el': 'Έσση',
#     'mr': 'एसेन',
#     'cs': 'Essen',
#     'kk': 'Эссен',
#     'ka': 'ესენი',
#     'uk': 'Ессен',
#     'th': 'เอสเซิน',
#     'ug': 'Ésén',
#     'ko': '에센',
#     'bg': 'Есен'},
#    'lat': 51.4582235,
#    'lon': 7.0158171,
#    'country': 'DE',
#    'state': 'North Rhine-Westphalia'}],
#  [{'name': 'Seoul',
#    'local_names': {'mr': 'सोल',
#     'he': 'סיאול',
#     'vi': 'Seoul',
#     'is': 'Seúl',
#     'bh': 'सियोल',
#     'ml': 'സോൾ',
#     'hi': 'सियोल',
#     'hr': 'Seul',
#     'mk': 'Сеул',
#     'eo': 'Seulo',
#     'th': 'โซล',
#     'tg': 'Сеул',
#     'ba': 'Сеул',
#     'tk': 'Seul',
#     'km': 'សេអ៊ូល',
#     'hy': 'Սեուլ',
#     'kk': 'Сеул',
#     'cv': 'Сеул',
#     'mn': 'Сөүл',
#     'qu': 'Siul',
#     'ku': 'Sêûl',
#     'bs': 'Seul',
#     'fr': 'Séoul',
#     'az': 'Seul',
#     'bn': 'সিওল',
#     'ca': 'Seül',
#     'ko': '서울',
#     'am': 'ሶል',
#     'bg': 'Сеул',
#     'sv': 'Seoul',
#     'kn': 'ಸೌಲ್',
#     'nl': 'Seoel',
#     'my': 'ဆိုးလ်မြို့',
#     'sr': 'Сеул',
#     'oc': 'Seol',
#     'sk': 'Soul',
#     'yi': 'סעאל',
#     'fi': 'Soul',
#     'tr': 'Seul',
#     'eu': 'Seul',
#     'it': 'Seul',
#     'el': 'Σεούλ',
#     'de': 'Seoul',
#     'zh': '首尔市 / 首爾',
#     'an': 'Seúl',
#     'en': 'Seoul',
#     'af': 'Seoel',
#     'cs': 'Soul',
#     'pt': 'Seul',
#     'ja': 'ソウル',
#     'ur': 'سؤل',
#     'uz': 'Seul',
#     'fa': 'سئول',
#     'ky': 'Сеул',
#     'ro': 'Seul',
#     'lv': 'Seula',
#     'ta': 'சியோல்',
#     'ka': 'სეული',
#     'ru': 'Сеул',
#     'sl': 'Seul',
#     'lt': 'Seulas',
#     'os': 'Сеул',
#     'vo': 'Söul',
#     'uk': 'Сеул',
#     'hu': 'Szöul',
#     'la': 'Seulum',
#     'et': 'Sŏul',
#     'es': 'Seúl',
#     'bo': 'སེ་ཨུལ།',
#     'be': 'Сеул',
#     'ar': 'سول',
#     'gl': 'Seúl',
#     'pl': 'Seul'},
#    'lat': 37.5666791,
#    'lon': 126.9782914,
#    'country': 'KR'}],
#  [{'name': 'Sandgrube',
#    'lat': 48.8658607,
#    'lon': 12.9046953,
#    'country': 'DE',
#    'state': 'Bavaria'}],
#  [{'name': 'SK',
#    'lat': 3.02872295,
#    'lon': 101.69964770488389,
#    'country': 'MY',
#    'state': 'Selangor'}],
#  [{'name': 'Si',
#    'local_names': {'th': 'สิ', 'en': 'Si'},
#    'lat': 14.6248479,
#    'lon': 104.4510392,
#    'country': 'TH',
#    'state': 'Si Sa Ket Province'}],
#  [{'name': 'Tuzla',
#    'local_names': {'sr': 'Тузла',
#     'hr': 'Tuzla',
#     'en': 'Tuzla',
#     'ru': 'Тузла',
#     'hu': 'Tuzla',
#     'tr': 'Tuzla',
#     'bs': 'Tuzla',
#     'de': 'Tuzla',
#     'es': 'Tuzla',
#     'ar': 'توزلا',
#     'fr': 'Tuzla',
#     'sq': 'Tuzlla'},
#    'lat': 44.5391105,
#    'lon': 18.675193,
#    'country': 'BA',
#    'state': 'Federation of Bosnia and Herzegovina'}],
#  [{'name': 'Arkońskie-Niemierzyn',
#    'local_names': {'pl': 'Arkońskie-Niemierzyn'},
#    'lat': 53.4553042,
#    'lon': 14.5298919,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Hèches',
#    'local_names': {'uk': 'Еш', 'fr': 'Hèches', 'oc': 'Hèishas'},
#    'lat': 43.0174862,
#    'lon': 0.3737441,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Lak',
#    'local_names': {'fa': 'لک', 'en': 'Lak'},
#    'lat': 37.6981704,
#    'lon': 45.0223151,
#    'country': 'IR',
#    'state': 'West Azerbaijan Province'}],
#  [{'name': 'Isdhoo',
#    'local_names': {'dv': 'އިސްދޫ', 'en': 'Isdhoo'},
#    'lat': 2.1189323,
#    'lon': 73.56443470496887,
#    'country': 'MV',
#    'state': 'Haddhunmathi'}],
#  [{'name': 'Steyr',
#    'local_names': {'de': 'Steyr', 'ru': 'Штайр'},
#    'lat': 48.0390046,
#    'lon': 14.4191276,
#    'country': 'AT',
#    'state': 'Upper Austria'}],
#  [{'name': 'Cheux',
#    'local_names': {'uk': 'Ше', 'fr': 'Cheux', 'ru': 'Шё'},
#    'lat': 49.1660575,
#    'lon': -0.5243876,
#    'country': 'FR',
#    'state': 'Normandy'}],
#  [{'name': 'Chandigarh',
#    'local_names': {'es': 'Chandigarh',
#     'fr': 'Chandigarh',
#     'hi': 'चण्डीगढ़',
#     'zh': '昌迪加尔中央直辖区',
#     'ru': 'Чандигарх',
#     'ta': 'சண்டிகர்',
#     'ar': 'شانديغار',
#     'cs': 'Čandígarh',
#     'de': 'Chandigarh',
#     'he': "צ'אנדיגאר",
#     'kn': 'ಚಂಡೀಗಡ',
#     'ml': 'ചണ്ഡീഗഢ്',
#     'te': 'చండీగఢ్',
#     'ja': 'チャンディーガル',
#     'ur': 'چندی گڑھ',
#     'eo': 'Ĉandigaro',
#     'pa': 'ਚੰਡੀਗੜ੍ਹ',
#     'ku': 'Çandîgar',
#     'en': 'Chandigarh',
#     'ko': '찬디가르',
#     'uk': 'Чандігарх'},
#    'lat': 30.7334421,
#    'lon': 76.7797143,
#    'country': 'IN'}],
#  [{'name': 'Dushanbe',
#    'local_names': {'gl': 'Dushanbe',
#     'et': 'Dušanbe',
#     'br': 'Douchanbe',
#     'de': 'Duschanbe',
#     'be': 'Душанбэ',
#     'sv': 'Dusjanbe',
#     'ro': 'Dușanbe',
#     'tg': 'Душанбе',
#     'he': 'דושנבה',
#     'ky': 'Душанбе',
#     'ur': 'دوشنبہ',
#     'eu': 'Dushanbe',
#     'ko': '두샨베',
#     'am': 'ዱሻንቤ',
#     'ug': 'Düshenbe',
#     'ca': 'Duixanbe',
#     'hr': 'Dušanbe',
#     'tr': 'Duşanbe',
#     'kn': 'ದುಶಾಂಬೆ',
#     'kk': 'Душанбе',
#     'da': 'Dusjanbe',
#     'th': 'ดูชานเบ',
#     'ka': 'დუშანბე',
#     'mk': 'Душанбе',
#     'lt': 'Dušanbė',
#     'hy': 'Դուշանբե',
#     'sq': 'Dushanbe',
#     'af': 'Doesjanbe',
#     'hi': 'दुशान्बे',
#     'cy': 'Dushanbe',
#     'ar': 'دوشنبه',
#     'ascii': 'Dushanbe',
#     'yo': 'Dushanbe',
#     'sk': 'Dušanbe',
#     'ht': 'Douchanbe',
#     'io': 'Dushanbe',
#     'fy': 'Doesjanbe',
#     'feature_name': 'Dushanbe',
#     'fa': 'دوشنبه',
#     'oc': 'Doshambe',
#     'pt': 'Duchambe',
#     'ku': 'Duşenbe',
#     'yi': 'דושאנבע',
#     'id': 'Dushanbe',
#     'ml': 'ദുഷാൻബെ',
#     'es': 'Dusambé',
#     'lv': 'Dušanbe',
#     'el': 'Ντουσαμπέ',
#     'ie': 'Dushanbe',
#     'uz': 'Dushanbe',
#     'gd': 'Dushanbe',
#     'en': 'Dushanbe',
#     'bg': 'Душанбе',
#     'hu': 'Dusanbe',
#     'tt': 'Дүшәнбе',
#     'az': 'Düşənbə',
#     'os': 'Душанбе',
#     'no': 'Dusjanbe',
#     'mn': 'Душанбе',
#     'sw': 'Dushanbe',
#     'zh': '杜尚别',
#     'sh': 'Dušanbe',
#     'kv': 'Душанбе',
#     'vi': 'Dushanbe',
#     'bs': 'Dušanbe',
#     'ru': 'Душанбе',
#     'ja': 'ドゥシャンベ',
#     'nn': 'Dusjanbe',
#     'sl': 'Dušanbej',
#     'bo': 'དུ་ཤང་པེ།',
#     'ga': 'Dushanbe',
#     'mr': 'दुशांबे',
#     'is': 'Dúshanbe',
#     'ta': 'துசான்பே',
#     'ps': 'دوشنبه',
#     'cs': 'Dušanbe',
#     'eo': 'Duŝanbeo',
#     'fr': 'Douchanbé',
#     'tl': 'Dushanbe',
#     'nl': 'Doesjanbe',
#     'uk': 'Душанбе',
#     'sr': 'Душанбе',
#     'fi': 'Dušanbe',
#     'pl': 'Duszanbe',
#     'bn': 'দুশান্\u200cবে',
#     'it': 'Dušanbe'},
#    'lat': 38.5762709,
#    'lon': 68.7863573,
#    'country': 'TJ'}],
#  [{'name': 'Tienhaara',
#    'local_names': {'en': 'Tienhaara',
#     'fi': 'Tienhaara',
#     'ru': 'Калинино',
#     'ascii': 'Tienhaara',
#     'feature_name': 'Tienhaara'},
#    'lat': 60.7547446,
#    'lon': 28.6486315,
#    'country': 'RU',
#    'state': 'Leningrad oblast'}],
#  [{'name': 'TT',
#    'lat': 18.3449742,
#    'lon': 97.0033054204086,
#    'country': 'MM',
#    'state': 'Bago Region'}],
#  [{'name': 'Athens',
#    'local_names': {'yi': 'אטען',
#     'ko': '아테네',
#     'hy': 'Աթենք',
#     'mn': 'Афин',
#     'ml': 'ഏതൻസ്\u200c',
#     'hu': 'Athén',
#     'tw': 'Athens',
#     'ca': 'Atenes',
#     'ug': 'ئافېنا',
#     'tl': 'Atenas',
#     'be': 'Афіны',
#     'ht': 'Atèn',
#     'an': 'Atenas',
#     'la': 'Athenae',
#     'cs': 'Athény',
#     'jv': 'Aténa',
#     'uk': 'Афіни',
#     'vi': 'Athena',
#     'vo': 'Atina',
#     'ba': 'Афина',
#     'co': 'Atene',
#     'uz': 'Afina',
#     'oc': 'Atenas',
#     'eu': 'Atenas',
#     'de': 'Athen',
#     'eo': 'Ateno',
#     'ta': 'ஏதென்ஸ்',
#     'ka': 'ათენი',
#     'el': 'Αθήνα',
#     'nn': 'Aten',
#     'bg': 'Атина',
#     'feature_name': 'Athina',
#     'bn': 'অ্যাথেন্স',
#     'ascii': 'Athina',
#     'no': 'Aten',
#     'zh': '雅典',
#     'lb': 'Athen',
#     'kv': 'Афинъяс',
#     'se': 'Athena',
#     'os': 'Афинæтæ',
#     'kn': 'ಅಥೆನ್ಸ್',
#     'et': 'Ateena',
#     'ro': 'Atena',
#     'kw': 'Athína',
#     'cv': 'Афин',
#     'ms': 'Athens',
#     'gd': 'An Àithne',
#     'sl': 'Atene',
#     'mr': 'अथेन्स',
#     'tt': 'Афиннар',
#     'pt': 'Atenas',
#     'li': 'Athene',
#     'cy': 'Athen',
#     'qu': 'Athina',
#     'az': 'Afina',
#     'lv': 'Atēnas',
#     'cu': 'Аѳинꙑ',
#     'ur': 'ایتھنز',
#     'wa': 'Atene',
#     'af': 'Athene',
#     'fi': 'Ateena',
#     'ln': 'Atenis',
#     'sv': 'Aten',
#     'bs': 'Atina',
#     'fa': 'آتن',
#     'nl': 'Athene',
#     'id': 'Athena',
#     'ie': 'Athina',
#     'tr': 'Atina',
#     'pl': 'Ateny',
#     'mt': 'Ateni',
#     'sr': 'Атина',
#     'mk': 'Атина',
#     'io': 'Athina',
#     'my': 'အေသင်မြို့',
#     'am': 'አቴና',
#     'gl': 'Atenas',
#     'ar': 'أثينا',
#     'br': 'Aten',
#     'hi': 'एथेंस',
#     'zu': 'I-Athene',
#     'sw': 'Athens',
#     'es': 'Atenas',
#     'sq': 'Athina',
#     'ku': 'Atîna',
#     'bo': 'ཨ་ཐེན།',
#     'kk': 'Афина',
#     'ga': 'An Aithin',
#     'yo': 'Áténì',
#     'lt': 'Atėnai',
#     'gn': 'Atena',
#     'ja': 'アテネ',
#     'en': 'Athens',
#     'sk': 'Atény',
#     'ia': 'Athenas',
#     'th': 'เอเธนส์',
#     'ru': 'Афины',
#     'te': 'ఏథెన్స్',
#     'gv': 'Yn Atheen',
#     'sh': 'Atena',
#     'is': 'Aþena',
#     'wo': 'Aten',
#     'fr': 'Athènes',
#     'it': 'Atene',
#     'hr': 'Atena',
#     'fy': 'Atene',
#     'sc': 'Atene',
#     'he': 'אתונה',
#     'mi': 'Ātene',
#     'tk': 'Afiny'},
#    'lat': 37.9839412,
#    'lon': 23.7283052,
#    'country': 'GR',
#    'state': 'Attica'}],
#  [{'name': 'Torre', 'lat': 39.9634843, 'lon': -6.9406539, 'country': 'PT'}],
#  [{'name': 'Ua',
#    'lat': -8.8613303,
#    'lon': 121.2037997,
#    'country': 'ID',
#    'state': 'East Nusa Tenggara'}],
#  [{'name': 'Ae',
#    'lat': -0.6858283,
#    'lon': -48.04675,
#    'country': 'BR',
#    'state': 'Pará'}],
#  [{'name': 'Geva',
#    'local_names': {'en': 'Geva', 'fr': 'Geva', 'he': 'גבע'},
#    'lat': 32.5663362,
#    'lon': 35.3715486,
#    'country': 'IL',
#    'state': 'North District'}],
#  [{'name': 'Us',
#    'lat': 49.1009451,
#    'lon': 1.9672466,
#    'country': 'FR',
#    'state': 'Ile-de-France'}],
#  [{'name': 'Wei County',
#    'local_names': {'fr': 'Wei', 'en': 'Wei County', 'zh': '威县', 'vi': 'Uy'},
#    'lat': 36.9820674,
#    'lon': 115.2666089,
#    'country': 'CN',
#    'state': 'Hebei'}],
#  [{'name': 'Uz',
#    'local_names': {'oc': 'Us', 'uk': 'Юз', 'ca': 'Us', 'fr': 'Uz'},
#    'lat': 42.9663688,
#    'lon': -0.0852324,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Ye County',
#    'local_names': {'zh': '叶县', 'vi': 'Diệp', 'en': 'Ye County'},
#    'lat': 33.54912,
#    'lon': 113.361272,
#    'country': 'CN',
#    'state': 'Henan'}],
#  [{'name': '`Azm',
#    'local_names': {'feature_name': '‘Az̧m',
#     'ar': 'عظم',
#     'en': '`Azm',
#     'ascii': '‘Az̧m'},
#    'lat': 14.893993,
#    'lon': 43.749254,
#    'country': 'YE',
#    'state': "Sana'a Governorate"}],
#  [{'name': 'زو',
#    'lat': 37.735917,
#    'lon': 57.77137,
#    'country': 'IR',
#    'state': 'North Khorasan Province'}]]

# %%
#Loading the co-ordinate data into lists
for r in response_api:
    if len(r)>=1:
        latitude.append(r[0]['lat'])
        longitude.append(r[0]['lon'])
    else:
        latitude.append('')
        longitude.append((''))

# %%
#Creating new dataframe with country codes, latitude and longitude
country_info_df=pd.DataFrame({'country':countries_names, 'Lat':latitude,'Long':longitude})

# %%
country_info_df.head()
# Out:
#        country        Lat        Long
# 0  afghanistan  54.235921   -4.514767
# 1      albania  36.717202   59.666131
# 2      algeria  36.392117 -107.834908
# 3      andorra  47.292376   23.020988
# 4       angola  34.626275  135.605845
