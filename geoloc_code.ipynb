# %% [markdown]
# # Project 3 - Books

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import pycountry
pd.options.display.max_colwidth = 200

# Import the API key
from config import api_key

# %%
#Creating dataframes from csv files to read the data
books_df = pd.read_csv('./Resources/books.csv')
users_df = pd.read_csv('./Resources/users.csv')
ratings_df = pd.read_csv('./Resources/ratings.csv')

# %%
books_df.head()
# Out:
#         ISBN           Book-Title         Book-Author  Year-Of-Publication  \
# 0  195153448  Classical Mythology  Mark P. O. Morford                 2002
# 1        133        single Rating             34f5tgd                 1444
# 2        123           No Ratings               dfgdg                 1245
# 3        144      several ratings               dsfdg                  234
# 4        234          huge rating              dffrrr                 3444
#
#            Publisher
# 0  Oxford University
# 1          dfgdrgdrh
# 2               dfgg
# 3                dfg
# 4                NaN

# %%
users_df.head()
# Out:
#    User-ID Location  Age
# 0        1      USA   12
# 1        2   Mexico   34
# 2        3   Mexico   24
# 3        4   France   34
# 4        5   France   56

# %%
ratings_df.head()
# Out:
#    User-ID       ISBN  Book-Rating
# 0        1  195153448            2
# 1        2        133            5
# 2        3        144            0
# 3        2        144            2
# 4        3        234           10

# %%
#Finding the size of each dataframe
print(books_df.shape)
print(users_df.shape)
print(ratings_df.shape)
# Out:
# (6, 5)
# (6, 3)
# (10, 3)

# %%
#Following code has steps to get co-ordinate information of the unique countries in the dataset

# %%
#Reading the cleanCountries csv file and adding it to countries dataframe
column_name=['Country']
countries_df = pd.read_csv("./Resources/cleanCountries.csv",header=None, names=column_name)
countries_df.head()
# Out:
#        Country
# 0  afghanistan
# 1      albania
# 2      algeria
# 3      andorra
# 4       angola

# %%
#Finding the unique countries 
countries_unique=countries_df['Country'].unique()

# %%
#Transforming the data into list
countries_data=countries_unique.tolist()

# %%
countries_data
# Out:
# ['afghanistan',
#  'albania',
#  'algeria',
#  'andorra',
#  'angola',
#  'antigua and barbuda',
#  'argentina',
#  'armenia',
#  'australia',
#  'austria',
#  'azerbaijan',
#  'bahamas',
#  'bahrain',
#  'bangladesh',
#  'barbados',
#  'belgium',
#  'belize',
#  'benin',
#  'bermuda',
#  'bhutan',
#  'bolivia',
#  'bosnia and herzegovina',
#  'botswana',
#  'brazil',
#  'brunei',
#  'bulgaria',
#  'burkina faso',
#  'burma',
#  'cameroon',
#  'canada',
#  'cape verde',
#  'chile',
#  'china',
#  'colombia',
#  'connecticut',
#  'costa rica',
#  'cote d`ivoire',
#  'Country',
#  'croatia',
#  'cuba',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'dominica',
#  'dominican republic',
#  'east africa',
#  'ecuador',
#  'egypt',
#  'england',
#  'equatorial geuinea',
#  'eritrea',
#  'estonia',
#  'ethiopia',
#  'faroe islands',
#  'fernando de la mora',
#  'fiji',
#  'finland',
#  'florida',
#  'france',
#  'gabon',
#  'gambia',
#  'georgia',
#  'germany',
#  'ghana',
#  'greece',
#  'grenada',
#  'guatemala',
#  'guinea-bissau',
#  'guyana',
#  'haiti',
#  'honduras',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iowa',
#  'iran',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'kyrgyzstan',
#  'laos',
#  'latvia',
#  'lebanon',
#  'lesotho',
#  'lithuania',
#  'luxembourg',
#  'macedonia',
#  'madagascar',
#  'malaysia',
#  'maldives',
#  'mali',
#  'malta',
#  'mauritania',
#  'mauritius',
#  'mexico',
#  'micronesia',
#  'moldova',
#  'monaco',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'mozambique',
#  'namibia',
#  'nepal',
#  'netherlands',
#  'new zealand',
#  'nicaragua',
#  'nigeria',
#  'north korea',
#  'northern ireland',
#  'norway',
#  'oman',
#  'pakistan',
#  'panama',
#  'papua new guinea',
#  'paraguay',
#  'pennsylvania',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'puerto rico',
#  'qatar',
#  'romania',
#  'russia',
#  'rwanda',
#  'saint kitts and nevis',
#  'saint lucia',
#  'saint vincent and the grenadines',
#  'samoa',
#  'sao tome and principe',
#  'saudi arabia',
#  'scotland',
#  'senegal',
#  'serbia & montenegro',
#  'sierra leone',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'somalia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'sudan',
#  'suriname',
#  'sweden',
#  'switzerland',
#  'syria',
#  'taiwan',
#  'tajikistan',
#  'tanzania',
#  'thailand',
#  'the gambia',
#  'trinidad',
#  'trinidad and tobago',
#  'tunisia',
#  'turkey',
#  'ukraine',
#  'united arab emirates',
#  'united kingdom',
#  'united states',
#  'uruguay',
#  'uzbekistan',
#  'venezuela',
#  'vietnam',
#  'wales',
#  'yemen',
#  'zambia',
#  'zimbabwe']

# %%
 #!pip install pycountry

# %%
#Using openweathermap API to get latitude and longitude for each country code(obtained from pycountry)
url = "http://api.openweathermap.org/geo/1.0/direct?"
new_query_url = url + "appid=" + api_key + "&q="

# Set up empty lists to hold the API response
latitude = []
longitude = []
country_codes=[]
countries_names=[]
response_api=[]
for country in countries_data:
        # Convert country name to ISO country code
    try:
        country_code = pycountry.countries.get(name=country).alpha_2
         # Make API request
        country_codes.append(country_code)
        countries_names.append(country)
        print(country_code)
    except AttributeError:
        print(f"Could not find ISO code for {country}")
        continue
# Out:
# AF
# AL
# DZ
# AD
# AO
# AG
# AR
# AM
# AU
# AT
# AZ
# BS
# BH
# BD
# BB
# BE
# BZ
# BJ
# BM
# BT
# Could not find ISO code for bolivia
# BA
# BW
# BR
# Could not find ISO code for brunei
# BG
# BF
# Could not find ISO code for burma
# CM
# CA
# Could not find ISO code for cape verde
# CL
# CN
# CO
# Could not find ISO code for connecticut
# CR
# Could not find ISO code for cote d`ivoire
# Could not find ISO code for Country
# HR
# CU
# CY
# Could not find ISO code for czech republic
# DK
# DM
# DO
# Could not find ISO code for east africa
# EC
# EG
# Could not find ISO code for england
# Could not find ISO code for equatorial geuinea
# ER
# EE
# ET
# FO
# Could not find ISO code for fernando de la mora
# FJ
# FI
# Could not find ISO code for florida
# FR
# GA
# GM
# GE
# DE
# GH
# GR
# GD
# GT
# GW
# GY
# HT
# HN
# HK
# HU
# IS
# IN
# ID
# Could not find ISO code for iowa
# Could not find ISO code for iran
# IQ
# IE
# IL
# IT
# JM
# JP
# JO
# KZ
# KE
# KW
# KG
# Could not find ISO code for laos
# LV
# LB
# LS
# LT
# LU
# Could not find ISO code for macedonia
# MG
# MY
# MV
# ML
# MT
# MR
# MU
# MX
# Could not find ISO code for micronesia
# Could not find ISO code for moldova
# MC
# MN
# ME
# MA
# MZ
# NA
# NP
# NL
# NZ
# NI
# NG
# Could not find ISO code for north korea
# Could not find ISO code for northern ireland
# NO
# OM
# PK
# PA
# PG
# PY
# Could not find ISO code for pennsylvania
# PE
# PH
# PL
# PT
# PR
# QA
# RO
# Could not find ISO code for russia
# RW
# KN
# LC
# VC
# WS
# ST
# SA
# Could not find ISO code for scotland
# SN
# Could not find ISO code for serbia & montenegro
# SL
# SG
# SK
# SI
# SO
# ZA
# Could not find ISO code for south korea
# ES
# LK
# SD
# SR
# SE
# CH
# Could not find ISO code for syria
# Could not find ISO code for taiwan
# TJ
# Could not find ISO code for tanzania
# TH
# Could not find ISO code for the gambia
# Could not find ISO code for trinidad
# TT
# TN
# TR
# UA
# AE
# GB
# US
# UY
# UZ
# Could not find ISO code for venezuela
# Could not find ISO code for vietnam
# Could not find ISO code for wales
# YE
# ZM
# ZW

# %%
#Sending API request to get response
for c in country_codes:
    response = requests.get(f"{new_query_url}{c}").json()
    response_api.append(response)

# %%
response_api
# Out:
# [[{'name': 'Isle of Man',
#    'local_names': {'pt': 'Ilha de Man',
#     'jv': 'Pulo Man',
#     'ky': 'Мэн аралы',
#     'qu': "Man wat'a",
#     'en': 'Isle of Man',
#     'la': 'Monapia',
#     'pa': 'ਆਇਲ ਆਫ਼ ਮੈਨ',
#     'kk': 'Мэн',
#     'lt': 'Meno sala',
#     'ga': 'Manainn',
#     'et': 'Man',
#     'ka': 'კუნძული მენი',
#     'af': 'Man',
#     'sl': 'Otok Man',
#     'nl': 'Man',
#     'ml': 'ഐൽ ഒഫ് മാൻ',
#     'rw': 'Ikirwa cya Man',
#     'os': 'Мэны сакъадах',
#     'dv': 'އައިޒަލް އޮފް މޭން',
#     'sh': 'Ostrvo Man',
#     'ia': 'Insula de Man',
#     'fr': 'île de Man',
#     'az': 'Men adası',
#     'sw': 'Isle of Man',
#     'mi': 'Motu o Man',
#     'tr': 'Man Adası',
#     'ms': 'Pulau Man',
#     'el': 'νησί του Μαν',
#     'no': 'Man',
#     'ur': 'آئل آف مین',
#     'nn': 'Man',
#     'is': 'Mön',
#     'gd': 'Eilean Mhanainn',
#     'be': 'Востраў Мэн',
#     'zh': '马恩岛',
#     'hy': 'Մեն կղզի',
#     'it': 'Isola di Man',
#     'yo': 'Erékùṣù ilẹ̀ Man',
#     'fi': 'Mansaari',
#     'bn': 'আইল অফ ম্যান',
#     'sk': 'Ostrov Man',
#     'oc': 'Illa de Man',
#     'da': 'Isle of Man',
#     'se': 'Mannin',
#     'hr': 'Otok Man',
#     'mr': 'आईल ऑफ मान',
#     'sv': 'Isle of Man',
#     'bg': 'Ман',
#     'fa': 'جزیرهٔ مَن',
#     'sr': 'Острво Мен',
#     'gv': 'Mannin',
#     'ar': 'جزيرة مان',
#     'br': 'Manav',
#     'io': 'Man',
#     'ro': 'Insula Man',
#     'pl': 'Wyspa Man',
#     'cv': 'Мэн утравĕ',
#     'eu': 'Man',
#     'tt': 'Мэн утравы',
#     'ru': 'О́стров Мэн',
#     'hi': 'मनुष्य का टापू',
#     'ko': '맨 섬',
#     'cs': 'Ostrov Man',
#     'mk': 'Ман',
#     'fy': 'Man',
#     'ta': 'மாண் தீவு',
#     'id': 'Pulau Man',
#     'hu': 'Man',
#     'su': 'Pulo Man',
#     'gl': 'Illa de Man',
#     'tl': 'Pulo ng Man',
#     'eo': 'Manksinsulo',
#     'ca': 'Man',
#     'sc': 'ìsula de Man',
#     'an': 'Isla de Man',
#     'th': 'เกาะแมน',
#     'uk': 'Острів Мен',
#     'vi': 'Đảo Man',
#     'es': 'isla de Man',
#     'lv': 'Menas Sala',
#     'fo': 'Isle of Man',
#     'sq': 'Ishulli i Njeriut',
#     'cy': 'Ynys Manaw',
#     'kw': 'Manow',
#     'he': 'האי מאן',
#     'ha': 'Isle of Man',
#     'li': 'Eiland Man',
#     'bs': 'Ostrvo Man',
#     'de': 'Isle of Man',
#     'ja': 'マン島'},
#    'lat': 54.23592075,
#    'lon': -4.514766902315387,
#    'country': 'IM'}],
#  [{'name': 'Al',
#    'local_names': {'en': 'Al', 'fa': 'آل'},
#    'lat': 36.7172018,
#    'lon': 59.6661311,
#    'country': 'IR',
#    'state': 'Razavi Khorasan'}],
#  [{'name': 'Dzilth-Na-O-Dith-Hle',
#    'local_names': {'en': 'Dzilth-Na-O-Dith-Hle'},
#    'lat': 36.3921169,
#    'lon': -107.834908,
#    'country': 'US',
#    'state': 'New Mexico'}],
#  [{'name': 'Dioșod',
#    'local_names': {'hu': 'Diósad', 'ro': 'Dioșod', 'uk': 'Діошод'},
#    'lat': 47.2923759,
#    'lon': 23.0209883,
#    'country': 'RO'}],
#  [{'name': 'Yao',
#    'local_names': {'es': 'Yao',
#     'zh': '八尾市',
#     'ru': 'Яо',
#     'ko': '야오시',
#     'uk': 'Яо',
#     'pl': 'Yao',
#     'en': 'Yao',
#     'de': 'Yao',
#     'ja': '八尾市',
#     'ar': 'ياو، أوساكا',
#     'fr': 'Yao'},
#    'lat': 34.626275,
#    'lon': 135.605845,
#    'country': 'JP',
#    'state': 'Osaka Prefecture'}],
#  [{'name': 'Ág',
#    'local_names': {'hu': 'Ág', 'ru': 'Аг'},
#    'lat': 46.2959997,
#    'lon': 18.204151,
#    'country': 'HU'}],
#  [{'name': 'Junction City',
#    'lat': 33.021446100000006,
#    'lon': -92.72446250787544,
#    'country': 'US',
#    'state': 'Arkansas'}],
#  [{'name': 'Iam',
#    'local_names': {'uk': 'Ям', 'hu': 'Jám', 'ro': 'Iam'},
#    'lat': 45.0100943,
#    'lon': 21.4012452,
#    'country': 'RO'}],
#  [{'name': 'Lauw',
#    'local_names': {'de': 'Au', 'fr': 'Lauw'},
#    'lat': 47.7563917,
#    'lon': 7.0194428,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'Ath',
#    'local_names': {'wa': 'Ate', 'fr': 'Ath', 'la': 'Athum', 'nl': 'Aat'},
#    'lat': 50.6288684,
#    'lon': 3.785318027789082,
#    'country': 'BE',
#    'state': 'Hainaut'}],
#  [{'name': 'Iaz',
#    'local_names': {'uk': 'Яз', 'hu': 'Jász', 'ro': 'Iaz'},
#    'lat': 45.4650871,
#    'lon': 22.2338393,
#    'country': 'RO'}],
#  [{'name': 'Bs',
#    'local_names': {'en': 'Bs',
#     'mk': "Б'с",
#     'ascii': 'Bs',
#     'feature_name': 'Bs'},
#    'lat': 42.1877996,
#    'lon': 22.3876518,
#    'country': 'MK',
#    'state': 'Northeastern Region'}],
#  [{'name': 'Belo Horizonte',
#    'local_names': {'oc': 'Belo Horizonte',
#     'ru': 'Белу-Оризонти',
#     'uk': 'Белу-Оризонті',
#     'mk': 'Бело Хоризонте',
#     'bg': 'Бело Оризонти',
#     'mn': 'Бе́лу-Оризо́нти',
#     'en': 'Belo Horizonte',
#     'ta': 'பெலோ அரிசாஞ்ச்',
#     'be': 'Белу-Арызонты',
#     'lv': 'Belu Orizonti',
#     'ar': 'بيلو هوريزونتي',
#     'la': 'Pulchri Horizontis',
#     'th': 'เบโลโอรีซอนชี',
#     'ce': 'Белу-Оризонти',
#     'pa': 'ਬੈਲੋ ਓਰੀਜ਼ੋਂਤੀ',
#     'he': 'בלו הוריזונטה',
#     'ko': '벨루오리존치',
#     'de': 'Belo Horizonte',
#     'sr': 'Бело Оризонте',
#     'ka': 'ბელუ-ორიზონტი',
#     'es': 'Belo Horizonte',
#     'it': 'Belo Horizonte',
#     'mr': 'बेलो होरिझोन्ते',
#     'uz': 'Belu-Orizonti',
#     'pt': 'Belo Horizonte',
#     'kk': 'Белу-Оризонти',
#     'tg': 'Белу-Оризонти',
#     'fr': 'Belo Horizonte',
#     'el': 'Μπέλο Οριζόντε',
#     'sv': 'Belo Horizonte',
#     'eo': 'Bel-Horizonto',
#     'nl': 'Belo Horizonte',
#     'ja': 'ベロオリゾンテ',
#     'kn': 'ಬೇಲೊಹೋರಿಜೊಂತೆ',
#     'zh': '贝洛奥里藏特',
#     'os': 'Белу-Оризонти',
#     'fa': 'بلو هوریزونته',
#     'pl': 'Belo Horizonte',
#     'tr': 'Belo Horizonte',
#     'lt': 'Belo Horizontė',
#     'hy': 'Բելու Օրիզոնտի'},
#    'lat': -19.9227318,
#    'lon': -43.9450948,
#    'country': 'BR',
#    'state': 'Minas Gerais'}],
#  [{'name': 'Budi',
#    'local_names': {'en': 'Budi', 'th': 'บุดี'},
#    'lat': 6.5193503,
#    'lon': 101.3177069,
#    'country': 'TH',
#    'state': 'Yala Province'}],
#  [{'name': 'ББ', 'lat': 42.8677615, 'lon': 74.5874803, 'country': 'KG'}],
#  [{'name': 'Berlin',
#    'local_names': {'ja': 'ベルリン',
#     'pl': 'Berlin',
#     'lv': 'Berlīne',
#     'uz': 'Berlin',
#     'de': 'Berlin',
#     'mg': 'Berlin',
#     'ka': 'ბერლინი',
#     'cy': 'Berlin',
#     'da': 'Berlin',
#     'zu': 'Berlin',
#     'so': 'Berlin',
#     'ca': 'Berlín',
#     'ko': '베를린',
#     'gv': 'Berleen',
#     'fo': 'Berlin',
#     'ia': 'Berlin',
#     'fi': 'Berliini',
#     'fr': 'Berlin',
#     'mr': 'बर्लिन',
#     'ty': 'Berlin',
#     'zh': '柏林',
#     'el': 'Βερολίνο',
#     'se': 'Berlin',
#     'he': 'ברלין',
#     'iu': 'ᐱᕐᓖᓐ',
#     'is': 'Berlín',
#     'sk': 'Berlín',
#     'wo': 'Berlin',
#     'kk': 'Берлин',
#     'ht': 'Bèlen',
#     'nn': 'Berlin',
#     'lb': 'Berlin',
#     'na': 'Berlin',
#     'sc': 'Berlinu',
#     'co': 'Berlinu',
#     'vi': 'Berlin',
#     'gl': 'Berlín',
#     'nl': 'Berlijn',
#     'sr': 'Берлин',
#     'sv': 'Berlin',
#     'an': 'Berlín',
#     'jv': 'Berlin',
#     'es': 'Berlín',
#     'sq': 'Berlini',
#     'te': 'బెర్లిన్',
#     'ab': 'Берлин',
#     'hr': 'Berlin',
#     'cu': 'Берлинъ',
#     'en': 'Berlin',
#     'ku': 'Berlîn',
#     'cv': 'Берлин',
#     'sw': 'Berlin',
#     'mn': 'Берлин',
#     'yi': 'בערלין',
#     'ml': 'ബെര്\u200dലിന്',
#     'mi': 'Pearīni',
#     'af': 'Berlyn',
#     'sl': 'Berlin',
#     'eu': 'Berlin',
#     'kw': 'Berlin',
#     'tg': 'Берлин',
#     'hy': 'Բեռլին',
#     'ba': 'Берлин',
#     'be': 'Берлін',
#     'la': 'Berolinum',
#     'ky': 'Берлин',
#     'br': 'Berlin',
#     'tr': 'Berlin',
#     'bi': 'Berlin',
#     'os': 'Берлин',
#     'ug': 'Bérlin',
#     'ro': 'Berlin',
#     'az': 'Berlin',
#     'bg': 'Берлин',
#     'pt': 'Berlim',
#     'ln': 'Berlin',
#     'kv': 'Берлин',
#     'th': 'เบอร์ลิน',
#     'hi': 'बर्लिन',
#     'ur': 'برلن',
#     'tl': 'Berlin',
#     'uk': 'Берлін',
#     'my': 'ဘာလင်မြို့',
#     'tt': 'Берлин',
#     'hu': 'Berlin',
#     'mk': 'Берлин',
#     'lt': 'Berlynas',
#     'cs': 'Berlín',
#     'si': 'බර්ලිනය',
#     'eo': 'Berlino',
#     'qu': 'Berlin',
#     'bn': 'বার্লিন',
#     'bs': 'Berlin',
#     'kn': 'ಬೆರ್ಲಿನ್',
#     'ar': 'برلين',
#     'fy': 'Berlyn',
#     'io': 'Berlin',
#     'gd': 'Berlin',
#     'mt': 'Berlin',
#     'it': 'Berlino',
#     'ps': 'برلين',
#     'sh': 'Berlin',
#     'fa': 'برلین',
#     'gn': 'Berlin',
#     'su': 'Berliini',
#     'lg': 'Berlin',
#     'ie': 'Berlin',
#     'no': 'Berlin',
#     'li': 'Berlien',
#     'am': 'በርሊን',
#     'et': 'Berliin',
#     'ru': 'Берлин',
#     'id': 'Berlin',
#     'ta': 'பெர்லின்',
#     'oc': 'Berlin',
#     'rm': 'Berlin',
#     'ga': 'Beirlín',
#     'bo': 'པེ་ལིང་',
#     'ms': 'Berlin',
#     'yo': 'Berlin'},
#    'lat': 52.5170365,
#    'lon': 13.3888599,
#    'country': 'DE'}],
#  [{'name': 'Brzesko',
#    'local_names': {'pl': 'Brzesko',
#     'he': "בז'סקו",
#     'ru': 'Бжеско',
#     'uk': 'Бжеско'},
#    'lat': 49.9678396,
#    'lon': 20.6068496,
#    'country': 'PL',
#    'state': 'Lesser Poland Voivodeship'}],
#  [{'name': 'BJ Block',
#    'local_names': {'bn': 'বিজে ব্লক', 'en': 'BJ Block'},
#    'lat': 22.5902239,
#    'lon': 88.4267468,
#    'country': 'IN',
#    'state': 'West Bengal'}],
#  [{'name': 'Bam',
#    'local_names': {'ru': 'Бам',
#     'fa': 'شهر بم',
#     'ja': 'バム',
#     'ar': 'بم',
#     'hi': 'बम',
#     'es': 'Bam',
#     'fr': 'Bam',
#     'ko': '밤',
#     'ml': 'ബം',
#     'de': 'Bam',
#     'uk': 'Бам',
#     'en': 'Bam',
#     'et': 'Bam'},
#    'lat': 29.1059864,
#    'lon': 58.3565663,
#    'country': 'IR',
#    'state': 'Kerman Province'}],
#  [{'name': 'Bath',
#    'local_names': {'it': 'Bath',
#     'ka': 'ბათი',
#     'vo': 'Bath',
#     'sr': 'Бат',
#     'es': 'Bath',
#     'ru': 'Бат',
#     'fa': 'باث',
#     'bn': 'বাথ',
#     'hu': 'Bath',
#     'fi': 'Bath',
#     'fr': 'Bath',
#     'ro': 'Bath',
#     'af': 'Bath',
#     'is': 'Bath',
#     'nl': 'Bath',
#     'ar': 'باث',
#     'cy': 'Caerfaddon',
#     'sk': 'Bath',
#     'bg': 'Бат',
#     'lb': 'Bath',
#     'de': 'Bath',
#     'eo': 'Bath',
#     'qu': 'Bath',
#     'he': "באת'",
#     'pl': 'Bath',
#     'gl': 'Bath',
#     'sd': 'باٿ شھر',
#     'th': 'บาธ',
#     'sl': 'Bath',
#     'ko': '바스',
#     'id': 'Bath',
#     'hr': 'Bath',
#     'tt': 'Бас',
#     'io': 'Bath',
#     'tr': 'Bath',
#     'hy': 'Բաթ',
#     'sh': 'Bath',
#     'sc': 'Bath',
#     'sv': 'Bath',
#     'fy': 'Bath',
#     'el': 'Μπαθ',
#     'br': 'Bath',
#     'mk': 'Бат',
#     'lt': 'Batas',
#     'la': 'Aquae Sulis',
#     'cs': 'Bath',
#     'lv': 'Bāta',
#     'vi': 'Bath',
#     'et': 'Bath',
#     'en': 'Bath',
#     'no': 'Bath',
#     'eu': 'Bath',
#     'uk': 'Бат',
#     'ja': 'バース',
#     'jv': 'Bath',
#     'be': 'Бат',
#     'tl': 'Bath',
#     'kk': 'Бат',
#     'zh': '巴斯',
#     'ur': 'باتھ',
#     'da': 'Bath',
#     'nn': 'Bath',
#     'ku': 'Bath',
#     'ca': 'Bath',
#     'pt': 'Bath',
#     'az': 'Bat',
#     'ga': 'Bath'},
#    'lat': 51.3813864,
#    'lon': -2.3596963,
#    'country': 'GB',
#    'state': 'England'}],
#  [{'name': 'Banan',
#    'local_names': {'zh': '巴南区', 'en': 'Banan', 'fr': 'Banan', 'vi': 'Ba Nam'},
#    'lat': 29.4043601,
#    'lon': 106.5368478,
#    'country': 'CN',
#    'state': 'Chongqing'}],
#  [{'name': 'Pau',
#    'local_names': {'la': 'Palum',
#     'ru': 'По',
#     'br': 'Pau',
#     'eu': 'Paue',
#     'zh': '波城',
#     'oc': 'Pau',
#     'lt': 'Po',
#     'ca': 'Pau',
#     'sr': 'По',
#     'ar': 'بو',
#     'el': 'Πω',
#     'hu': 'Pau',
#     'ja': 'ポー',
#     'fr': 'Pau',
#     'eo': 'Paŭo',
#     'uk': 'По'},
#    'lat': 43.2957547,
#    'lon': -0.3685668,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'Bar',
#    'local_names': {'fr': 'Bar',
#     'bg': 'Бар',
#     'nl': 'Bar',
#     'ce': 'Бар',
#     'uk': 'Бар',
#     'sl': 'Bar',
#     'ru': 'Бар',
#     'is': 'Bar',
#     'sq': 'Tivar',
#     'ko': '바르',
#     'nb': 'Bar',
#     'bs': 'Bar',
#     'la': 'Antibarium',
#     'ro': 'Bar',
#     'en': 'Bar',
#     'ja': 'バール',
#     'cs': 'Bar',
#     'pl': 'Bar',
#     'mk': 'Бар',
#     'he': 'בר',
#     'hu': 'Bar',
#     'fo': 'Bar',
#     'sk': 'Bar',
#     'kl': 'Bar',
#     'lt': 'Baras',
#     'ka': 'ბარი',
#     'tr': 'Bar',
#     'be': 'Бар',
#     'ar': 'بار',
#     'sv': 'Bar',
#     'ca': 'Bar',
#     'de': 'Bar',
#     'et': 'Bar',
#     'da': 'Bar',
#     'hr': 'Bar',
#     'pt': 'Bar',
#     'eu': 'Bar',
#     'ur': 'بار',
#     'nn': 'Bar',
#     'oc': 'Bar',
#     'id': 'Bar',
#     'sh': 'Bar',
#     'it': 'Antivari',
#     'fa': 'بار',
#     'es': 'Bar',
#     'fi': 'Bar',
#     'sr': 'Бар',
#     'el': 'Μπαρ'},
#    'lat': 42.0979745,
#    'lon': 19.0954528,
#    'country': 'ME'}],
#  [{'name': 'Bergamo',
#    'local_names': {'it': 'Bergamo',
#     'bg': 'Бергамо',
#     'uk': 'Бергамо',
#     'pt': 'Bérgamo',
#     'la': 'Bergomum',
#     'hu': 'Bergamo',
#     'el': 'Μπέργκαμο',
#     'fr': 'Bergame',
#     'en': 'Bergamo',
#     'es': 'Bérgamo',
#     'ru': 'Бергамо',
#     'zh': '贝尔加莫',
#     'ca': 'Bèrgam'},
#    'lat': 45.6944947,
#    'lon': 9.6698727,
#    'country': 'IT',
#    'state': 'Lombardy'}],
#  [{'name': 'BF Homes Caloocan',
#    'lat': 14.7321052,
#    'lon': 121.0237227,
#    'country': 'PH'}],
#  [{'name': 'Bujumbura',
#    'local_names': {'af': 'Bujumbura',
#     'ha': 'Bujumbura',
#     'be': 'Бужумбура',
#     'sk': 'Bujumbura',
#     'rw': 'Bujumbura',
#     'az': 'Bujumbura',
#     'ka': 'ბუჟუმბურა',
#     'ro': 'Bujumbura',
#     'br': 'Bujumbura',
#     'gd': 'Bujumbura',
#     'ie': 'Bujumbura',
#     'hr': 'Bujumbura',
#     'zh': '布琼布拉',
#     'sh': 'Bujumbura',
#     'fr': 'Bujumbura',
#     'tr': 'Bujumbura',
#     'da': 'Bujumbura',
#     'it': 'Bujumbura',
#     'bo': 'བུ་ཇུམ་བུ་ར།',
#     'ny': 'Bujumbura',
#     'lv': 'Bužumbura',
#     'de': 'Bujumbura',
#     'hy': 'Բուժումբուրա',
#     'ru': 'Бужумбура',
#     'th': 'บูจุมบูรา',
#     'cs': 'Bujumbura',
#     'ml': 'ബുജുംബുറ',
#     'ce': 'Бужумбура',
#     'mg': 'Bujumbura',
#     'sv': 'Bujumbura',
#     'so': 'Bujumbura',
#     'en': 'Bujumbura',
#     'bg': 'Бужумбура',
#     'ln': 'Bujumbúra',
#     'ga': 'Bujumbura',
#     'mr': 'बुजुंबुरा',
#     'ur': 'بوجومبرا',
#     'vi': 'Bujumbura',
#     'la': 'Bujumbura',
#     'mk': 'Буџумбура',
#     'rn': 'Bujumbura',
#     'jv': 'Bujumbura',
#     'kg': 'Bujumbura',
#     'sn': 'Bujumbura',
#     'eu': 'Bujumbura',
#     'ht': 'Boujoumboura',
#     'sl': 'Bujumbura',
#     'kw': 'Bujumbura',
#     'oc': 'Bujumbura',
#     'hu': 'Bujumbura',
#     'cy': 'Bujumbura',
#     'lt': 'Bužumbūra',
#     'pl': 'Bużumbura',
#     'no': 'Bujumbura',
#     'io': 'Bujumbura',
#     'sw': 'Bujumbura',
#     'nl': 'Bujumbura',
#     'uk': 'Бужумбура',
#     'is': 'Bújúmbúra',
#     'kk': 'Бужумбура',
#     'ps': 'بوجومبورا',
#     'et': 'Bujumbura',
#     'am': 'ቡጁምቡራ',
#     'fa': 'بوجومبورا',
#     'ta': 'புசும்புரா',
#     'fy': 'Bûjûmbûra',
#     'mn': 'Бужумбура',
#     'sr': 'Буџумбура',
#     'ky': 'Бужумбура',
#     'zu': 'Bujumbura',
#     'yo': 'Bujumbura',
#     'pt': 'Bujumbura',
#     'yi': 'בוזשומבורע',
#     'gl': 'Bujumbura',
#     'nn': 'Bujumbura',
#     'ku': 'Bujumbura',
#     'eo': 'Buĵumburo',
#     'tg': 'Буҷумбура',
#     'sq': 'Buzhumbura',
#     'he': "בוג'ומבורה",
#     'ar': 'بوجومبورا',
#     'pa': 'ਬੁਜੁੰਬੁਰਾ',
#     'an': 'Buyumbura',
#     'ca': 'Mbabane',
#     'ja': 'ブジュンブラ',
#     'ko': '부줌부라',
#     'id': 'Bujumbura',
#     'uz': 'Bujumbura',
#     'na': 'Bujumbura',
#     'ms': 'Bujumbura',
#     'tl': 'Bujumbura',
#     'qu': 'Bujumbura',
#     'lb': 'Bujumbura',
#     'el': 'Μπουζουμπούρα',
#     'wo': 'Bujumbura',
#     'bs': 'Bujumbura',
#     'es': 'Buyumbura',
#     'fi': 'Bujumbura'},
#    'lat': -3.3638125,
#    'lon': 29.3675028,
#    'country': 'BI',
#    'state': 'Bujumbura Mairie'}],
#  [{'name': 'Companhia',
#    'lat': -22.1822689,
#    'lon': -44.68776,
#    'country': 'BR',
#    'state': 'Minas Gerais'}],
#  [{'name': 'Close',
#    'local_names': {'ga': 'An Clós'},
#    'lat': 51.6901245,
#    'lon': -9.5131483,
#    'country': 'IE'}],
#  [{'name': 'Chun',
#    'local_names': {'en': 'Chun', 'th': 'จุน'},
#    'lat': 19.3091175,
#    'lon': 100.1647501,
#    'country': 'TH',
#    'state': 'Phayao Province'}],
#  [{'name': 'Co',
#    'lat': 60.29492475,
#    'lon': 26.0047019985007,
#    'country': 'FI'}],
#  [{'name': 'Crescent',
#    'lat': 41.3650699,
#    'lon': -95.858422,
#    'country': 'US',
#    'state': 'Iowa'}],
#  [{'name': 'Huraa',
#    'local_names': {'dv': 'ހުރާ', 'en': 'Huraa'},
#    'lat': 4.3337710000000005,
#    'lon': 73.60197749346682,
#    'country': 'MV',
#    'state': 'Malé Atoll'}],
#  [{'name': 'Chișinău Municipality',
#    'local_names': {'ro': 'Municipiul Chișinău',
#     'ru': 'Муниципалитет Кишинёв',
#     'uk': 'Муніципій Кишинів',
#     'fr': 'Municipalité de Chișinău',
#     'mo': 'Municipiul Chișinău',
#     'de': 'Munizip Kischinau',
#     'en': 'Chișinău Municipality'},
#    'lat': 47.00740025,
#    'lon': 28.843146600415984,
#    'country': 'MD'}],
#  [{'name': 'Denbigh',
#    'local_names': {'ur': 'ڈنبی', 'cy': 'Dinbych', 'en': 'Denbigh'},
#    'lat': 53.1853776,
#    'lon': -3.4178289,
#    'country': 'GB',
#    'state': 'Wales'}],
#  [{'name': 'Doha',
#    'local_names': {'ro': 'Doha',
#     'hu': 'Doha',
#     'pt': 'Doha',
#     'hi': 'दोहा, क़तर',
#     'pa': 'ਦੋਹਾ',
#     'sr': 'Доха',
#     'bg': 'Доха',
#     'pl': 'Doha',
#     'gn': 'Doha',
#     'cy': 'Doha',
#     'cs': 'Dauhá',
#     'fy': 'Doha',
#     'eu': 'Doha',
#     'no': 'Doha',
#     'hr': 'Doha',
#     'bs': 'Doha',
#     'km': 'ដូហា',
#     'fi': 'Doha',
#     'kn': 'ದೊಹಾ',
#     'gu': 'દોહા',
#     'lt': 'Doha',
#     'ml': 'ദോഹ',
#     'ne': 'दोहा',
#     'tg': 'Дуҳа',
#     'ta': 'தோகா',
#     'mr': 'दोहा',
#     'ba': 'Доһа',
#     'ps': 'دوحه',
#     'ha': 'Doha',
#     'la': 'Doha',
#     'vo': 'Däuha',
#     'ky': 'Доха',
#     'kl': 'Doha',
#     'lv': 'Doha',
#     'an': 'Doha',
#     'sv': 'Doha',
#     'ug': 'دوھا',
#     'tk': 'Doha',
#     'nl': 'Doha',
#     'es': 'Doha',
#     'lb': 'Doha',
#     'et': 'Doha',
#     'yi': 'דאכא',
#     'jv': 'Doha',
#     'da': 'Doha',
#     'my': 'ဒိုဟာမြို့',
#     'nn': 'Doha',
#     'fr': 'Doha',
#     'el': 'Ντόχα',
#     'gd': 'Doha',
#     'ja': 'ドーハ',
#     'ca': 'Doha',
#     'sd': 'دوحہ',
#     'it': 'Doha',
#     'sh': 'Doha',
#     'os': 'Дохæ',
#     'sc': 'Doha',
#     'ur': 'دوحہ',
#     'ku': 'Doha',
#     'ga': 'Doha',
#     'ms': 'Doha',
#     'uz': 'Doʻha',
#     'de': 'Doha',
#     'so': 'Dooxa',
#     'eo': 'Doho',
#     'tt': 'Doha',
#     'sk': 'Dauha',
#     'kk': 'Доһа',
#     'ru': 'Доха',
#     'gr': 'Δοχή',
#     'mn': 'Доха',
#     'sn': 'Doha',
#     'fa': 'دوحه',
#     'az': 'Doha',
#     'mg': 'Doha',
#     'io': 'Doha',
#     'hy': 'Դոհա',
#     'zh': '多哈',
#     'en': 'Doha',
#     'th': 'โดฮา',
#     'ka': 'დოჰა',
#     'sw': 'Doha',
#     'ht': 'Doha',
#     'ie': 'Doha',
#     'sq': 'Doha',
#     'af': 'Doha',
#     'am': 'ዶሃ',
#     'rw': 'Doha',
#     'ko': '도하',
#     'vi': 'Doha',
#     'bn': 'দোহা',
#     'be': 'Доха',
#     'is': 'Doha',
#     'ce': 'Духьа',
#     'id': 'Doha',
#     'ar': 'الدوحة',
#     'tl': 'Doha',
#     'uk': 'Доха',
#     'bo': 'དྷོ་ཧ།',
#     'he': 'דוחה',
#     'ia': 'Doha',
#     'mk': 'Доха',
#     'yo': 'Doha',
#     'sl': 'Doha',
#     'gl': 'Doha',
#     'br': 'Doha',
#     'tr': 'Doha',
#     'oc': 'Doha'},
#    'lat': 25.2856329,
#    'lon': 51.5264162,
#    'country': 'QA'}],
#  [{'name': 'Majowe',
#    'local_names': {'pl': 'Majowe'},
#    'lat': 53.3759661,
#    'lon': 14.6659283,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Do',
#    'lat': 42.9000719,
#    'lon': 18.0298066,
#    'country': 'BA',
#    'state': 'Republika Srpska'}],
#  [{'name': 'Opatowiec',
#    'local_names': {'uk': "Опатов'єц", 'pl': 'Opatowiec', 'ru': 'Опатовец'},
#    'lat': 50.2425871,
#    'lon': 20.7237798,
#    'country': 'PL',
#    'state': 'Świętokrzyskie Voivodeship'}],
#  [{'name': 'Eigg',
#    'local_names': {'en': 'Eigg', 'gd': 'Eige', 'mk': 'Ег'},
#    'lat': 56.907925399999996,
#    'lon': -6.160063788529316,
#    'country': 'GB',
#    'state': 'Scotland'}],
#  [{'name': 'Err',
#    'local_names': {'ca': 'Er', 'fr': 'Err'},
#    'lat': 42.4406621,
#    'lon': 2.0328526,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Ee',
#    'local_names': {'nl': 'Ee', 'fy': 'Ie'},
#    'lat': 53.3300561,
#    'lon': 6.1040747,
#    'country': 'NL',
#    'state': 'Frisia'}],
#  [{'name': 'Eth',
#    'local_names': {'fr': 'Eth', 'ru': 'Эт'},
#    'lat': 50.3260433,
#    'lon': 3.6671281,
#    'country': 'FR',
#    'state': 'Hauts-de-France'}],
#  [{'name': 'Faux',
#    'local_names': {'sr': 'Фо',
#     'kk': 'Фо',
#     'ru': 'Фо',
#     'zh': '福村',
#     'be': 'Фо',
#     'bg': 'Фо',
#     'fr': 'Faux',
#     'mk': 'Фо',
#     'uk': 'Фо'},
#    'lat': 49.5374982,
#    'lon': 4.5001619,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'FJ Kato Village',
#    'lat': 7.0682339,
#    'lon': 125.5825322,
#    'country': 'PH'}],
#  [{'name': 'Fing',
#    'local_names': {'fr': 'Fing'},
#    'lat': 14.0685426,
#    'lon': -5.4854786,
#    'country': 'ML',
#    'state': 'Ségou Region'}],
#  [{'name': 'Schönberg/Schoenberg',
#    'local_names': {'de': 'Schönberg', 'fr': 'Schoenberg'},
#    'lat': 46.8101241,
#    'lon': 7.171828,
#    'country': 'CH',
#    'state': 'Fribourg'}],
#  [{'name': 'Town of Gates',
#    'local_names': {'en': 'Town of Gates'},
#    'lat': 43.1514226,
#    'lon': -77.7130004,
#    'country': 'US',
#    'state': 'New York'}],
#  [{'name': 'GM',
#    'lat': 37.36827785,
#    'lon': -121.88408532799455,
#    'country': 'US',
#    'state': 'California'}],
#  [{'name': 'Geapa',
#    'local_names': {'en': 'Geapa'},
#    'lat': 6.453333,
#    'lon': -8.998056,
#    'country': 'LR',
#    'state': 'Nimba County'}],
#  [{'name': 'Daix',
#    'local_names': {'fr': 'Daix', 'ja': 'デ'},
#    'lat': 47.3521149,
#    'lon': 5.0008333,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Qal`eh Gah-e Karkar',
#    'local_names': {'en': 'Qal`eh Gah-e Karkar', 'fa': 'قلعه گه کرکر'},
#    'lat': 36.159,
#    'lon': 46.6714,
#    'country': 'IR',
#    'state': 'Kurdistan Province'}],
#  [{'name': 'Graben',
#    'lat': 48.1890811,
#    'lon': 10.8220308,
#    'country': 'DE',
#    'state': 'Bavaria'}],
#  [{'name': 'Goidhoo',
#    'local_names': {'dv': 'ގޮއިދޫ', 'en': 'Goidhoo'},
#    'lat': 4.87108555,
#    'lon': 72.99771789715751,
#    'country': 'MV',
#    'state': 'Maalhosmadulu Dhekunuburi'}],
#  [{'name': 'Gat',
#    'local_names': {'en': 'Gat', 'fr': 'Gat', 'he': 'גת'},
#    'lat': 31.6268616,
#    'lon': 34.7951088,
#    'country': 'IL',
#    'state': 'South District'}],
#  [{'name': 'Baharan',
#    'local_names': {'fa': 'بهاران', 'en': 'Baharan'},
#    'lat': 25.3562859,
#    'lon': 60.8477664,
#    'country': 'IR',
#    'state': 'Sistan and Baluchestan Province'}],
#  [{'name': 'Gy',
#    'local_names': {'fr': 'Gy', 'uk': 'Жі'},
#    'lat': 47.4068,
#    'lon': 5.8146609,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Heights',
#    'lat': 37.2112612,
#    'lon': -77.4072045,
#    'country': 'US',
#    'state': 'Virginia'}],
#  [{'name': 'Əhən',
#    'local_names': {'az': 'Əhən'},
#    'lat': 40.8525767,
#    'lon': 48.4162128,
#    'country': 'AZ',
#    'state': 'Mountainous Shirvan'}],
#  [{'name': 'Hek',
#    'local_names': {'en': 'Hek', 'fa': 'هک'},
#    'lat': 31.0869054,
#    'lon': 53.3006387,
#    'country': 'IR',
#    'state': 'Yazd Province'}],
#  [{'name': 'Shanghai',
#    'local_names': {'ro': 'Shanghai',
#     'li': 'Sjanghai',
#     'kg': 'Shanghai',
#     'tt': 'Şanxay',
#     'kv': 'Шанхай',
#     'si': 'ෂැංහයි',
#     'ar': 'شانغهاي',
#     'mk': 'Шангај',
#     'sq': 'Shangai',
#     'hi': 'शंघाई',
#     'pt': 'Xangai',
#     'ay': 'Shanghai',
#     'kk': 'Шанхай',
#     'nl': 'Shanghai',
#     'uz': 'Shanxay',
#     'fa': 'شانگهای',
#     'ne': 'शाङ्घाई',
#     'ie': 'Shanghai',
#     'mn': 'Шанхай',
#     'id': 'Shanghai',
#     'ky': 'Шанхай',
#     'zu': 'Shanghai',
#     'ba': 'Шанхай',
#     'eu': 'Shanghai',
#     'ce': 'Шанхай',
#     'qu': 'Shanghai',
#     'te': 'షాంఘై',
#     'ka': 'შანხაი',
#     'es': 'Shanghái',
#     'fo': 'Shanghai',
#     'hr': 'Šangaj',
#     'bn': 'সাংহাই',
#     'cy': 'Shanghai',
#     'tn': 'Shanghai',
#     'bg': 'Шанхай',
#     'tl': 'Shanghai',
#     'th': 'เซี่ยงไฮ้',
#     'he': 'שאנגחאי',
#     'ja': '上海市',
#     'kl': 'Shanghai',
#     'cv': 'Шанхай',
#     'ms': 'Shanghai',
#     'ps': 'شانگهای',
#     'ny': 'Shanghai',
#     'su': 'Shanghai',
#     'is': 'Sjanghæ',
#     'be': 'Шанхай',
#     'io': 'Shanghai',
#     'vo': 'Shanghai',
#     'ru': 'Шанхай',
#     'ha': 'Shanghai',
#     'as': 'ছাংহাই',
#     'sv': 'Shanghai',
#     'lb': 'Shanghai',
#     'sl': 'Šanghaj',
#     'no': 'Shanghai',
#     'uk': 'Шанхай',
#     'my': 'ရှန်ဟိုင်းမြို့',
#     'bo': 'ཧྲང་ཧའེ་གྲོང་ཁྱེར།',
#     'jv': 'Shanghai',
#     'rm': 'Schanghai',
#     'da': 'Shanghai',
#     'tk': 'Şanhaý',
#     'la': 'Sciamhaevum',
#     'mg': 'Shanghai',
#     'nn': 'Shanghai',
#     'bs': 'Šangaj',
#     'cs': 'Šanghaj',
#     'ht': 'Shanghai',
#     'tr': 'Şanghay',
#     'en': 'Shanghai',
#     'ki': 'Shanghai',
#     'lv': 'Šanhaja',
#     'kn': 'ಶಾಂಘೈ',
#     'gl': 'Shanghai',
#     'hy': 'Շանհայ',
#     'gd': 'Shanghai',
#     'os': 'Шанхай',
#     'vi': 'Thượng Hải',
#     'ml': 'ഷാങ്ഹായ്',
#     'af': 'Sjanghai',
#     'az': 'Şanxay',
#     'fr': 'Shanghai',
#     'fy': 'Shanghai',
#     'br': 'Shanghai',
#     'wo': 'Shanghai',
#     'om': 'Shaangaayi',
#     'ta': 'சாங்காய்',
#     'pl': 'Szanghaj',
#     'zh': '上海市',
#     'ia': 'Shanghai',
#     'feature_name': 'Shanghai',
#     'tw': 'Shangai',
#     'kw': 'Shanghai',
#     'sr': 'Шангај',
#     'sk': 'Šanghaj',
#     'am': 'ሻንግሃይ',
#     'gv': 'Shanghai',
#     'ln': 'Shanghai',
#     'hu': 'Sanghaj',
#     'ascii': 'Shanghai',
#     'mr': 'शांघाय',
#     'de': 'Shanghai',
#     'et': 'Shanghai',
#     'tg': 'Шанхай',
#     'fj': 'Shaghai',
#     'ga': 'Shang-hai',
#     'bm': 'Shanghai',
#     'mi': 'Hangahai',
#     'it': 'Shanghai',
#     'pa': 'ਸ਼ੰਘਾਈ',
#     'eo': 'Ŝanhajo',
#     'ur': 'شنگھائی',
#     'oc': 'Shanghai',
#     'yi': 'שאנכיי',
#     'an': 'Xangai',
#     'sw': 'Shanghai',
#     'ko': '상하이',
#     'ug': 'شاڭخەي شەھىرى',
#     'lt': 'Šanchajus',
#     'el': 'Σαγκάη',
#     'ca': 'Xangai',
#     'ku': 'Şanghay',
#     'lo': 'ຊຽງໄຮ້',
#     'za': 'Sanghaij',
#     'bi': 'Shanghai',
#     'gn': 'Changái',
#     'fi': 'Shanghai'},
#    'lat': 31.2322758,
#    'lon': 121.4692071,
#    'country': 'CN'}],
#  [{'name': 'Islamabad',
#    'local_names': {'gr': 'Ἰσλαμαβάδη',
#     'lt': 'Islamabadas',
#     'it': 'Islamabad',
#     'pl': 'Islamabad',
#     'tg': 'Исламабад',
#     'nl': 'Islamabad',
#     'be': 'Ісламабад',
#     'de': 'Islamabad',
#     'mr': 'इस्लामाबाद',
#     'et': 'Islāmābād',
#     'ka': 'ისლამაბადი',
#     'ja': 'イスラーマーバード首都圏;イスラマバード',
#     'te': 'ఇస్లామాబాద్',
#     'hu': 'Iszlámábád',
#     'hy': 'Իսլամաբադ',
#     'bo': 'ཨི་སི་ལམ་བོ།',
#     'es': 'Islamabad',
#     'zh': '伊斯蘭堡',
#     'sq': 'Islamabadi',
#     'el': 'Ισλαμαμπάντ',
#     'tr': 'İslamabad',
#     'ur': 'اسلام آباد',
#     'sk': 'Islamabad',
#     'pa': 'ਇਸਲਾਮਾਬਾਦ',
#     'cs': 'Islámábád',
#     'la': 'Islamabada',
#     'sr': 'Исламабад',
#     'pt': 'Islamabade',
#     'ar': 'إسلام آباد',
#     'nn': 'Islamabad',
#     'sv': 'Islamabad',
#     'ru': 'Исламабад',
#     'ko': '이슬라마바드',
#     'ug': 'ئىسلامئاباد',
#     'th': 'อิสลามาบัด',
#     'oc': 'Islamabad',
#     'bn': 'ইসলামাবাদ',
#     'yi': 'איסלאמאבאד',
#     'kn': 'ಇಸ್ಲಾಮಾಬಾದ್',
#     'hi': 'इस्लामाबाद',
#     'lv': 'Islāmābāda',
#     'ks': 'اِسلام آبادٖ',
#     'en': 'Islamabad',
#     'eu': 'Islamabad',
#     'no': 'Islamabad',
#     'fa': 'اسلام\u200cآباد',
#     'bg': 'Исламабад',
#     'kk': 'Исламабад',
#     'fr': 'Islamabad',
#     'dv': 'އިސްލާމްއާބާދު',
#     'uk': 'Ісламабад',
#     'vi': 'Islamabad',
#     'ta': 'இஸ்லாமாபாத்',
#     'am': 'ኢስላማባድ',
#     'ps': 'اسلام آباد',
#     'az': 'İslamabad',
#     'ml': 'ഇസ്ലാമബാദ്',
#     'gu': 'ઇસ્લામાબાદ',
#     'eo': 'Islamabado',
#     'ku': 'Îslamabad',
#     'mn': 'Исламабад',
#     'he': 'איסלמבד',
#     'is': 'Islamabad',
#     'mk': 'Исламабад',
#     'sd': 'اسلام آباد',
#     'os': 'Исламабад'},
#    'lat': 33.6938118,
#    'lon': 73.0651511,
#    'country': 'PK',
#    'state': 'Islamabad Capital Territory'}],
#  [{'name': 'Innermedøya',
#    'lat': 66.8789958,
#    'lon': 13.44650821244402,
#    'country': 'NO'}],
#  [{'name': 'Narman',
#    'local_names': {'ka': 'ნარიმანი',
#     'tr': 'Narman',
#     'ur': 'نارمان',
#     'hy': 'Նառիման',
#     'ku': 'Narman',
#     'ru': 'Нарман',
#     'ce': 'Нарман',
#     'tt': 'Нарман',
#     'fa': 'نارمان'},
#    'lat': 40.3452003,
#    'lon': 41.871138,
#    'country': 'TR'}],
#  [{'name': 'Hadaiq el Qubbah',
#    'local_names': {'de': 'Hadaiq el Qubbah',
#     'en': 'Hadaiq el Qubbah',
#     'fr': 'Hadaiq el Qubbah',
#     'ascii': 'Ḩadā’iq al Qubbah, Hadaiq al Qubbah, Garden City, Qubba Gardens',
#     'feature_name': 'Ḩadā’iq al Qubbah, Hadaiq al Qubbah, Garden City, Qubba Gardens',
#     'ar': 'حدائق القبة'},
#    'lat': 30.0821784,
#    'lon': 31.2825387,
#    'country': 'EG',
#    'state': 'Cairo'}],
#  [{'name': 'Ie',
#    'local_names': {'ru': 'Иэ',
#     'fr': 'Ie',
#     'uk': 'Іє',
#     'en': 'Ie',
#     'zh': '伊江村',
#     'ja': '伊江村'},
#    'lat': 26.721715,
#    'lon': 127.786429,
#    'country': 'JP'}],
#  [{'name': 'Isle',
#    'local_names': {'fr': 'Isle', 'oc': 'Isla (de Vinhana)', 'uk': 'Іль'},
#    'lat': 45.8055591,
#    'lon': 1.2238259,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'It',
#    'lat': 45.6628887,
#    'lon': 10.118138,
#    'country': 'IT',
#    'state': 'Lombardy'}],
#  [{'name': 'Jam',
#    'local_names': {'fa': 'جم',
#     'fr': 'Jam',
#     'hi': 'जम',
#     'ja': 'ジャム',
#     'ru': 'Джем',
#     'de': 'Dscham',
#     'en': 'Jam'},
#    'lat': 27.8262811,
#    'lon': 52.3263597,
#    'country': 'IR',
#    'state': 'Bushehr Province'}],
#  [{'name': 'Tokyo',
#    'local_names': {'lv': 'Tokija',
#     'eo': 'Tokio',
#     'be': 'Токіа',
#     'ta': 'டோக்கியோ',
#     'tr': 'Tokyo',
#     'kn': 'ಟೋಕ್ಯೊ',
#     'ku': 'Tokyo',
#     'vi': 'Tokyo',
#     'sl': 'Tokio',
#     'sv': 'Tokyo',
#     'is': 'Tókýó',
#     'fr': 'Tokyo',
#     'fi': 'Tokio',
#     'lb': 'Tokio',
#     'cs': 'Tokio',
#     'ru': 'Токио',
#     'uk': 'Токіо',
#     'bg': 'Токио',
#     'fa': 'توکیو',
#     'et': 'Tōkyō',
#     'ia': 'Tokyo',
#     'tg': 'Токио',
#     'cy': 'Tokyo',
#     'sk': 'Tokio',
#     'pl': 'Tokio',
#     'da': 'Tokyo',
#     'pt': 'Tóquio',
#     'ca': 'Tòquio',
#     'en': 'Tokyo',
#     'io': 'Tokyo',
#     'it': 'Tokyo',
#     'he': 'טוקיו',
#     'mi': 'Tōkio',
#     'hr': 'Tokio',
#     'el': 'Τόκιο',
#     'mr': 'तोक्यो',
#     'ko': '도쿄도',
#     'th': 'โตเกียว',
#     'nl': 'Tokio',
#     'ja': '東京都',
#     'sr': 'Токио',
#     'zh': '东京都/東京都',
#     'ar': 'طوكيو',
#     'la': 'Tokium',
#     'de': 'Tokio',
#     'es': 'Tokio',
#     'lt': 'Tokijas',
#     'hu': 'Tokió',
#     'oc': 'Tòquio'},
#    'lat': 35.6828387,
#    'lon': 139.7594549,
#    'country': 'JP'}],
#  [{'name': 'Jo',
#    'local_names': {'en': 'Jo'},
#    'lat': 27.248611,
#    'lon': 66.630556,
#    'country': 'PK',
#    'state': 'Balochistan'}],
#  [{'name': 'Križ',
#    'local_names': {'hr': 'Križ', 'hu': 'Obedszentkereszt'},
#    'lat': 45.6632061,
#    'lon': 16.5204571,
#    'country': 'HR'}],
#  [{'name': 'Ke',
#    'lat': 4.454561,
#    'lon': 6.915462,
#    'country': 'NG',
#    'state': 'Rivers State'}],
#  [{'name': 'Acre',
#    'local_names': {'ur': 'عکا',
#     'cs': 'Akko',
#     'hi': 'एकर',
#     'ru': 'Акко',
#     'ml': 'ഏക്കർ',
#     'lt': 'Akas',
#     'ca': 'Acre',
#     'de': 'Akko',
#     'am': 'ዓኮ',
#     'ja': 'アッコ',
#     'fi': 'Akko',
#     'he': 'עכו',
#     'fr': 'Acre',
#     'cy': 'Acre',
#     'ar': 'عكا',
#     'fa': 'عکا',
#     'el': 'Άκρα',
#     'es': 'Acre',
#     'it': 'Acri',
#     'da': 'Akko',
#     'eo': 'Akko',
#     'et': 'Akko',
#     'af': 'Akko',
#     'en': 'Acre',
#     'ku': 'Eka',
#     'eu': 'Akre',
#     'bg': 'Акра'},
#    'lat': 32.9281731,
#    'lon': 35.0756378,
#    'country': 'IL',
#    'state': 'North District'}],
#  [{'name': 'Kogel',
#    'local_names': {'de': 'Kogel'},
#    'lat': 53.4672206,
#    'lon': 10.9199709,
#    'country': 'DE',
#    'state': 'Mecklenburg-Vorpommern'}],
#  [{'name': 'Riga',
#    'local_names': {'br': 'Riga',
#     'sr': 'Рига',
#     'kw': 'Rīga',
#     'eu': 'Riga',
#     'fa': 'ریگا',
#     'nn': 'Riga',
#     'os': 'Ригæ',
#     'gv': 'Rīga',
#     'fy': 'Riga',
#     'th': 'รีกา',
#     'hu': 'Riga',
#     'uk': 'Рига',
#     'fi': 'Riika',
#     'feature_name': 'Riga',
#     'yo': 'Riga',
#     'ka': 'რიგა',
#     'be': 'Рыга',
#     'sk': 'Riga',
#     'na': 'Riga',
#     'es': 'Riga',
#     'zh': '里加',
#     'ko': '리가',
#     'sq': 'Riga',
#     'cs': 'Riga',
#     'vi': 'Riga',
#     'zu': 'IRiga',
#     'sw': 'Riga',
#     'ta': 'ரீகா',
#     'no': 'Riga',
#     'bg': 'Рига',
#     'tl': 'Riga',
#     'yi': 'ריגע',
#     'oc': 'Riga',
#     'ur': 'ریگا',
#     'mg': 'Riga',
#     'el': 'Ρίγα',
#     'mt': 'Riga',
#     'ar': 'ريغا',
#     'st': 'Riga',
#     'mr': 'रिगा',
#     'en': 'Riga',
#     'af': 'Riga',
#     'kk': 'Рига',
#     'nl': 'Riga',
#     'ro': 'Riga',
#     'ku': 'Rîga',
#     'gl': 'Riga',
#     'he': 'ריגה',
#     'hy': 'Ռիգա',
#     'uz': 'Riga',
#     'lb': 'Rīga',
#     'ln': 'Riga',
#     'az': 'Riqa',
#     'tt': 'Рига',
#     'hi': 'रीगा',
#     'de': 'Riga',
#     'ca': 'Riga',
#     'la': 'Riga',
#     'fr': 'Riga',
#     'pl': 'Ryga',
#     'id': 'Riga',
#     'lv': 'Rīga',
#     'fo': 'Riga',
#     'ms': 'Riga',
#     'eo': 'Rigo',
#     'tg': 'Рига',
#     'ky': 'Рига',
#     'gd': 'Riga',
#     'jv': 'Riga',
#     'bo': 'རི་ག',
#     'lt': 'Ryga',
#     'nv': 'Wiiga',
#     'mk': 'Рига',
#     'et': 'Riia',
#     'my': 'ရီဂါမြို့',
#     'wo': 'Riga',
#     'cu': 'Рига',
#     'it': 'Riga',
#     'bn': 'রিগা',
#     'an': 'Riga',
#     'hr': 'Riga',
#     'is': 'Ríga',
#     'tr': 'Riga',
#     'ja': 'リガ',
#     'pa': 'ਰੀਗਾ',
#     'mi': 'Riga',
#     'ug': 'رىگا',
#     'ee': 'Riga',
#     'vo': 'Rīga',
#     'qu': 'Riga',
#     'ga': 'Ríge',
#     'ie': 'Riga',
#     'cv': 'Рига',
#     'io': 'Riga',
#     'da': 'Riga',
#     'kv': 'Рига',
#     'am': 'ሪጋ',
#     'bs': 'Riga',
#     'ru': 'Рига',
#     'kl': 'Riga',
#     'sv': 'Riga',
#     'ht': 'Riga',
#     'se': 'Riga',
#     'pt': 'Riga',
#     'ascii': 'Riga',
#     'cy': 'Riga',
#     'sl': 'Riga'},
#    'lat': 56.9493977,
#    'lon': 24.1051846,
#    'country': 'LV',
#    'state': 'Vidzeme'}],
#  [{'name': 'Elba',
#    'local_names': {'af': 'Elba',
#     'ar': 'إلبا',
#     'nl': 'Elba',
#     'nn': 'Elba',
#     'sv': 'Elba',
#     'zh': '厄尔巴岛',
#     'su': 'Elba',
#     'lt': 'Elba',
#     'da': 'Elba',
#     'pt': 'Ilha de Elba',
#     'et': 'Elba',
#     'en': 'Elba',
#     'hr': 'Elba',
#     'de': 'Elba',
#     'sk': 'Elba',
#     'ml': 'എൽബ',
#     'eo': 'Elbo',
#     'pl': 'Elba',
#     'id': 'Elba',
#     'is': 'Elba',
#     'uk': 'Ельба',
#     'la': 'Ilva',
#     'cy': 'Ynys Elba',
#     'vi': 'Elba',
#     'gl': 'Illa de Elba',
#     'fr': "Île d'Elbe",
#     'th': 'เกาะเอลบา',
#     'ca': "Illa d'Elba",
#     'br': 'Elba',
#     'gd': 'Elba',
#     'bg': 'Елба',
#     'ru': 'Эльба',
#     'ja': 'エルバ島',
#     'cs': 'Elba',
#     'fi': 'Elba',
#     'eu': 'Elba',
#     'sl': 'Elba',
#     'hy': 'Էլբա',
#     'yi': 'עלבע',
#     'ka': 'ელბა',
#     'es': 'Isla de Elba',
#     'ta': 'எல்பா',
#     'tr': 'Elba',
#     'sr': 'Елба',
#     'mr': 'एल्बा',
#     'no': 'Elba',
#     'co': "Isula d'Elba",
#     'lv': 'Elba',
#     'ko': '엘바 섬',
#     'mk': 'Елба',
#     'el': 'Έλβα',
#     'lb': 'Elba',
#     'ga': 'Elba',
#     'be': 'Востраў Эльба',
#     'ro': 'Elba'},
#    'lat': 42.790216599999994,
#    'lon': 10.340278678735025,
#    'country': 'IT',
#    'state': 'Tuscany'}],
#  [{'name': 'Awlus',
#    'local_names': {'en': 'Awlus',
#     'fr': 'Awlus',
#     'ascii': '`Allas, `Allās, Awlūs',
#     'feature_name': '`Allas, `Allās, Awlūs',
#     'ar': 'علص',
#     'de': 'Awlus'},
#    'lat': 35.7129221,
#    'lon': 37.3643315,
#    'country': 'SY',
#    'state': 'Aleppo Governorate'}],
#  [{'name': '`Alt',
#    'local_names': {'de': '`Alt',
#     'en': '`Alt',
#     'fr': '`Alt',
#     'ascii': '‘Alt',
#     'feature_name': '‘Alt',
#     'ar': 'علط'},
#    'lat': 15.544005,
#    'lon': 48.0239718,
#    'country': 'YE',
#    'state': 'Hadramaut Governorate'}],
#  [{'name': 'Lu',
#    'local_names': {'en': 'Lu', 'fr': 'Lu', 'vi': 'Lô', 'zh': '泸县'},
#    'lat': 29.1539219,
#    'lon': 105.3788947,
#    'country': 'CN',
#    'state': 'Sichuan'}],
#  [{'name': 'Majuro',
#    'local_names': {'nl': 'Majuro',
#     'sw': 'Majuro',
#     'io': 'Majuro',
#     'da': 'Majuro',
#     'ml': 'മാജുറോ',
#     'lb': 'Majuro',
#     'mr': 'माजुरो',
#     'ar': 'ماجورو',
#     'uz': 'Majuro',
#     'sc': 'Majuro',
#     'ru': 'Маджуро',
#     'sr': 'Маџуро',
#     'ro': 'Majuro',
#     'sl': 'Majuro',
#     'pa': 'ਮਾਜੁਰੋ',
#     'it': 'Majuro',
#     'bo': 'མ་ཇུ་རོ།',
#     'am': 'ማጁሮ',
#     'tl': 'Majuro',
#     'hy': 'Մաջուրո',
#     'is': 'Majúró',
#     'zh': '马朱罗',
#     'la': 'Madzurum',
#     'lv': 'Madžuro',
#     'hr': 'Majuro',
#     'cy': 'Majuro',
#     'ie': 'Majuro',
#     'cs': 'Majuro',
#     'uk': 'Маджуро',
#     'ka': 'მაჯურო',
#     'sq': 'Majuro',
#     'tr': 'Majuro',
#     'sk': 'Dalap-Uliga-Darrit',
#     'mk': 'Маџуро',
#     'ja': 'マジュロ',
#     'nn': 'Majuro',
#     'os': 'Маджуро',
#     'hi': 'माजुरो',
#     'ht': 'Majouro',
#     'ny': 'Majuro',
#     'sh': 'Majuro',
#     'rw': 'Majuro',
#     'no': 'Majuro',
#     'kk': 'Маджуро',
#     'el': 'Ματζούρο',
#     'th': 'มาจูโร',
#     'ta': 'மாசூரோ',
#     'sv': 'Majuro',
#     'pt': 'Majuro',
#     'gd': 'Majuro',
#     'vi': 'Majuro',
#     'id': 'Majuro',
#     'mh': 'Mājro',
#     'he': "מג'ורו",
#     'ms': 'Majuro',
#     'fr': 'Majuro',
#     'ascii': 'Majuro',
#     'br': 'Majuro',
#     'az': 'Macuro',
#     'bg': 'Маджуро',
#     'fi': 'Majuro',
#     'de': 'Majuro',
#     'ur': 'ماجورو',
#     'ba': 'Маджуро',
#     'et': 'Majuro atoll',
#     'be': 'Маджура',
#     'sn': 'Majuro',
#     'tg': 'Маҷуро',
#     'hu': 'Majuro',
#     'fy': 'Majuro',
#     'ko': '마주로',
#     'en': 'Majuro',
#     'af': 'Majuro',
#     'ca': 'Majuro',
#     'pl': 'Majuro',
#     'bs': 'Majuro',
#     'ky': 'Мажeро',
#     'bn': 'মাজুরো',
#     'feature_name': 'Majuro',
#     'es': 'Majuro',
#     'gn': 'Majuro',
#     'eo': 'Majuro',
#     'ps': 'ماجورو',
#     'oc': 'Majuro',
#     'ty': 'Majuro',
#     'eu': 'Majuro',
#     'gl': 'Majuro',
#     'fa': 'ماجورو',
#     'lt': 'Madžūras'},
#    'lat': 7.0909924,
#    'lon': 171.3816354,
#    'country': 'MH'}],
#  [{'name': 'Mei County',
#    'local_names': {'zh': '眉县', 'vi': 'My', 'en': 'Mei County'},
#    'lat': 34.130278,
#    'lon': 107.835,
#    'country': 'CN',
#    'state': 'Shaanxi'}],
#  [{'name': 'Malé',
#    'local_names': {'ml': 'മാലി',
#     'hi': 'माले',
#     'mr': 'मले',
#     'zh': '马累',
#     'et': 'Male',
#     'nl': 'Malé',
#     'cs': 'Male',
#     'pl': 'Male',
#     'sv': 'Malé',
#     'ta': 'மாலே',
#     'de': 'Malé',
#     'dv': 'މާލެ',
#     'en': 'Malé',
#     'hu': 'Malé',
#     'oc': 'Male',
#     'fr': 'Malé'},
#    'lat': 4.1779879,
#    'lon': 73.5107387,
#    'country': 'MV'}],
#  [{'name': 'Melilla',
#    'local_names': {'sk': 'Melilla',
#     'ja': 'メリリャ',
#     'bg': 'Мелиля',
#     'ko': '멜리야',
#     'ta': 'மெலில்லா',
#     'zh': '梅利利亚',
#     'el': 'Μελίγια',
#     'ar': 'مليلية',
#     'be': 'Мелілья',
#     'cs': 'Melilla',
#     'sr': 'Мелиља',
#     'mr': 'मेलिया',
#     'lv': 'Melilja',
#     'zu': 'IMelilla',
#     'ru': 'Мелилья',
#     'es': 'Melilla',
#     'su': 'Mélilya',
#     'kk': 'Мелилья',
#     'la': 'Rusadir',
#     'pl': 'Melilla',
#     'eo': 'Melilo',
#     'os': 'Мелилья',
#     'hy': 'Մելիլյա',
#     'fa': 'ملیلیه',
#     'mk': 'Мелилја',
#     'lt': 'Melilja',
#     'ka': 'მელილია',
#     'th': 'เมลียา',
#     'en': 'Melilla',
#     'uk': 'Мелілья',
#     'he': 'מלייה'},
#    'lat': 35.2918698,
#    'lon': -2.9409026,
#    'country': 'ES',
#    'state': 'Melilla'}],
#  [{'name': 'Mont',
#    'lat': 46.6260356,
#    'lon': 3.8306675,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Aomar',
#    'local_names': {'fr': 'Aomar',
#     'ur': 'عمر',
#     'ar': 'عمر',
#     'en': 'Aomar',
#     'fa': 'عمر'},
#    'lat': 36.492393,
#    'lon': 3.7711939,
#    'country': 'DZ',
#    'state': 'Bouira'}],
#  [{'name': 'Moult',
#    'local_names': {'ru': 'Муль', 'uk': 'Му', 'fr': 'Moult'},
#    'lat': 49.115483,
#    'lon': -0.1657186,
#    'country': 'FR',
#    'state': 'Normandy'}],
#  [{'name': 'Mexico',
#    'local_names': {'ar': 'المكسيك', 'en': 'Mexico', 'es': 'México'},
#    'lat': 25.20193915,
#    'lon': 55.15419672678571,
#    'country': 'AE',
#    'state': 'Dubai'}],
#  [{'name': 'Monte-Carlo',
#    'local_names': {'et': 'Monte Carlo',
#     'fr': 'Monte-Carlo',
#     'mk': 'Монте Карло',
#     'da': 'Monte Carlo'},
#    'lat': 43.7402961,
#    'lon': 7.426559,
#    'country': 'MC'}],
#  [{'name': 'Amman',
#    'local_names': {'cv': 'Амман',
#     'he': 'רבת עמון',
#     'sk': 'Ammán',
#     'uk': 'Амман',
#     'am': 'አማን',
#     'ar': 'عمان',
#     'de': 'Amman',
#     'lv': 'Ammāna',
#     'da': 'Amman',
#     'eu': 'Amman',
#     'tr': 'Amman',
#     'ku': 'Amman',
#     'os': 'Амман',
#     'fi': 'Amman',
#     'oc': 'Amman',
#     'hr': 'Amman',
#     'ja': 'アンマン',
#     'sv': 'Amman',
#     'nl': 'Amman',
#     'gl': 'Amán - عمان',
#     'tg': 'Аммон',
#     'tt': 'Амман',
#     'hu': 'Ammán',
#     'be': 'Аман',
#     'zh': '安曼',
#     'fa': 'امان',
#     'pl': 'Amman',
#     'mn': 'Амман',
#     'mr': 'अम्मान',
#     'sr': 'Аман',
#     'ht': 'Amàn',
#     'lt': 'Amanas',
#     'ko': '암만',
#     'cs': 'Ammán',
#     'bs': 'Aman',
#     'ru': 'Амман',
#     'pt': 'Amã',
#     'ur': 'عمان',
#     'ug': 'ئاممان',
#     'el': 'Αμμάν',
#     'no': 'Amman',
#     'feature_name': 'Amman',
#     'en': 'Amman',
#     'is': 'Amman',
#     'es': 'Amán',
#     'hy': 'Ամման',
#     'bn': 'আম্মান',
#     'bo': 'ཨམ་མན།',
#     'ascii': 'Amman',
#     'yi': 'אמאן',
#     'kn': 'ಅಮ್ಮಾನ್',
#     'et': 'Amman',
#     'sl': 'Aman',
#     'ta': 'அம்மான்',
#     'it': 'Amman',
#     'ka': 'ამანი',
#     'kk': 'Амман',
#     'mk': 'Аман',
#     'hi': 'अम्मान',
#     'bg': 'Аман',
#     'eo': 'Amano',
#     'te': 'అమ్మాన్',
#     'ml': 'അമ്മാൻ',
#     'ks': 'عمان',
#     'fr': 'Amman',
#     'th': 'อัมมาน'},
#    'lat': 31.9515694,
#    'lon': 35.9239625,
#    'country': 'JO',
#    'state': 'Amman'}],
#  [{'name': 'Kiamika',
#    'lat': 46.4188742,
#    'lon': -75.3799932,
#    'country': 'CA',
#    'state': 'Quebec'}],
#  [{'name': 'Mau',
#    'local_names': {'ar': 'ماو',
#     'hi': 'मऊ',
#     'kn': 'ಮಾಹು',
#     'mr': 'मऊ',
#     'pa': 'ਮਊ',
#     'he': 'מאו',
#     'ml': 'മൗ'},
#    'lat': 25.9391096,
#    'lon': 83.5716125,
#    'country': 'IN',
#    'state': 'Uttar Pradesh'}],
#  [{'name': 'Metz',
#    'local_names': {'th': 'แม็ส',
#     'lb': 'Metz',
#     'fr': 'Metz',
#     'lv': 'Meca',
#     'ko': '메스',
#     'uk': 'Мец',
#     'hu': 'Metz',
#     'he': 'מץ',
#     'br': 'Metz',
#     'kk': 'Мец',
#     'el': 'Μετς',
#     'bg': 'Мец',
#     'ur': 'میتز',
#     'ar': 'متز',
#     'mk': 'Мец',
#     'hy': 'Մեց',
#     'ta': 'மெட்சு',
#     'fa': 'متز',
#     'ja': 'メス',
#     'lt': 'Mecas',
#     'oc': 'Mètz',
#     'bo': 'མེ་ཊི་ཛི།',
#     'yi': 'מעץ',
#     'ru': 'Мец',
#     'ka': 'მეცი',
#     'be': 'Мец',
#     'jv': 'Métz',
#     'sr': 'Мец',
#     'am': 'መትዝ',
#     'zh': '梅斯',
#     'la': 'Mettis',
#     'cs': 'Mety',
#     'mr': 'मेस'},
#    'lat': 49.1196964,
#    'lon': 6.1763552,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'NA',
#    'lat': -51.3184588,
#    'lon': -59.741689897506845,
#    'country': 'FK'}],
#  [{'name': 'National Park',
#    'lat': 39.865968,
#    'lon': -75.1796351,
#    'country': 'US',
#    'state': 'New Jersey'}],
#  [{'name': 'نعل کنان',
#    'lat': 31.7428456,
#    'lon': 50.1793258,
#    'country': 'IR',
#    'state': 'Khuzestan Province'}],
#  [{'name': '`Anaz',
#    'local_names': {'en': '`Anaz',
#     'fr': '`Anaz',
#     'ascii': 'Aanaz, `Anaz',
#     'feature_name': 'Aanaz, `Anaz',
#     'ar': 'عنز',
#     'de': '`Anaz'},
#    'lat': 34.7360048,
#    'lon': 36.3011029,
#    'country': 'SY',
#    'state': 'Homs Governorate'}],
#  [{'name': 'Ni',
#    'local_names': {'en': 'Ni', 'ja': 'ニ'},
#    'lat': 35.72047,
#    'lon': 140.6298436,
#    'country': 'JP'}],
#  [{'name': 'ng',
#    'lat': -3.3669467500000003,
#    'lon': 36.67738947024446,
#    'country': 'TZ',
#    'state': 'Arusha'}],
#  [{'name': 'Nou',
#    'local_names': {'ru': 'Но',
#     'hu': 'Szászújfalu',
#     'uk': 'Ноу',
#     'ro': 'Nou',
#     'de': 'Neudorf bei Hermannstadt'},
#    'lat': 45.8299398,
#    'lon': 24.2830582,
#    'country': 'RO'}],
#  [{'name': 'Omps',
#    'local_names': {'uk': 'Ом', 'fr': 'Omps', 'oc': 'Omps'},
#    'lat': 44.8779952,
#    'lon': 2.2761709,
#    'country': 'FR',
#    'state': 'Auvergne-Rhône-Alpes'}],
#  [{'name': 'Park',
#    'lat': 39.112507,
#    'lon': -100.358747,
#    'country': 'US',
#    'state': 'Kansas'}],
#  [{'name': 'Pay',
#    'local_names': {'hi': 'पाय', 'en': 'Pay'},
#    'lat': 23.1361652,
#    'lon': 68.9346579,
#    'country': 'IN',
#    'state': 'Gujarat'}],
#  [{'name': 'Golęcino-Gocław',
#    'local_names': {'de': 'Frauendorf-Gotzlow', 'pl': 'Golęcino-Gocław'},
#    'lat': 53.4711354,
#    'lon': 14.5976516,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Py',
#    'local_names': {'fr': 'Py', 'ca': 'Pi de Conflent'},
#    'lat': 42.49576,
#    'lon': 2.3506675,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Pey',
#    'local_names': {'fr': 'Pey', 'oc': 'Pei', 'uk': 'Пе'},
#    'lat': 43.6302615,
#    'lon': -1.2015629,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [],
#  [{'name': 'Plains',
#    'lat': 33.1892387,
#    'lon': -102.827274,
#    'country': 'US',
#    'state': 'Texas'}],
#  [{'name': 'Opatów',
#    'local_names': {'pl': 'Opatów',
#     'he': 'אפטא',
#     'ru': 'Опатув',
#     'uk': 'Опатув'},
#    'lat': 50.8017661,
#    'lon': 21.4238281,
#    'country': 'PL',
#    'state': 'Świętokrzyskie Voivodeship'}],
#  [{'name': 'Prague',
#    'local_names': {'hu': 'Prága főváros',
#     'oc': 'Praga',
#     'bs': 'Prag',
#     'cv': 'Прага',
#     'gl': 'Praga',
#     'eo': 'Ĉefurba regiono Prago',
#     'ta': 'பிராகா',
#     'el': 'Πράγα',
#     'ca': 'Praga',
#     'se': 'Praha',
#     'ie': 'Praha',
#     'cs': 'Hlavní město Praha',
#     'nl': 'Praag',
#     'fr': 'Prague',
#     'pl': 'Miasto Stołeczne Praga',
#     'hr': 'Prag',
#     'mi': 'Prague',
#     'kk': 'Прага',
#     'no': 'Praha',
#     'kw': 'Praha',
#     'ak': 'Prague',
#     'yi': 'פראג',
#     'cu': 'Прага',
#     'ku': 'Prag',
#     'da': 'Prag',
#     'mn': 'Прага',
#     'id': 'Praha',
#     'th': 'ปราก',
#     'az': 'Praqa',
#     'os': 'Прагæ',
#     'it': 'Praga',
#     'fo': 'Prag',
#     'sh': 'Prag',
#     'ms': 'Praha',
#     'nn': 'Praha',
#     'sc': 'Praga',
#     'he': 'פראג',
#     'la': 'Praga',
#     'yo': 'Prague',
#     'tt': 'Прага',
#     'sl': 'Praga',
#     'ga': 'Prág',
#     'ee': 'Prague',
#     'kn': 'ಪ್ರಾಗ',
#     'gd': 'Pràg',
#     'ka': 'პრაღა',
#     'my': 'ပရက်ဂ်မြို့',
#     'tr': 'Prag',
#     'ml': 'പ്രാഗ്',
#     'ro': 'Praga',
#     'hy': 'Պրահա',
#     'sr': 'Праг',
#     'fy': 'Praach',
#     'es': 'Praga',
#     'ru': 'Столица Прага',
#     'an': 'Praga',
#     'ur': 'پراگ',
#     'kv': 'Прага',
#     'ja': 'プラハ',
#     'is': 'Prag',
#     'zh': '布拉格',
#     'cy': 'Prag',
#     'ps': 'پراګ',
#     'be': 'Прага',
#     'lt': 'Praha',
#     'li': 'Praag',
#     'kl': 'Praha',
#     'ko': '프라하',
#     'zu': 'IPraha',
#     'io': 'Praha',
#     'gv': 'Praag',
#     'lv': 'Prāga',
#     'co': 'Praga',
#     'na': 'Praha',
#     'eu': 'Praga',
#     'jv': 'Praha',
#     'sk': 'Praha',
#     'hi': 'प्राग',
#     'vi': 'Praha',
#     'lb': 'Prag',
#     'tl': 'Praga',
#     'br': 'Praha',
#     'bg': 'Прага',
#     'uk': 'Прага',
#     'mk': 'Прага',
#     'et': 'Praha',
#     'af': 'Praag',
#     'mr': 'प्राग',
#     'qu': 'Praha',
#     'ia': 'Praga',
#     'sv': 'Prag',
#     'am': 'ፕራግ',
#     'ar': 'براغ',
#     'sw': 'Praha',
#     'mt': 'Praga',
#     'fa': 'پراگ',
#     'pt': 'Praga',
#     'uz': 'Praga',
#     'sq': 'Praga',
#     'bn': 'প্রাগ',
#     'ug': 'پراگا',
#     'bo': 'པུ་ལ་ཁེ།',
#     'ky': 'Прага',
#     'de': 'Hauptstadt Prag',
#     'tg': 'Прага',
#     'fi': 'Praha',
#     'en': 'Prague'},
#    'lat': 50.0874654,
#    'lon': 14.4212535,
#    'country': 'CZ',
#    'state': 'Prague'}],
#  [{'name': 'Doha',
#    'local_names': {'nl': 'Doha',
#     'es': 'Doha',
#     'jv': 'Doha',
#     'uz': 'Doʻha',
#     'kn': 'ದೊಹಾ',
#     'it': 'Doha',
#     'mn': 'Доха',
#     'de': 'Doha',
#     'tg': 'Дуҳа',
#     'io': 'Doha',
#     'ps': 'دوحه',
#     'my': 'ဒိုဟာမြို့',
#     'cy': 'Doha',
#     'hy': 'Դոհա',
#     'be': 'Доха',
#     'mg': 'Doha',
#     'ms': 'Doha',
#     'lv': 'Doha',
#     'bo': 'དྷོ་ཧ།',
#     'ug': 'دوھا',
#     'ce': 'Духьа',
#     'ar': 'الدوحة',
#     'ne': 'दोहा',
#     'gu': 'દોહા',
#     'hi': 'दोहा, क़तर',
#     'kk': 'Доһа',
#     'bn': 'দোহা',
#     'os': 'Дохæ',
#     'fr': 'Doha',
#     'th': 'โดฮา',
#     'rw': 'Doha',
#     'ba': 'Доһа',
#     'ie': 'Doha',
#     'ur': 'دوحہ',
#     'mk': 'Доха',
#     'oc': 'Doha',
#     'pl': 'Doha',
#     'yi': 'דאכא',
#     'ga': 'Doha',
#     'an': 'Doha',
#     'id': 'Doha',
#     'hu': 'Doha',
#     'so': 'Dooxa',
#     'ky': 'Доха',
#     'ml': 'ദോഹ',
#     'tr': 'Doha',
#     'en': 'Doha',
#     'kl': 'Doha',
#     'fy': 'Doha',
#     'ro': 'Doha',
#     'lt': 'Doha',
#     'sd': 'دوحہ',
#     'lb': 'Doha',
#     'tt': 'Doha',
#     'sl': 'Doha',
#     'ka': 'დოჰა',
#     'gn': 'Doha',
#     'eo': 'Doho',
#     'el': 'Ντόχα',
#     'nn': 'Doha',
#     'ja': 'ドーハ',
#     'yo': 'Doha',
#     'tk': 'Doha',
#     'sk': 'Dauha',
#     'vi': 'Doha',
#     'br': 'Doha',
#     'gr': 'Δοχή',
#     'sn': 'Doha',
#     'fa': 'دوحه',
#     'ta': 'தோகா',
#     'no': 'Doha',
#     'eu': 'Doha',
#     'sq': 'Doha',
#     'sc': 'Doha',
#     'hr': 'Doha',
#     'gl': 'Doha',
#     'gd': 'Doha',
#     'la': 'Doha',
#     'ru': 'Доха',
#     'bg': 'Доха',
#     'af': 'Doha',
#     'zh': '多哈',
#     'vo': 'Däuha',
#     'uk': 'Доха',
#     'sw': 'Doha',
#     'fi': 'Doha',
#     'tl': 'Doha',
#     'sv': 'Doha',
#     'he': 'דוחה',
#     'pt': 'Doha',
#     'az': 'Doha',
#     'bs': 'Doha',
#     'cs': 'Dauhá',
#     'mr': 'दोहा',
#     'am': 'ዶሃ',
#     'da': 'Doha',
#     'is': 'Doha',
#     'ia': 'Doha',
#     'pa': 'ਦੋਹਾ',
#     'et': 'Doha',
#     'sh': 'Doha',
#     'ha': 'Doha',
#     'ko': '도하',
#     'ku': 'Doha',
#     'km': 'ដូហា',
#     'ht': 'Doha',
#     'ca': 'Doha',
#     'sr': 'Доха'},
#    'lat': 25.2856329,
#    'lon': 51.5264162,
#    'country': 'QA'}],
#  [{'name': 'Ro',
#    'lat': 44.9466518,
#    'lon': 11.7626169,
#    'country': 'IT',
#    'state': 'Emilia-Romagna'}],
#  [],
#  [{'name': 'Aachen',
#    'local_names': {'ce': 'Ахен',
#     'uz': 'Axen',
#     'qu': 'Aachen',
#     'ia': 'Aquisgrano',
#     'he': 'אַאכֶן',
#     'fi': 'Aachen',
#     'th': 'อาเคิน',
#     'oc': 'Aquisgran',
#     'eu': 'Akisgran',
#     'li': 'Aoke',
#     'af': 'Aken',
#     'fr': 'Aix-la-Chapelle',
#     'uk': 'Аа́хен',
#     'bg': 'А̀хен',
#     'co': 'Aquisgrana',
#     'ml': 'ആഹ്ഹൻ',
#     'kk': 'Ахен',
#     'mn': 'Аахен',
#     'an': 'Aquisgrán',
#     'el': 'Άαχεν',
#     'tt': 'Ахен',
#     'lv': 'Āhene',
#     'ca': 'Aquisgrà',
#     'az': 'Aaxen',
#     'no': 'Aachen',
#     'sk': 'Aachen',
#     'sl': 'Aachen',
#     'ur': 'آخن',
#     'vo': 'Aachen',
#     'fa': 'آخن',
#     'en': 'Aachen',
#     'id': 'Aachen',
#     'ku': 'Aachen',
#     'sw': 'Aachen',
#     'ga': 'Aachen',
#     'ie': 'Aachen',
#     'ps': 'آخن',
#     'de': 'Aachen',
#     'hy': 'Աախեն',
#     'la': 'Aquisgranum',
#     'mk': 'Ахен',
#     'am': 'አኽን',
#     'cy': 'Aachen',
#     'da': 'Aachen',
#     'gd': 'Aachen',
#     'br': 'Aachen',
#     'ar': 'آخن',
#     'io': 'Aachen',
#     'nb': 'Aachen',
#     'zh': '亚琛',
#     'eo': 'Aachen',
#     'tl': 'Aachen',
#     'wa': 'Åxhe',
#     'ms': 'Aachen',
#     'tr': 'Aachen',
#     'pt': 'Aquisgrão',
#     'lb': 'Oochen',
#     'mr': 'आखन',
#     'es': 'Aquisgrán',
#     'ta': 'ஆஃகன்',
#     'be': 'А́хен',
#     'pl': 'Akwizgran',
#     'nl': 'Aken',
#     'fy': 'Aken',
#     'it': 'Aquisgrana',
#     'ru': 'Ахен',
#     'ro': 'Aachen',
#     'ka': 'აახენი',
#     'cs': 'Cáchy',
#     'ja': 'アーヘン',
#     'ko': '아헨',
#     'is': 'Aachen',
#     'sh': 'Aachen',
#     'sv': 'Aachen',
#     'ky': 'Ахен',
#     'hr': 'Aachen',
#     'bs': 'Aachen',
#     'sr': 'Ахен',
#     'hu': 'Aachen',
#     'tg': 'А́хен',
#     'lt': 'Achenas',
#     'nn': 'Aachen',
#     'et': 'Aachen',
#     'hi': 'आखन',
#     'vi': 'Aachen',
#     'gl': 'Aquisgrán'},
#    'lat': 50.776351,
#    'lon': 6.083862,
#    'country': 'DE',
#    'state': 'North Rhine-Westphalia'}],
#  [{'name': 'Lac',
#    'local_names': {'tr': 'Lac',
#     'ru': 'Лак',
#     'ro': 'Regiunea Lac',
#     'zh': '湖區',
#     'bg': 'Лак',
#     'et': 'Laci piirkond',
#     'hi': 'लाक',
#     'es': 'Lac',
#     'ka': 'ლაკის რეგიონი',
#     'it': 'Regione del Lago',
#     'ja': 'ラク州',
#     'lt': 'Ežero regionas',
#     'en': 'Lac',
#     'de': 'Region See',
#     'ko': '라크주',
#     'fr': 'Lac',
#     'no': 'Lac',
#     'da': 'Lac',
#     'uk': 'Лак',
#     'eu': 'Lac',
#     'pl': 'Lac',
#     'id': 'Region Lac',
#     'fi': 'Lac',
#     'ar': 'البحيرة',
#     'ur': 'لاک علاقہ',
#     'nl': 'Lac',
#     'fa': 'بخش بحیره'},
#    'lat': 13.5820827,
#    'lon': 14.3788329,
#    'country': 'TD'}],
#  [{'name': 'Chancelade',
#    'local_names': {'fr': 'Chancelade', 'oc': 'Chancelada'},
#    'lat': 45.2063889,
#    'lon': 0.6661111,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'Auch',
#    'local_names': {'fr': 'Auch',
#     'zh': '欧什',
#     'an': 'Aush',
#     'br': 'Aush',
#     'ca': 'Aush',
#     'ru': 'Ош',
#     'la': 'Augusta-Auscorum',
#     'bg': 'Ош',
#     'oc': 'Aush',
#     'uk': 'Ош',
#     'sr': 'Ош',
#     'ja': 'オーシュ',
#     'he': 'אוש'},
#    'lat': 43.6463558,
#    'lon': 0.5850507,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Street',
#    'lat': 51.1267494,
#    'lon': -2.7397217,
#    'country': 'GB',
#    'state': 'England'}],
#  [{'name': 'Shah Alam',
#    'local_names': {'en': 'Shah Alam',
#     'ko': '샤알람',
#     'ms': 'Shah Alam',
#     'th': 'ชะฮ์อาลัม',
#     'ru': 'Шах-Алам',
#     'zh': '莎亚南',
#     'my': 'ရှားအလမ်မြို့',
#     'ja': 'シャー・アラム',
#     'ar': 'شاه عالم',
#     'ta': 'ஷா ஆலாம்'},
#    'lat': 3.0733644,
#    'lon': 101.5195149,
#    'country': 'MY',
#    'state': 'Selangor'}],
#  [{'name': 'Essen',
#    'local_names': {'hu': 'Essen',
#     'de': 'Essen',
#     'ja': 'エッセン',
#     'bg': 'Есен',
#     'fa': 'اسن',
#     'mr': 'एसेन',
#     'ru': 'Эссен',
#     'ar': 'إسن',
#     'zh': '埃森',
#     'he': 'אסן',
#     'li': 'Esse',
#     'ug': 'Ésén',
#     'lv': 'Esene',
#     'la': 'Assindia',
#     'ka': 'ესენი',
#     'th': 'เอสเซิน',
#     'el': 'Έσση',
#     'lt': 'Esenas',
#     'cs': 'Essen',
#     'ur': 'ایسن',
#     'uk': 'Ессен',
#     'ko': '에센',
#     'sr': 'Есен',
#     'kk': 'Эссен'},
#    'lat': 51.4582235,
#    'lon': 7.0158171,
#    'country': 'DE',
#    'state': 'North Rhine-Westphalia'}],
#  [{'name': 'Seoul',
#    'local_names': {'mn': 'Сөүл',
#     'th': 'โซล',
#     'ko': '서울',
#     'fr': 'Séoul',
#     'de': 'Seoul',
#     'ru': 'Сеул',
#     'sv': 'Seoul',
#     'an': 'Seúl',
#     'en': 'Seoul',
#     'bg': 'Сеул',
#     'bo': 'སེ་ཨུལ།',
#     'fi': 'Soul',
#     'sl': 'Seul',
#     'vo': 'Söul',
#     'hy': 'Սեուլ',
#     'ur': 'سؤل',
#     'cs': 'Soul',
#     'ta': 'சியோல்',
#     'hi': 'सियोल',
#     'hr': 'Seul',
#     'af': 'Seoel',
#     'es': 'Seúl',
#     'oc': 'Seol',
#     'bh': 'सियोल',
#     'ba': 'Сеул',
#     'zh': '首尔市 / 首爾',
#     'uz': 'Seul',
#     'fa': 'سئول',
#     'qu': 'Siul',
#     'mk': 'Сеул',
#     'yi': 'סעאל',
#     'la': 'Seulum',
#     'bs': 'Seul',
#     'cv': 'Сеул',
#     'ja': 'ソウル',
#     'ky': 'Сеул',
#     'pt': 'Seul',
#     'eu': 'Seul',
#     'ka': 'სეული',
#     'sk': 'Soul',
#     'ro': 'Seul',
#     'tr': 'Seul',
#     'mr': 'सोल',
#     'is': 'Seúl',
#     'my': 'ဆိုးလ်မြို့',
#     'vi': 'Seoul',
#     'pl': 'Seul',
#     'ar': 'سول',
#     'am': 'ሶል',
#     'kn': 'ಸೌಲ್',
#     'hu': 'Szöul',
#     'tk': 'Seul',
#     'lv': 'Seula',
#     'sr': 'Сеул',
#     'uk': 'Сеул',
#     'kk': 'Сеул',
#     'eo': 'Seulo',
#     'bn': 'সিওল',
#     'ml': 'സോൾ',
#     'nl': 'Seoel',
#     'lt': 'Seulas',
#     'ku': 'Sêûl',
#     'km': 'សេអ៊ូល',
#     'az': 'Seul',
#     'el': 'Σεούλ',
#     'et': 'Sŏul',
#     'it': 'Seul',
#     'gl': 'Seúl',
#     'he': 'סיאול',
#     'be': 'Сеул',
#     'ca': 'Seül',
#     'os': 'Сеул',
#     'tg': 'Сеул'},
#    'lat': 37.5666791,
#    'lon': 126.9782914,
#    'country': 'KR'}],
#  [{'name': 'Sandgrube',
#    'lat': 48.8658607,
#    'lon': 12.9046953,
#    'country': 'DE',
#    'state': 'Bavaria'}],
#  [{'name': 'SK',
#    'lat': 3.02872295,
#    'lon': 101.69964770488389,
#    'country': 'MY',
#    'state': 'Selangor'}],
#  [{'name': 'Si',
#    'local_names': {'th': 'สิ', 'en': 'Si'},
#    'lat': 14.6248479,
#    'lon': 104.4510392,
#    'country': 'TH',
#    'state': 'Si Sa Ket Province'}],
#  [{'name': 'Tuzla',
#    'local_names': {'sr': 'Тузла',
#     'hr': 'Tuzla',
#     'ar': 'توزلا',
#     'sq': 'Tuzlla',
#     'bs': 'Tuzla',
#     'de': 'Tuzla',
#     'es': 'Tuzla',
#     'hu': 'Tuzla',
#     'en': 'Tuzla',
#     'fr': 'Tuzla',
#     'ru': 'Тузла',
#     'tr': 'Tuzla'},
#    'lat': 44.5391105,
#    'lon': 18.675193,
#    'country': 'BA',
#    'state': 'Federation of Bosnia and Herzegovina'}],
#  [{'name': 'Arkońskie-Niemierzyn',
#    'local_names': {'pl': 'Arkońskie-Niemierzyn'},
#    'lat': 53.4553042,
#    'lon': 14.5298919,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Hèches',
#    'local_names': {'uk': 'Еш', 'fr': 'Hèches', 'oc': 'Hèishas'},
#    'lat': 43.0174862,
#    'lon': 0.3737441,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Lak',
#    'local_names': {'en': 'Lak', 'fa': 'لک'},
#    'lat': 37.6981704,
#    'lon': 45.0223151,
#    'country': 'IR',
#    'state': 'West Azerbaijan Province'}],
#  [{'name': 'Isdhoo',
#    'local_names': {'dv': 'އިސްދޫ', 'en': 'Isdhoo'},
#    'lat': 2.1189323,
#    'lon': 73.56443470496887,
#    'country': 'MV',
#    'state': 'Haddhunmathi'}],
#  [{'name': 'Steyr',
#    'local_names': {'de': 'Steyr', 'ru': 'Штайр'},
#    'lat': 48.0390046,
#    'lon': 14.4191276,
#    'country': 'AT',
#    'state': 'Upper Austria'}],
#  [{'name': 'Cheux',
#    'local_names': {'uk': 'Ше', 'fr': 'Cheux', 'ru': 'Шё'},
#    'lat': 49.1660575,
#    'lon': -0.5243876,
#    'country': 'FR',
#    'state': 'Normandy'}],
#  [{'name': 'Chandigarh',
#    'local_names': {'he': "צ'אנדיגאר",
#     'ru': 'Чандигарх',
#     'es': 'Chandigarh',
#     'pa': 'ਚੰਡੀਗੜ੍ਹ',
#     'zh': '昌迪加尔中央直辖区',
#     'cs': 'Čandígarh',
#     'de': 'Chandigarh',
#     'ar': 'شانديغار',
#     'ja': 'チャンディーガル',
#     'ku': 'Çandîgar',
#     'ta': 'சண்டிகர்',
#     'en': 'Chandigarh',
#     'ur': 'چندی گڑھ',
#     'uk': 'Чандігарх',
#     'ko': '찬디가르',
#     'eo': 'Ĉandigaro',
#     'fr': 'Chandigarh',
#     'ml': 'ചണ്ഡീഗഢ്',
#     'hi': 'चण्डीगढ़',
#     'te': 'చండీగఢ్',
#     'kn': 'ಚಂಡೀಗಡ'},
#    'lat': 30.7334421,
#    'lon': 76.7797143,
#    'country': 'IN'}],
#  [{'name': 'Dushanbe',
#    'local_names': {'fy': 'Doesjanbe',
#     'fa': 'دوشنبه',
#     'kn': 'ದುಶಾಂಬೆ',
#     'nl': 'Doesjanbe',
#     'ro': 'Dușanbe',
#     'vi': 'Dushanbe',
#     'os': 'Душанбе',
#     'hr': 'Dušanbe',
#     'feature_name': 'Dushanbe',
#     'hy': 'Դուշանբե',
#     'sr': 'Душанбе',
#     'az': 'Düşənbə',
#     'th': 'ดูชานเบ',
#     'is': 'Dúshanbe',
#     'hi': 'दुशान्बे',
#     'es': 'Dusambé',
#     'lt': 'Dušanbė',
#     'oc': 'Doshambe',
#     'el': 'Ντουσαμπέ',
#     'yo': 'Dushanbe',
#     'ug': 'Düshenbe',
#     'sh': 'Dušanbe',
#     'ga': 'Dushanbe',
#     'ta': 'துசான்பே',
#     'kk': 'Душанбе',
#     'ie': 'Dushanbe',
#     'sv': 'Dusjanbe',
#     'cy': 'Dushanbe',
#     'ar': 'دوشنبه',
#     'lv': 'Dušanbe',
#     'sk': 'Dušanbe',
#     'ku': 'Duşenbe',
#     'he': 'דושנבה',
#     'uz': 'Dushanbe',
#     'eo': 'Duŝanbeo',
#     'sl': 'Dušanbej',
#     'tl': 'Dushanbe',
#     'id': 'Dushanbe',
#     'ht': 'Douchanbe',
#     'eu': 'Dushanbe',
#     'ml': 'ദുഷാൻബെ',
#     'ascii': 'Dushanbe',
#     'af': 'Doesjanbe',
#     'tr': 'Duşanbe',
#     'kv': 'Душанбе',
#     'ko': '두샨베',
#     'tt': 'Дүшәнбе',
#     'ru': 'Душанбе',
#     'fi': 'Dušanbe',
#     'pl': 'Duszanbe',
#     'br': 'Douchanbe',
#     'hu': 'Dusanbe',
#     'am': 'ዱሻንቤ',
#     'bn': 'দুশান্\u200cবে',
#     'yi': 'דושאנבע',
#     'ca': 'Duixanbe',
#     'ky': 'Душанбе',
#     'mn': 'Душанбе',
#     'cs': 'Dušanbe',
#     'tg': 'Душанбе',
#     'en': 'Dushanbe',
#     'be': 'Душанбэ',
#     'mk': 'Душанбе',
#     'io': 'Dushanbe',
#     'sq': 'Dushanbe',
#     'it': 'Dušanbe',
#     'mr': 'दुशांबे',
#     'ps': 'دوشنبه',
#     'ur': 'دوشنبہ',
#     'gl': 'Dushanbe',
#     'nn': 'Dusjanbe',
#     'ka': 'დუშანბე',
#     'gd': 'Dushanbe',
#     'bg': 'Душанбе',
#     'bo': 'དུ་ཤང་པེ།',
#     'no': 'Dusjanbe',
#     'fr': 'Douchanbé',
#     'zh': '杜尚别',
#     'bs': 'Dušanbe',
#     'uk': 'Душанбе',
#     'da': 'Dusjanbe',
#     'ja': 'ドゥシャンベ',
#     'sw': 'Dushanbe',
#     'de': 'Duschanbe',
#     'pt': 'Duchambe',
#     'et': 'Dušanbe'},
#    'lat': 38.5762709,
#    'lon': 68.7863573,
#    'country': 'TJ'}],
#  [{'name': 'Tienhaara',
#    'local_names': {'ascii': 'Tienhaara',
#     'feature_name': 'Tienhaara',
#     'en': 'Tienhaara',
#     'fi': 'Tienhaara',
#     'ru': 'Калинино'},
#    'lat': 60.7547446,
#    'lon': 28.6486315,
#    'country': 'RU',
#    'state': 'Leningrad oblast'}],
#  [{'name': 'TT',
#    'lat': 18.3449742,
#    'lon': 97.0033054204086,
#    'country': 'MM',
#    'state': 'Bago Region'}],
#  [{'name': 'Athens',
#    'local_names': {'ar': 'أثينا',
#     'kv': 'Афинъяс',
#     'tk': 'Afiny',
#     'tl': 'Atenas',
#     'nl': 'Athene',
#     'wo': 'Aten',
#     'pt': 'Atenas',
#     'bo': 'ཨ་ཐེན།',
#     'tr': 'Atina',
#     'yo': 'Áténì',
#     'cv': 'Афин',
#     'el': 'Αθήνα',
#     'id': 'Athena',
#     'no': 'Aten',
#     'nn': 'Aten',
#     'cu': 'Аѳинꙑ',
#     'an': 'Atenas',
#     'os': 'Афинæтæ',
#     'la': 'Athenae',
#     'ja': 'アテネ',
#     'oc': 'Atenas',
#     'th': 'เอเธนส์',
#     'co': 'Atene',
#     'am': 'አቴና',
#     'zh': '雅典',
#     'gl': 'Atenas',
#     'vi': 'Athena',
#     'ko': '아테네',
#     'io': 'Athina',
#     'my': 'အေသင်မြို့',
#     'lb': 'Athen',
#     'de': 'Athen',
#     'ga': 'An Aithin',
#     'te': 'ఏథెన్స్',
#     'sc': 'Atene',
#     'br': 'Aten',
#     'hu': 'Athén',
#     'ie': 'Athina',
#     'ca': 'Atenes',
#     'sk': 'Atény',
#     'jv': 'Aténa',
#     'ht': 'Atèn',
#     'mr': 'अथेन्स',
#     'uz': 'Afina',
#     'sr': 'Атина',
#     'mk': 'Атина',
#     'fa': 'آتن',
#     'fy': 'Atene',
#     'ascii': 'Athina',
#     'mn': 'Афин',
#     'gn': 'Atena',
#     'af': 'Athene',
#     'eu': 'Atenas',
#     'et': 'Ateena',
#     'se': 'Athena',
#     'hy': 'Աթենք',
#     'uk': 'Афіни',
#     'ta': 'ஏதென்ஸ்',
#     'ml': 'ഏതൻസ്\u200c',
#     'cy': 'Athen',
#     'feature_name': 'Athina',
#     'kw': 'Athína',
#     'sv': 'Aten',
#     'it': 'Atene',
#     'tt': 'Афиннар',
#     'he': 'אתונה',
#     'mi': 'Ātene',
#     'ug': 'ئافېنا',
#     'zu': 'I-Athene',
#     'eo': 'Ateno',
#     'sh': 'Atena',
#     'ru': 'Афины',
#     'gd': 'An Àithne',
#     'ur': 'ایتھنز',
#     'hr': 'Atena',
#     'kn': 'ಅಥೆನ್ಸ್',
#     'fi': 'Ateena',
#     'is': 'Aþena',
#     'bg': 'Атина',
#     'bn': 'অ্যাথেন্স',
#     'ro': 'Atena',
#     'yi': 'אטען',
#     'ka': 'ათენი',
#     'ln': 'Atenis',
#     'ia': 'Athenas',
#     'vo': 'Atina',
#     'az': 'Afina',
#     'ba': 'Афина',
#     'gv': 'Yn Atheen',
#     'mt': 'Ateni',
#     'wa': 'Atene',
#     'cs': 'Athény',
#     'fr': 'Athènes',
#     'be': 'Афіны',
#     'hi': 'एथेंस',
#     'sw': 'Athens',
#     'es': 'Atenas',
#     'sq': 'Athina',
#     'sl': 'Atene',
#     'pl': 'Ateny',
#     'en': 'Athens',
#     'lt': 'Atėnai',
#     'tw': 'Athens',
#     'li': 'Athene',
#     'kk': 'Афина',
#     'qu': 'Athina',
#     'lv': 'Atēnas',
#     'ms': 'Athens',
#     'bs': 'Atina',
#     'ku': 'Atîna'},
#    'lat': 37.9839412,
#    'lon': 23.7283052,
#    'country': 'GR',
#    'state': 'Attica'}],
#  [{'name': 'Torre', 'lat': 39.9634843, 'lon': -6.9406539, 'country': 'PT'}],
#  [{'name': 'Ua',
#    'lat': -8.8613303,
#    'lon': 121.2037997,
#    'country': 'ID',
#    'state': 'East Nusa Tenggara'}],
#  [{'name': 'Ae',
#    'lat': -0.6858283,
#    'lon': -48.04675,
#    'country': 'BR',
#    'state': 'Pará'}],
#  [{'name': 'Geva',
#    'local_names': {'en': 'Geva', 'fr': 'Geva', 'he': 'גבע'},
#    'lat': 32.5663362,
#    'lon': 35.3715486,
#    'country': 'IL',
#    'state': 'North District'}],
#  [{'name': 'Us',
#    'lat': 49.1009451,
#    'lon': 1.9672466,
#    'country': 'FR',
#    'state': 'Ile-de-France'}],
#  [{'name': 'Wei County',
#    'local_names': {'vi': 'Uy', 'fr': 'Wei', 'en': 'Wei County', 'zh': '威县'},
#    'lat': 36.9820674,
#    'lon': 115.2666089,
#    'country': 'CN',
#    'state': 'Hebei'}],
#  [{'name': 'Uz',
#    'local_names': {'fr': 'Uz', 'oc': 'Us', 'uk': 'Юз', 'ca': 'Us'},
#    'lat': 42.9663688,
#    'lon': -0.0852324,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Ye County',
#    'local_names': {'en': 'Ye County', 'zh': '叶县', 'vi': 'Diệp'},
#    'lat': 33.54912,
#    'lon': 113.361272,
#    'country': 'CN',
#    'state': 'Henan'}],
#  [{'name': '`Azm',
#    'local_names': {'ar': 'عظم',
#     'en': '`Azm',
#     'ascii': '‘Az̧m',
#     'feature_name': '‘Az̧m'},
#    'lat': 14.893993,
#    'lon': 43.749254,
#    'country': 'YE',
#    'state': "Sana'a Governorate"}],
#  [{'name': 'زو',
#    'lat': 37.735917,
#    'lon': 57.77137,
#    'country': 'IR',
#    'state': 'North Khorasan Province'}]]

# %%
#Loading the co-ordinate data into lists
for r in response_api:
    if len(r)>=1:
        latitude.append(r[0]['lat'])
        longitude.append(r[0]['lon'])
    else:
        latitude.append('')
        longitude.append((''))

# %%
#Creating new dataframe with country codes, latitude and longitude
country_info_df=pd.DataFrame({'country':countries_names, 'Lat':latitude,'Long':longitude})

# %%
country_info_df.head()
# Out:
#        country        Lat        Long
# 0  afghanistan  54.235921   -4.514767
# 1      albania  36.717202   59.666131
# 2      algeria  36.392117 -107.834908
# 3      andorra  47.292376   23.020988
# 4       angola  34.626275  135.605845

# %%
import os  
os.makedirs('Resources', exist_ok=True)  
country_info_df.to_csv('./Resources/GeoLoc.csv', index=False)
