# %% [markdown]
# # Project 3 - Books

# %%
# Dependencies
import requests
import pandas as pd
from pprint import pprint

# %%
booksSmall_df = pd.read_csv('./Resources/Books.csv')
booksSmall_df[booksSmall_df['Year-Of-Publication']==2004]
# Out:
#       Unnamed: 0.1  Unnamed: 0        ISBN  \
# 12              12          12   887841740
# 26              26          26   971880107
# 117            117         117   553584383
# 120            120         120   316735736
# 223            225         225  140003180X
# 249            251         251   373836023
# 265            267         267   451526341
# 308            311         311   312988699
# 354            358         358   743470389
# 437            441         441   316168815
# 556            561         561   425182878
# 559            564         564   743412621
# 581            586         586   821772953
# 601            606         606  193072229X
# 604            610         610   312995431
# 605            611         611   312312628
# 621            628         628    60575808
# 622            629         629    60558865
# 623            630         630   767912918
# 673            680         680   316735027
# 876            890         890   451155750
# 928            942         942   515134368
# 936            950         950   892967994
# 1008          1023        1023   375507256
# 1019          1034        1034   975311255
# 1282          1303        1303   671573020
# 1323          1344        1344   399242562
# 1392          1416        1416   385510438
# 1417          1441        1441  1400062888
# 1499          1523        1523   142004030
# 1532          1556        1556   425163385
# 1671          1699        1699   312423209
# 1695          1724        1724    60514949
# 1715          1744        1744   312423799
# 1730          1759        1759  1555973981
# 1741          1770        1770  1590171012
# 1742          1771        1771    60505273
# 1751          1781        1781   883659654
# 1774          1804        1804   743437810
# 1975          2010        2010  1593080743
# 1996          2031        2031    60972459
#
#                                              Book-Title  \
# 12                                   The Middle Stories
# 26                                          Wild Animus
# 117                                            Dead Aim
# 120                         All He Ever Wanted: A Novel
# 223   The Kalahari Typing School for Men (No. 1 Ladi...
# 249                                    Powder and Patch
# 265                                         Animal Farm
# 308                                      Nowhere To Run
# 354                                     The Snow Garden
# 437                                    The Lovely Bones
# 556                                         Chosen Prey
# 559                    The Second Time Around : A Novel
# 581                                   The Morning After
# 601   MoveOn's 50 Ways to Love Your Country: How to ...
# 604   A Fountain Filled With Blood (A Rev. Clare Fer...
# 605   Out of the Deep I Cry : A Clare Fergusson/Russ...
# 621                      Two Princesses of Bamarre, The
# 622                               Ella Enchanted (rack)
# 623   Passing for Thin : Losing Half My Weight and F...
# 673   The True and Outstanding Adventures of the Hun...
# 876                                       The Dead Zone
# 928                                   The Penwyth Curse
# 936        The Fractal Murders (Pepper Keane Mysteries)
# 1008                              Cloud Atlas : A Novel
# 1019                               A Temporary New Wife
# 1282          Divining Women (Ay Spoken Word - Gibbons)
# 1323                                       Shadowmancer
# 1392                                     The Last Juror
# 1417  Obliviously On He Sails : The Bush Administrat...
# 1499  Lost in a Good Book (Thursday Next Novels (Pen...
# 1532                                     The Night Crew
# 1671                                  Mason &amp; Dixon
# 1695                                        Dead Ringer
# 1715                                     Dry : A Memoir
# 1730                                             Baby B
# 1741  The Magic Pudding: Being the Adventures of Bun...
# 1742  The Sewing Circles of Herat : A Personal Voyag...
# 1751  The Company of Cats : 20 Contemporary Stories ...
# 1774  The Vanished Man : A Lincoln Rhyme Novel (Linc...
# 1975                               The Age of Innocence
# 1996                                          Tracks RI
#
#                  Book-Author  Year-Of-Publication  \
# 12               Sheila Heti                 2004
# 26              Rich Shapero                 2004
# 117            IRIS JOHANSEN                 2004
# 120             Anita Shreve                 2004
# 223   ALEXANDER MCCALL SMITH                 2004
# 249          Georgette Heyer                 2004
# 265            George Orwell                 2004
# 308          Mary Jane Clark                 2004
# 354         Christopher Rice                 2004
# 437             Alice Sebold                 2004
# 556            John Sandford                 2004
# 559       Mary Higgins Clark                 2004
# 581             Lisa Jackson                 2004
# 601                   Moveon                 2004
# 604    Julia Spencer-Fleming                 2004
# 605    Julia Spencer-Fleming                 2004
# 621       Gail Carson Levine                 2004
# 622       Gail Carson Levine                 2004
# 623           FRANCES KUFFEL                 2004
# 673       Elisabeth Robinson                 2004
# 876             Stephen King                 2004
# 928        Catherine Coulter                 2004
# 936               Mark Cohen                 2004
# 1008          DAVID MITCHELL                 2004
# 1019         Malcolm Goodway                 2004
# 1282            Kaye Gibbons                 2004
# 1323            G. P. Taylor                 2004
# 1392            John Grisham                 2004
# 1417          CALVIN TRILLIN                 2004
# 1499           Jasper Fforde                 2004
# 1532           John Sandford                 2004
# 1671          Thomas Pynchon                 2004
# 1695         Lisa Scottoline                 2004
# 1715      Augusten Burroughs                 2004
# 1730            Michael Ryan                 2004
# 1741          Norman Lindsay                 2004
# 1742          Christina Lamb                 2004
# 1751        Michael J. Rosen                 2004
# 1774          Jeffery Deaver                 2004
# 1975           Edith Wharton                 2004
# 1996          Louise Erdrich                 2004
#
#                                   Publisher
# 12                    House of Anansi Press
# 26                                  Too Far
# 117                            Bantam Books
# 120                          Back Bay Books
# 223                                  Anchor
# 249                               Harlequin
# 265                                  Signet
# 308                 St. Martin's Paperbacks
# 354                             Pocket Star
# 437                          Back Bay Books
# 556                Berkley Publishing Group
# 559                                  Pocket
# 581                             Zebra Books
# 601                  Inner Ocean Publishing
# 604                 St. Martin's Paperbacks
# 605                   St. Martin's Minotaur
# 621                                     Eos
# 622                                    Avon
# 623                                Broadway
# 673                           Little, Brown
# 876                             Signet Book
# 928                              Jove Books
# 936                        Mysterious Press
# 1008          Random House Trade Paperbacks
# 1019           AuthorsOmniscient Publishers
# 1282                             Audioworks
# 1323                Putnam Publishing Group
# 1392                              Doubleday
# 1417                           Random House
# 1499                          Penguin Books
# 1532               Berkley Publishing Group
# 1671                                Picador
# 1695                            HarperTorch
# 1715                                Picador
# 1730                         Graywolf Press
# 1741  New York Review Children's Collection
# 1742                              Perennial
# 1751                                Galahad
# 1774                           Pocket Books
# 1975       Barnes &amp; Noble Books-Imports
# 1996                              Perennial

# %%
#Creating dataframes from csv files to read the data
# books_df = pd.read_csv('./Resources2/Books.csv')
books_df = booksSmall_df[booksSmall_df['Year-Of-Publication'] != 0]
users_df = pd.read_csv('./Resources/Users.csv')
ratings_df = pd.read_csv('./Resources/Ratings.csv')
geoloc_df = pd.read_csv('./Resources/GeoLoc.csv')

# %%
books_df.head()
# Out:
#    Unnamed: 0       ISBN                                         Book-Title  \
# 0           0  195153448                                Classical Mythology
# 1           1    2005018                                       Clara Callan
# 2           2   60973129                               Decision in Normandy
# 3           3  374157065  Flu: The Story of the Great Influenza Pandemic...
# 4           4  393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 0 to 2034
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           2000 non-null   int64
#  1   ISBN                 2000 non-null   object
#  2   Book-Title           2000 non-null   object
#  3   Book-Author          2000 non-null   object
#  4   Year-Of-Publication  2000 non-null   int64
#  5   Publisher            2000 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 109.4+ KB

# %%
users_df.head()
# Out:
#    Unnamed: 0  User-ID       Location
# 0           7        8         canada
# 1          11       12  united states
# 2          20       22        germany
# 3          61       64         france
# 4          66       69         canada

# %%
ratings_df.head()
# Out:
#    Unnamed: 0  User-ID        ISBN  Book-Rating
# 0         273   276939  2253063339            9
# 1         353   276994  3596214629            8
# 2         397   277072  1573229571            9
# 3         573   277212  044023722X            8
# 4         699   277427  039304016X            8

# %%
geoloc_df.head()
# Out:
#    Unnamed: 0    country        Lat       Long
# 0           8  australia  47.756392   7.019443
# 1           9    austria  50.628868   3.785318
# 2          11    bahamas  42.187800  22.387652
# 3          16    belgium  52.517037  13.388860
# 4          19    bermuda  29.105986  58.356566

# %%
isbn=books_df['ISBN'].unique()
isbn
# Out:
# array(['195153448', '2005018', '60973129', ..., '805012478', '60975547',
#        '375704000'], dtype=object)

# %%
newratings=ratings_df[ratings_df['ISBN'].isin(isbn)]
newratings
# Out:
#       Unnamed: 0  User-ID        ISBN  Book-Rating
# 0            273   276939  2253063339            9
# 2            397   277072  1573229571            9
# 3            573   277212  044023722X            8
# 4            699   277427  039304016X            8
# 5            825   277435  031215125X            8
# ...          ...      ...         ...          ...
# 4781      433104   276394  1853260053           10
# 4782      433107   276401  006019491X            7
# 4783      433183   276487  8420725927            6
# 4784      433385   276602  3453212150            8
# 4785      433410   276634  039456894X            8
#
# [4678 rows x 4 columns]

# %%
users=newratings['User-ID'].unique()
users
# Out:
# array([276939, 277072, 277212, ..., 276487, 276602, 276634])

# %%
new_users=users_df[users_df['User-ID'].isin(users)]
new_users
# Out:
#       Unnamed: 0  User-ID       Location
# 0              7        8         canada
# 1             11       12  united states
# 2             20       22        germany
# 3             61       64         france
# 4             66       69         canada
# ...          ...      ...            ...
# 3578      272884   278390  united states
# 3579      272912   278418  united states
# 3580      273073   278582  united states
# 3581      273318   278832  united states
# 3582      273337   278851  united states
#
# [3511 rows x 3 columns]

# %%
locations=new_users['Location'].unique()
locations
# Out:
# array(['canada', 'united states', 'germany', 'france', 'spain',
#        'united kingdom', 'portugal', 'finland', 'italy', 'austria',
#        'netherlands', 'switzerland', 'malaysia', 'australia', 'chile',
#        'philippines', 'india', 'belgium', 'new zealand', 'slovenia',
#        'costa rica', 'israel', 'ireland', 'romania', 'sweden',
#        'hong kong', 'china', 'qatar', 'kuwait', 'iran', 'singapore',
#        'hungary', 'bermuda', 'venezuela', 'bahamas', 'saudi arabia',
#        'united arab emirates', 'norway', 'brazil', 'luxembourg',
#        'bulgaria', 'mexico', 'saint lucia', 'egypt', 'dominican republic',
#        'trinidad and tobago', 'czech republic', 'denmark'], dtype=object)

# %%
new_locations=geoloc_df[geoloc_df['country'].isin(locations)]
new_locations
# Out:
#     Unnamed: 0               country        Lat        Long
# 0            8             australia  47.756392    7.019443
# 1            9               austria  50.628868    3.785318
# 2           11               bahamas  42.187800   22.387652
# 3           16               belgium  52.517037   13.388860
# 4           19               bermuda  29.105986   58.356566
# 5           24                brazil  42.097974   19.095453
# 6           26              bulgaria  45.694495    9.669873
# 7           30                canada -22.182269  -44.687760
# 8           34                 chile  51.690125   -9.513148
# 9           35                 china  19.309117  100.164750
# 10          39            costa rica  41.365070  -95.858422
# 11          43        czech republic  49.803763   15.474913
# 12          44               denmark  25.285633   51.526416
# 13          47    dominican republic  42.900072   18.029807
# 14          49                 egypt  56.907925   -6.160064
# 15          56               finland  14.068543   -5.485479
# 16          57                france  46.810124    7.171828
# 17          61               germany  47.352115    5.000833
# 18          73             hong kong  31.086905   53.300639
# 19          74               hungary  31.232276  121.469207
# 20          76                 india  66.878996   13.446508
# 21          78                  iran  32.420742   53.683016
# 22          80               ireland  26.721715  127.786429
# 23          81                israel  45.805559    1.223826
# 24          82                 italy  45.662889   10.118138
# 25          92                kuwait  32.928173   35.075638
# 26         101            luxembourg  29.153922  105.378895
# 27         106              malaysia  34.130278  107.835000
# 28         113                mexico  25.201939   55.154197
# 29         124           netherlands  31.742846   50.179326
# 30         125           new zealand  34.736005   36.301103
# 31         131                norway  45.829940   24.283058
# 32         139           philippines  11.697835  122.621754
# 33         141              portugal  50.801766   21.423828
# 34         143                 qatar  25.285633   51.526416
# 35         144               romania  44.946652   11.762617
# 36         148           saint lucia  13.582083   14.378833
# 37         153          saudi arabia   3.073364  101.519515
# 38         158             singapore  48.865861   12.904695
# 39         160              slovenia  14.624848  104.451039
# 40         165                 spain  43.017486    0.373744
# 41         169                sweden  49.166058   -0.524388
# 42         170           switzerland  30.733442   76.779714
# 43         178   trinidad and tobago  18.344974   97.003305
# 44         184  united arab emirates  -0.685828  -48.046750
# 45         185        united kingdom  32.566336   35.371549
# 46         186         united states  49.100945    1.967247
# 47         190             venezuela   5.163296  -69.414670

# %%
new_locations.to_csv('./Resources/GeoLoc.csv')

# %%
new_users.to_csv('./Resources/Users.csv')

# %%
newratings.to_csv('./Resources/Ratings.csv')

# %%
books_df.to_csv('./Resources/Books.csv')
