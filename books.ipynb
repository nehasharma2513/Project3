# %% [markdown]
# # Project 3 - Books

# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint
import pycountry
pd.options.display.max_colwidth = 200

# Import the API key
from config import api_key

# %%
#Creating dataframes from csv files to read the data
books_df = pd.read_csv('./Resources/books.csv')
users_df = pd.read_csv('./Resources/users.csv')
ratings_df = pd.read_csv('./Resources/ratings.csv')
# Out:
# C:\Users\nehas\AppData\Local\Temp\ipykernel_3952\237644461.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_df = pd.read_csv('./Resources/books.csv')

# %%
books_df.head()
# Out:
#          ISBN  \
# 0  0195153448
# 1  0002005018
# 2  0060973129
# 3  0374157065
# 4  0393045218
#
#                                                                                            Book-Title  \
# 0                                                                                 Classical Mythology
# 1                                                                                        Clara Callan
# 2                                                                                Decision in Normandy
# 3  Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It
# 4                                                                              The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg
# 1  http://images.amazon.com/images/P/0002005018.01.THUMBZZZ.jpg
# 2  http://images.amazon.com/images/P/0060973129.01.THUMBZZZ.jpg
# 3  http://images.amazon.com/images/P/0374157065.01.THUMBZZZ.jpg
# 4  http://images.amazon.com/images/P/0393045218.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0060973129.01.MZZZZZZZ.jpg
# 3  http://images.amazon.com/images/P/0374157065.01.MZZZZZZZ.jpg
# 4  http://images.amazon.com/images/P/0393045218.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/0060973129.01.LZZZZZZZ.jpg
# 3  http://images.amazon.com/images/P/0374157065.01.LZZZZZZZ.jpg
# 4  http://images.amazon.com/images/P/0393045218.01.LZZZZZZZ.jpg

# %%
users_df.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings_df.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
#Finding the size of each dataframe
print(books_df.shape)
print(users_df.shape)
print(ratings_df.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
#Following code has steps to get co-ordinate information of the unique countries in the dataset

# %%
#Reading the cleanCountries csv file and adding it to countries dataframe
column_name=['Country']
countries_df = pd.read_csv("./Resources/cleanCountries.csv",header=None, names=column_name)
countries_df.head()
# Out:
#        Country
# 0  afghanistan
# 1      albania
# 2      algeria
# 3      andorra
# 4       angola

# %%
#Finding the unique countries 
countries_unique=countries_df['Country'].unique()

# %%
#Transforming the data into list
countries_data=countries_unique.tolist()

# %%
countries_data
# Out:
# ['afghanistan',
#  'albania',
#  'algeria',
#  'andorra',
#  'angola',
#  'antigua and barbuda',
#  'argentina',
#  'armenia',
#  'australia',
#  'austria',
#  'azerbaijan',
#  'bahamas',
#  'bahrain',
#  'bangladesh',
#  'barbados',
#  'belgium',
#  'belize',
#  'benin',
#  'bermuda',
#  'bhutan',
#  'bolivia',
#  'bosnia and herzegovina',
#  'botswana',
#  'brazil',
#  'brunei',
#  'bulgaria',
#  'burkina faso',
#  'burma',
#  'cameroon',
#  'canada',
#  'cape verde',
#  'chile',
#  'china',
#  'colombia',
#  'connecticut',
#  'costa rica',
#  'cote d`ivoire',
#  'Country',
#  'croatia',
#  'cuba',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'dominica',
#  'dominican republic',
#  'east africa',
#  'ecuador',
#  'egypt',
#  'england',
#  'equatorial geuinea',
#  'eritrea',
#  'estonia',
#  'ethiopia',
#  'faroe islands',
#  'fernando de la mora',
#  'fiji',
#  'finland',
#  'florida',
#  'france',
#  'gabon',
#  'gambia',
#  'georgia',
#  'germany',
#  'ghana',
#  'greece',
#  'grenada',
#  'guatemala',
#  'guinea-bissau',
#  'guyana',
#  'haiti',
#  'honduras',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'iowa',
#  'iran',
#  'iraq',
#  'ireland',
#  'israel',
#  'italy',
#  'jamaica',
#  'japan',
#  'jordan',
#  'kazakhstan',
#  'kenya',
#  'kuwait',
#  'kyrgyzstan',
#  'laos',
#  'latvia',
#  'lebanon',
#  'lesotho',
#  'lithuania',
#  'luxembourg',
#  'macedonia',
#  'madagascar',
#  'malaysia',
#  'maldives',
#  'mali',
#  'malta',
#  'mauritania',
#  'mauritius',
#  'mexico',
#  'micronesia',
#  'moldova',
#  'monaco',
#  'mongolia',
#  'montenegro',
#  'morocco',
#  'mozambique',
#  'namibia',
#  'nepal',
#  'netherlands',
#  'new zealand',
#  'nicaragua',
#  'nigeria',
#  'north korea',
#  'northern ireland',
#  'norway',
#  'oman',
#  'pakistan',
#  'panama',
#  'papua new guinea',
#  'paraguay',
#  'pennsylvania',
#  'peru',
#  'philippines',
#  'poland',
#  'portugal',
#  'puerto rico',
#  'qatar',
#  'romania',
#  'russia',
#  'rwanda',
#  'saint kitts and nevis',
#  'saint lucia',
#  'saint vincent and the grenadines',
#  'samoa',
#  'sao tome and principe',
#  'saudi arabia',
#  'scotland',
#  'senegal',
#  'serbia & montenegro',
#  'sierra leone',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'somalia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'sudan',
#  'suriname',
#  'sweden',
#  'switzerland',
#  'syria',
#  'taiwan',
#  'tajikistan',
#  'tanzania',
#  'thailand',
#  'the gambia',
#  'trinidad',
#  'trinidad and tobago',
#  'tunisia',
#  'turkey',
#  'ukraine',
#  'united arab emirates',
#  'united kingdom',
#  'united states',
#  'uruguay',
#  'uzbekistan',
#  'venezuela',
#  'vietnam',
#  'wales',
#  'yemen',
#  'zambia',
#  'zimbabwe']

# %%
 #!pip install pycountry

# %%
#Using openweathermap API to get latitude and longitude for each country code(obtained from pycountry)
url = "http://api.openweathermap.org/geo/1.0/direct?"
new_query_url = url + "appid=" + api_key + "&q="

# Set up empty lists to hold the API response
latitude = []
longitude = []
country_codes=[]
response_api=[]
for country in countries_data:
        # Convert country name to ISO country code
    try:
        country_code = pycountry.countries.get(name=country).alpha_2
         # Make API request
        country_codes.append(country_code)
        print(country_code)
    except AttributeError:
        print(f"Could not find ISO code for {country}")
        continue
# Out:
# AF
# AL
# DZ
# AD
# AO
# AG
# AR
# AM
# AU
# AT
# AZ
# BS
# BH
# BD
# BB
# BE
# BZ
# BJ
# BM
# BT
# Could not find ISO code for bolivia
# BA
# BW
# BR
# Could not find ISO code for brunei
# BG
# BF
# Could not find ISO code for burma
# CM
# CA
# Could not find ISO code for cape verde
# CL
# CN
# CO
# Could not find ISO code for connecticut
# CR
# Could not find ISO code for cote d`ivoire
# Could not find ISO code for Country
# HR
# CU
# CY
# Could not find ISO code for czech republic
# DK
# DM
# DO
# Could not find ISO code for east africa
# EC
# EG
# Could not find ISO code for england
# Could not find ISO code for equatorial geuinea
# ER
# EE
# ET
# FO
# Could not find ISO code for fernando de la mora
# FJ
# FI
# Could not find ISO code for florida
# FR
# GA
# GM
# GE
# DE
# GH
# GR
# GD
# GT
# GW
# GY
# HT
# HN
# HK
# HU
# IS
# IN
# ID
# Could not find ISO code for iowa
# Could not find ISO code for iran
# IQ
# IE
# IL
# IT
# JM
# JP
# JO
# KZ
# KE
# KW
# KG
# Could not find ISO code for laos
# LV
# LB
# LS
# LT
# LU
# Could not find ISO code for macedonia
# MG
# MY
# MV
# ML
# MT
# MR
# MU
# MX
# Could not find ISO code for micronesia
# Could not find ISO code for moldova
# MC
# MN
# ME
# MA
# MZ
# NA
# NP
# NL
# NZ
# NI
# NG
# Could not find ISO code for north korea
# Could not find ISO code for northern ireland
# NO
# OM
# PK
# PA
# PG
# PY
# Could not find ISO code for pennsylvania
# PE
# PH
# PL
# PT
# PR
# QA
# RO
# Could not find ISO code for russia
# RW
# KN
# LC
# VC
# WS
# ST
# SA
# Could not find ISO code for scotland
# SN
# Could not find ISO code for serbia & montenegro
# SL
# SG
# SK
# SI
# SO
# ZA
# Could not find ISO code for south korea
# ES
# LK
# SD
# SR
# SE
# CH
# Could not find ISO code for syria
# Could not find ISO code for taiwan
# TJ
# Could not find ISO code for tanzania
# TH
# Could not find ISO code for the gambia
# Could not find ISO code for trinidad
# TT
# TN
# TR
# UA
# AE
# GB
# US
# UY
# UZ
# Could not find ISO code for venezuela
# Could not find ISO code for vietnam
# Could not find ISO code for wales
# YE
# ZM
# ZW

# %%
len(country_codes)
# Out:
# 145

# %%
#Sending API request to get response
for c in country_codes:
    response = requests.get(f"{new_query_url}{c}").json()
    response_api.append(response)

# %%
len(response_api)
# Out:
# 145

# %%
response_api
# Out:
# [[{'name': 'Isle of Man',
#    'local_names': {'sl': 'Otok Man',
#     'hr': 'Otok Man',
#     'su': 'Pulo Man',
#     'ia': 'Insula de Man',
#     'gl': 'Illa de Man',
#     'qu': "Man wat'a",
#     'fo': 'Isle of Man',
#     'fi': 'Mansaari',
#     'sc': 'ìsula de Man',
#     'pt': 'Ilha de Man',
#     'it': 'Isola di Man',
#     'ro': 'Insula Man',
#     'dv': 'އައިޒަލް އޮފް މޭން',
#     'lv': 'Menas Sala',
#     'fy': 'Man',
#     'hi': 'मनुष्य का टापू',
#     'ur': 'آئل آف مین',
#     'ja': 'マン島',
#     'la': 'Monapia',
#     'bg': 'Ман',
#     'cs': 'Ostrov Man',
#     'se': 'Mannin',
#     'hy': 'Մեն կղզի',
#     'ml': 'ഐൽ ഒഫ് മാൻ',
#     'bn': 'আইল অফ ম্যান',
#     'hu': 'Man',
#     'is': 'Mön',
#     'os': 'Мэны сакъадах',
#     'sk': 'Ostrov Man',
#     'lt': 'Meno sala',
#     'da': 'Isle of Man',
#     'ar': 'جزيرة مان',
#     'de': 'Isle of Man',
#     'cy': 'Ynys Manaw',
#     'ko': '맨 섬',
#     'gd': 'Eilean Mhanainn',
#     'ms': 'Pulau Man',
#     'af': 'Man',
#     'vi': 'Đảo Man',
#     'mk': 'Ман',
#     'ky': 'Мэн аралы',
#     'mr': 'आईल ऑफ मान',
#     'ru': 'О́стров Мэн',
#     'ca': 'Man',
#     'be': 'Востраў Мэн',
#     'et': 'Man',
#     'nl': 'Man',
#     'br': 'Manav',
#     'an': 'Isla de Man',
#     'io': 'Man',
#     'th': 'เกาะแมน',
#     'yo': 'Erékùṣù ilẹ̀ Man',
#     'fa': 'جزیرهٔ مَن',
#     'kk': 'Мэн',
#     'sh': 'Ostrvo Man',
#     'zh': '马恩岛',
#     'jv': 'Pulo Man',
#     'eu': 'Man',
#     'sq': 'Ishulli i Njeriut',
#     'kw': 'Manow',
#     'oc': 'Illa de Man',
#     'es': 'isla de Man',
#     'sw': 'Isle of Man',
#     'tl': 'Pulo ng Man',
#     'rw': 'Ikirwa cya Man',
#     'el': 'νησί του Μαν',
#     'bs': 'Ostrvo Man',
#     'mi': 'Motu o Man',
#     'li': 'Eiland Man',
#     'en': 'Isle of Man',
#     'pa': 'ਆਇਲ ਆਫ਼ ਮੈਨ',
#     'pl': 'Wyspa Man',
#     'ha': 'Isle of Man',
#     'gv': 'Mannin',
#     'ga': 'Manainn',
#     'id': 'Pulau Man',
#     'tr': 'Man Adası',
#     'sr': 'Острво Мен',
#     'nn': 'Man',
#     'he': 'האי מאן',
#     'uk': 'Острів Мен',
#     'ta': 'மாண் தீவு',
#     'no': 'Man',
#     'tt': 'Мэн утравы',
#     'ka': 'კუნძული მენი',
#     'sv': 'Isle of Man',
#     'cv': 'Мэн утравĕ',
#     'az': 'Men adası',
#     'eo': 'Manksinsulo',
#     'fr': 'île de Man'},
#    'lat': 54.23592075,
#    'lon': -4.514766902315387,
#    'country': 'IM'}],
#  [{'name': 'Al',
#    'local_names': {'en': 'Al', 'fa': 'آل'},
#    'lat': 36.7172018,
#    'lon': 59.6661311,
#    'country': 'IR',
#    'state': 'Razavi Khorasan'}],
#  [{'name': 'Dzilth-Na-O-Dith-Hle',
#    'local_names': {'en': 'Dzilth-Na-O-Dith-Hle'},
#    'lat': 36.3921169,
#    'lon': -107.834908,
#    'country': 'US',
#    'state': 'New Mexico'}],
#  [{'name': 'Dioșod',
#    'local_names': {'uk': 'Діошод', 'hu': 'Diósad', 'ro': 'Dioșod'},
#    'lat': 47.2923759,
#    'lon': 23.0209883,
#    'country': 'RO'}],
#  [{'name': 'Yao',
#    'local_names': {'en': 'Yao',
#     'ar': 'ياو، أوساكا',
#     'fr': 'Yao',
#     'ko': '야오시',
#     'zh': '八尾市',
#     'ru': 'Яо',
#     'uk': 'Яо',
#     'pl': 'Yao',
#     'de': 'Yao',
#     'ja': '八尾市',
#     'es': 'Yao'},
#    'lat': 34.626275,
#    'lon': 135.605845,
#    'country': 'JP',
#    'state': 'Osaka Prefecture'}],
#  [{'name': 'Ág',
#    'local_names': {'hu': 'Ág', 'ru': 'Аг'},
#    'lat': 46.2959997,
#    'lon': 18.204151,
#    'country': 'HU'}],
#  [{'name': 'Junction City',
#    'lat': 33.021446100000006,
#    'lon': -92.72446250787544,
#    'country': 'US',
#    'state': 'Arkansas'}],
#  [{'name': 'Iam',
#    'local_names': {'hu': 'Jám', 'ro': 'Iam', 'uk': 'Ям'},
#    'lat': 45.0100943,
#    'lon': 21.4012452,
#    'country': 'RO'}],
#  [{'name': 'Lauw',
#    'local_names': {'de': 'Au', 'fr': 'Lauw'},
#    'lat': 47.7563917,
#    'lon': 7.0194428,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'Ath',
#    'local_names': {'la': 'Athum', 'nl': 'Aat', 'wa': 'Ate', 'fr': 'Ath'},
#    'lat': 50.6288684,
#    'lon': 3.785318027789082,
#    'country': 'BE',
#    'state': 'Hainaut'}],
#  [{'name': 'Iaz',
#    'local_names': {'uk': 'Яз', 'hu': 'Jász', 'ro': 'Iaz'},
#    'lat': 45.4650871,
#    'lon': 22.2338393,
#    'country': 'RO'}],
#  [{'name': 'Bs',
#    'local_names': {'en': 'Bs',
#     'mk': "Б'с",
#     'ascii': 'Bs',
#     'feature_name': 'Bs'},
#    'lat': 42.1877996,
#    'lon': 22.3876518,
#    'country': 'MK',
#    'state': 'Northeastern Region'}],
#  [{'name': 'Belo Horizonte',
#    'local_names': {'ru': 'Белу-Оризонти',
#     'uz': 'Belu-Orizonti',
#     'kk': 'Белу-Оризонти',
#     'sv': 'Belo Horizonte',
#     'es': 'Belo Horizonte',
#     'ja': 'ベロオリゾンテ',
#     'ko': '벨루오리존치',
#     'oc': 'Belo Horizonte',
#     'ce': 'Белу-Оризонти',
#     'mk': 'Бело Хоризонте',
#     'th': 'เบโลโอรีซอนชี',
#     'hy': 'Բելու Օրիզոնտի',
#     'pl': 'Belo Horizonte',
#     'bg': 'Бело Оризонти',
#     'ar': 'بيلو هوريزونتي',
#     'kn': 'ಬೇಲೊಹೋರಿಜೊಂತೆ',
#     'tg': 'Белу-Оризонти',
#     'el': 'Μπέλο Οριζόντε',
#     'lt': 'Belo Horizontė',
#     'tr': 'Belo Horizonte',
#     'nl': 'Belo Horizonte',
#     'mr': 'बेलो होरिझोन्ते',
#     'be': 'Белу-Арызонты',
#     'lv': 'Belu Orizonti',
#     'pa': 'ਬੈਲੋ ਓਰੀਜ਼ੋਂਤੀ',
#     'he': 'בלו הוריזונטה',
#     'de': 'Belo Horizonte',
#     'uk': 'Белу-Оризонті',
#     'ka': 'ბელუ-ორიზონტი',
#     'it': 'Belo Horizonte',
#     'en': 'Belo Horizonte',
#     'ta': 'பெலோ அரிசாஞ்ச்',
#     'la': 'Pulchri Horizontis',
#     'zh': '贝洛奥里藏特',
#     'fa': 'بلو هوریزونته',
#     'pt': 'Belo Horizonte',
#     'os': 'Белу-Оризонти',
#     'mn': 'Бе́лу-Оризо́нти',
#     'fr': 'Belo Horizonte',
#     'eo': 'Bel-Horizonto',
#     'sr': 'Бело Оризонте'},
#    'lat': -19.9227318,
#    'lon': -43.9450948,
#    'country': 'BR',
#    'state': 'Minas Gerais'}],
#  [{'name': 'Budi',
#    'local_names': {'en': 'Budi', 'th': 'บุดี'},
#    'lat': 6.5193503,
#    'lon': 101.3177069,
#    'country': 'TH',
#    'state': 'Yala Province'}],
#  [{'name': 'ББ', 'lat': 42.8677615, 'lon': 74.5874803, 'country': 'KG'}],
#  [{'name': 'Berlin',
#    'local_names': {'co': 'Berlinu',
#     'so': 'Berlin',
#     'af': 'Berlyn',
#     'ab': 'Берлин',
#     'bo': 'པེ་ལིང་',
#     'br': 'Berlin',
#     'cv': 'Берлин',
#     'wo': 'Berlin',
#     'sh': 'Berlin',
#     'es': 'Berlín',
#     'my': 'ဘာလင်မြို့',
#     'ie': 'Berlin',
#     'ro': 'Berlin',
#     'ba': 'Берлин',
#     'io': 'Berlin',
#     'kk': 'Берлин',
#     'ur': 'برلن',
#     'eu': 'Berlin',
#     'su': 'Berliini',
#     'ko': '베를린',
#     'mn': 'Берлин',
#     'cs': 'Berlín',
#     'sl': 'Berlin',
#     'th': 'เบอร์ลิน',
#     'az': 'Berlin',
#     'sc': 'Berlinu',
#     'mr': 'बर्लिन',
#     'ms': 'Berlin',
#     'ca': 'Berlín',
#     'sr': 'Берлин',
#     'ta': 'பெர்லின்',
#     'ru': 'Берлин',
#     'yi': 'בערלין',
#     'sw': 'Berlin',
#     'kv': 'Берлин',
#     'bi': 'Berlin',
#     'ky': 'Берлин',
#     'mt': 'Berlin',
#     'no': 'Berlin',
#     'id': 'Berlin',
#     'el': 'Βερολίνο',
#     'jv': 'Berlin',
#     'ja': 'ベルリン',
#     'iu': 'ᐱᕐᓖᓐ',
#     'uz': 'Berlin',
#     'qu': 'Berlin',
#     'na': 'Berlin',
#     'gd': 'Berlin',
#     'si': 'බර්ලිනය',
#     'ku': 'Berlîn',
#     'rm': 'Berlin',
#     'fi': 'Berliini',
#     'ga': 'Beirlín',
#     'zu': 'Berlin',
#     'li': 'Berlien',
#     'hy': 'Բեռլին',
#     'is': 'Berlín',
#     'fr': 'Berlin',
#     'kw': 'Berlin',
#     'gn': 'Berlin',
#     'sk': 'Berlín',
#     'mi': 'Pearīni',
#     'la': 'Berolinum',
#     'oc': 'Berlin',
#     'ug': 'Bérlin',
#     'ps': 'برلين',
#     'ar': 'برلين',
#     'lb': 'Berlin',
#     'hi': 'बर्लिन',
#     'lv': 'Berlīne',
#     'gl': 'Berlín',
#     'sv': 'Berlin',
#     'ty': 'Berlin',
#     'lt': 'Berlynas',
#     'hr': 'Berlin',
#     'ka': 'ბერლინი',
#     'vi': 'Berlin',
#     'fo': 'Berlin',
#     'tl': 'Berlin',
#     'et': 'Berliin',
#     'ln': 'Berlin',
#     'ml': 'ബെര്\u200dലിന്',
#     'mg': 'Berlin',
#     'uk': 'Берлін',
#     'fy': 'Berlyn',
#     'tr': 'Berlin',
#     'zh': '柏林',
#     'bn': 'বার্লিন',
#     'sq': 'Berlini',
#     'be': 'Берлін',
#     'yo': 'Berlin',
#     'fa': 'برلین',
#     'da': 'Berlin',
#     'eo': 'Berlino',
#     'mk': 'Берлин',
#     'nn': 'Berlin',
#     'en': 'Berlin',
#     'bg': 'Берлин',
#     'hu': 'Berlin',
#     'lg': 'Berlin',
#     'kn': 'ಬೆರ್ಲಿನ್',
#     'tg': 'Берлин',
#     'ia': 'Berlin',
#     'te': 'బెర్లిన్',
#     'an': 'Berlín',
#     'it': 'Berlino',
#     'gv': 'Berleen',
#     'tt': 'Берлин',
#     'nl': 'Berlijn',
#     'am': 'በርሊን',
#     'bs': 'Berlin',
#     'ht': 'Bèlen',
#     'cy': 'Berlin',
#     'se': 'Berlin',
#     'he': 'ברלין',
#     'os': 'Берлин',
#     'cu': 'Берлинъ',
#     'pt': 'Berlim',
#     'de': 'Berlin',
#     'pl': 'Berlin'},
#    'lat': 52.5170365,
#    'lon': 13.3888599,
#    'country': 'DE'}],
#  [{'name': 'Brzesko',
#    'local_names': {'pl': 'Brzesko',
#     'he': "בז'סקו",
#     'ru': 'Бжеско',
#     'uk': 'Бжеско'},
#    'lat': 49.9678396,
#    'lon': 20.6068496,
#    'country': 'PL',
#    'state': 'Lesser Poland Voivodeship'}],
#  [{'name': 'BJ Block',
#    'local_names': {'bn': 'বিজে ব্লক', 'en': 'BJ Block'},
#    'lat': 22.5902239,
#    'lon': 88.4267468,
#    'country': 'IN',
#    'state': 'West Bengal'}],
#  [{'name': 'Bam',
#    'local_names': {'uk': 'Бам',
#     'ar': 'بم',
#     'fr': 'Bam',
#     'hi': 'बम',
#     'es': 'Bam',
#     'ru': 'Бам',
#     'en': 'Bam',
#     'et': 'Bam',
#     'ko': '밤',
#     'fa': 'شهر بم',
#     'ja': 'バム',
#     'ml': 'ബം',
#     'de': 'Bam'},
#    'lat': 29.1059864,
#    'lon': 58.3565663,
#    'country': 'IR',
#    'state': 'Kerman Province'}],
#  [{'name': 'Bath',
#    'local_names': {'qu': 'Bath',
#     'zh': '巴斯',
#     'de': 'Bath',
#     'ko': '바스',
#     'jv': 'Bath',
#     'eo': 'Bath',
#     'ar': 'باث',
#     'hu': 'Bath',
#     'la': 'Aquae Sulis',
#     'sd': 'باٿ شھر',
#     'nn': 'Bath',
#     'sv': 'Bath',
#     'tr': 'Bath',
#     'bg': 'Бат',
#     'es': 'Bath',
#     'tl': 'Bath',
#     'nl': 'Bath',
#     'uk': 'Бат',
#     'ja': 'バース',
#     'hr': 'Bath',
#     'ur': 'باتھ',
#     'bn': 'বাথ',
#     'sh': 'Bath',
#     'lb': 'Bath',
#     'fy': 'Bath',
#     'fr': 'Bath',
#     'el': 'Μπαθ',
#     'cy': 'Caerfaddon',
#     'hy': 'Բաթ',
#     'sc': 'Bath',
#     'lt': 'Batas',
#     'cs': 'Bath',
#     'af': 'Bath',
#     'vo': 'Bath',
#     'ga': 'Bath',
#     'be': 'Бат',
#     'vi': 'Bath',
#     'eu': 'Bath',
#     'pl': 'Bath',
#     'tt': 'Бас',
#     'he': "באת'",
#     'et': 'Bath',
#     'kk': 'Бат',
#     'is': 'Bath',
#     'fi': 'Bath',
#     'ca': 'Bath',
#     'sk': 'Bath',
#     'ru': 'Бат',
#     'th': 'บาธ',
#     'no': 'Bath',
#     'id': 'Bath',
#     'io': 'Bath',
#     'fa': 'باث',
#     'ku': 'Bath',
#     'mk': 'Бат',
#     'ka': 'ბათი',
#     'da': 'Bath',
#     'pt': 'Bath',
#     'gl': 'Bath',
#     'sr': 'Бат',
#     'it': 'Bath',
#     'en': 'Bath',
#     'lv': 'Bāta',
#     'sl': 'Bath',
#     'az': 'Bat',
#     'br': 'Bath',
#     'ro': 'Bath'},
#    'lat': 51.3813864,
#    'lon': -2.3596963,
#    'country': 'GB',
#    'state': 'England'}],
#  [{'name': 'Banan',
#    'local_names': {'fr': 'Banan', 'vi': 'Ba Nam', 'zh': '巴南区', 'en': 'Banan'},
#    'lat': 29.4043601,
#    'lon': 106.5368478,
#    'country': 'CN',
#    'state': 'Chongqing'}],
#  [{'name': 'Pau',
#    'local_names': {'sr': 'По',
#     'ja': 'ポー',
#     'ar': 'بو',
#     'lt': 'Po',
#     'eu': 'Paue',
#     'la': 'Palum',
#     'ru': 'По',
#     'eo': 'Paŭo',
#     'br': 'Pau',
#     'uk': 'По',
#     'zh': '波城',
#     'el': 'Πω',
#     'oc': 'Pau',
#     'hu': 'Pau',
#     'fr': 'Pau',
#     'ca': 'Pau'},
#    'lat': 43.2957547,
#    'lon': -0.3685668,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'Bar',
#    'local_names': {'ca': 'Bar',
#     'is': 'Bar',
#     'uk': 'Бар',
#     'hu': 'Bar',
#     'cs': 'Bar',
#     'ce': 'Бар',
#     'it': 'Antivari',
#     'fo': 'Bar',
#     'he': 'בר',
#     'la': 'Antibarium',
#     'id': 'Bar',
#     'fr': 'Bar',
#     'el': 'Μπαρ',
#     'et': 'Bar',
#     'ka': 'ბარი',
#     'pt': 'Bar',
#     'sl': 'Bar',
#     'bg': 'Бар',
#     'ar': 'بار',
#     'kl': 'Bar',
#     'pl': 'Bar',
#     'hr': 'Bar',
#     'be': 'Бар',
#     'en': 'Bar',
#     'ja': 'バール',
#     'es': 'Bar',
#     'sv': 'Bar',
#     'da': 'Bar',
#     'ro': 'Bar',
#     'tr': 'Bar',
#     'bs': 'Bar',
#     'nn': 'Bar',
#     'mk': 'Бар',
#     'ur': 'بار',
#     'fi': 'Bar',
#     'de': 'Bar',
#     'nl': 'Bar',
#     'sh': 'Bar',
#     'sk': 'Bar',
#     'eu': 'Bar',
#     'fa': 'بار',
#     'lt': 'Baras',
#     'sq': 'Tivar',
#     'oc': 'Bar',
#     'ko': '바르',
#     'nb': 'Bar',
#     'sr': 'Бар',
#     'ru': 'Бар'},
#    'lat': 42.0979745,
#    'lon': 19.0954528,
#    'country': 'ME'}],
#  [{'name': 'Bergamo',
#    'local_names': {'ru': 'Бергамо',
#     'la': 'Bergomum',
#     'zh': '贝尔加莫',
#     'el': 'Μπέργκαμο',
#     'fr': 'Bergame',
#     'uk': 'Бергамо',
#     'en': 'Bergamo',
#     'es': 'Bérgamo',
#     'pt': 'Bérgamo',
#     'ca': 'Bèrgam',
#     'hu': 'Bergamo',
#     'it': 'Bergamo',
#     'bg': 'Бергамо'},
#    'lat': 45.6944947,
#    'lon': 9.6698727,
#    'country': 'IT',
#    'state': 'Lombardy'}],
#  [{'name': 'BF Homes Caloocan',
#    'lat': 14.7321052,
#    'lon': 121.0237227,
#    'country': 'PH'}],
#  [{'name': 'Bujumbura',
#    'local_names': {'am': 'ቡጁምቡራ',
#     'id': 'Bujumbura',
#     'ln': 'Bujumbúra',
#     'en': 'Bujumbura',
#     'fy': 'Bûjûmbûra',
#     'el': 'Μπουζουμπούρα',
#     'kk': 'Бужумбура',
#     'tl': 'Bujumbura',
#     'nl': 'Bujumbura',
#     'br': 'Bujumbura',
#     'ml': 'ബുജുംബുറ',
#     'kg': 'Bujumbura',
#     'lb': 'Bujumbura',
#     'ru': 'Бужумбура',
#     'ps': 'بوجومبورا',
#     'la': 'Bujumbura',
#     'ar': 'بوجومبورا',
#     'pl': 'Bużumbura',
#     'sw': 'Bujumbura',
#     'cs': 'Bujumbura',
#     'wo': 'Bujumbura',
#     'es': 'Buyumbura',
#     'ha': 'Bujumbura',
#     'et': 'Bujumbura',
#     'sl': 'Bujumbura',
#     'nn': 'Bujumbura',
#     'it': 'Bujumbura',
#     'ky': 'Бужумбура',
#     'hr': 'Bujumbura',
#     'zu': 'Bujumbura',
#     'sq': 'Buzhumbura',
#     'az': 'Bujumbura',
#     'be': 'Бужумбура',
#     'ny': 'Bujumbura',
#     'eu': 'Bujumbura',
#     'lt': 'Bužumbūra',
#     'ku': 'Bujumbura',
#     'ko': '부줌부라',
#     'sv': 'Bujumbura',
#     'gd': 'Bujumbura',
#     'mg': 'Bujumbura',
#     'bs': 'Bujumbura',
#     'ie': 'Bujumbura',
#     'ce': 'Бужумбура',
#     'mn': 'Бужумбура',
#     'th': 'บูจุมบูรา',
#     'lv': 'Bužumbura',
#     'mk': 'Буџумбура',
#     'sk': 'Bujumbura',
#     'mr': 'बुजुंबुरा',
#     'sn': 'Bujumbura',
#     'de': 'Bujumbura',
#     'yi': 'בוזשומבורע',
#     'ka': 'ბუჟუმბურა',
#     'gl': 'Bujumbura',
#     'fi': 'Bujumbura',
#     'ur': 'بوجومبرا',
#     'tg': 'Буҷумбура',
#     'pt': 'Bujumbura',
#     'fr': 'Bujumbura',
#     'da': 'Bujumbura',
#     'oc': 'Bujumbura',
#     'is': 'Bújúmbúra',
#     'qu': 'Bujumbura',
#     'he': "בוג'ומבורה",
#     'ms': 'Bujumbura',
#     'bg': 'Бужумбура',
#     'ca': 'Mbabane',
#     'kw': 'Bujumbura',
#     'ta': 'புசும்புரா',
#     'so': 'Bujumbura',
#     'fa': 'بوجومبورا',
#     'sr': 'Буџумбура',
#     'yo': 'Bujumbura',
#     'pa': 'ਬੁਜੁੰਬੁਰਾ',
#     'na': 'Bujumbura',
#     'an': 'Buyumbura',
#     'hy': 'Բուժումբուրա',
#     'cy': 'Bujumbura',
#     'bo': 'བུ་ཇུམ་བུ་ར།',
#     'eo': 'Buĵumburo',
#     'uz': 'Bujumbura',
#     'no': 'Bujumbura',
#     'ro': 'Bujumbura',
#     'jv': 'Bujumbura',
#     'hu': 'Bujumbura',
#     'ga': 'Bujumbura',
#     'af': 'Bujumbura',
#     'sh': 'Bujumbura',
#     'ht': 'Boujoumboura',
#     'tr': 'Bujumbura',
#     'ja': 'ブジュンブラ',
#     'rw': 'Bujumbura',
#     'zh': '布琼布拉',
#     'vi': 'Bujumbura',
#     'io': 'Bujumbura',
#     'rn': 'Bujumbura',
#     'uk': 'Бужумбура'},
#    'lat': -3.3638125,
#    'lon': 29.3675028,
#    'country': 'BI',
#    'state': 'Bujumbura Mairie'}],
#  [{'name': 'Companhia',
#    'lat': -22.1822689,
#    'lon': -44.68776,
#    'country': 'BR',
#    'state': 'Minas Gerais'}],
#  [{'name': 'Close',
#    'local_names': {'ga': 'An Clós'},
#    'lat': 51.6901245,
#    'lon': -9.5131483,
#    'country': 'IE'}],
#  [{'name': 'Chun',
#    'local_names': {'th': 'จุน', 'en': 'Chun'},
#    'lat': 19.3091175,
#    'lon': 100.1647501,
#    'country': 'TH',
#    'state': 'Phayao Province'}],
#  [{'name': 'Co',
#    'lat': 60.29492475,
#    'lon': 26.0047019985007,
#    'country': 'FI'}],
#  [{'name': 'Crescent',
#    'lat': 41.3650699,
#    'lon': -95.858422,
#    'country': 'US',
#    'state': 'Iowa'}],
#  [{'name': 'Huraa',
#    'local_names': {'en': 'Huraa', 'dv': 'ހުރާ'},
#    'lat': 4.3337710000000005,
#    'lon': 73.60197749346682,
#    'country': 'MV',
#    'state': 'Malé Atoll'}],
#  [{'name': 'Chișinău Municipality',
#    'local_names': {'en': 'Chișinău Municipality',
#     'ro': 'Municipiul Chișinău',
#     'ru': 'Муниципалитет Кишинёв',
#     'uk': 'Муніципій Кишинів',
#     'fr': 'Municipalité de Chișinău',
#     'mo': 'Municipiul Chișinău',
#     'de': 'Munizip Kischinau'},
#    'lat': 47.00740025,
#    'lon': 28.843146600415984,
#    'country': 'MD'}],
#  [{'name': 'Denbigh',
#    'local_names': {'ur': 'ڈنبی', 'cy': 'Dinbych', 'en': 'Denbigh'},
#    'lat': 53.1853776,
#    'lon': -3.4178289,
#    'country': 'GB',
#    'state': 'Wales'}],
#  [{'name': 'Doha',
#    'local_names': {'sc': 'Doha',
#     'ja': 'ドーハ',
#     'bg': 'Доха',
#     'ka': 'დოჰა',
#     'et': 'Doha',
#     'es': 'Doha',
#     'id': 'Doha',
#     'lv': 'Doha',
#     'sl': 'Doha',
#     'nn': 'Doha',
#     'fy': 'Doha',
#     'eu': 'Doha',
#     'ky': 'Доха',
#     'ia': 'Doha',
#     'sw': 'Doha',
#     'gl': 'Doha',
#     'kn': 'ದೊಹಾ',
#     'ca': 'Doha',
#     'cy': 'Doha',
#     'tt': 'Doha',
#     'so': 'Dooxa',
#     'an': 'Doha',
#     'tg': 'Дуҳа',
#     'bn': 'দোহা',
#     'de': 'Doha',
#     'he': 'דוחה',
#     'gd': 'Doha',
#     'nl': 'Doha',
#     'la': 'Doha',
#     'oc': 'Doha',
#     'ku': 'Doha',
#     'lb': 'Doha',
#     'tr': 'Doha',
#     'ht': 'Doha',
#     'sv': 'Doha',
#     'yo': 'Doha',
#     'hi': 'दोहा, क़तर',
#     'be': 'Доха',
#     'rw': 'Doha',
#     'ug': 'دوھا',
#     'vo': 'Däuha',
#     'fa': 'دوحه',
#     'ml': 'ദോഹ',
#     'kl': 'Doha',
#     'my': 'ဒိုဟာမြို့',
#     'io': 'Doha',
#     'ko': '도하',
#     'mg': 'Doha',
#     'jv': 'Doha',
#     'en': 'Doha',
#     'ar': 'الدوحة',
#     'da': 'Doha',
#     'ie': 'Doha',
#     'ms': 'Doha',
#     'ha': 'Doha',
#     'ta': 'தோகா',
#     'pa': 'ਦੋਹਾ',
#     'gu': 'દોહા',
#     'ba': 'Доһа',
#     'sd': 'دوحہ',
#     'km': 'ដូហា',
#     'ru': 'Доха',
#     'sr': 'Доха',
#     'ga': 'Doha',
#     'mr': 'दोहा',
#     'hr': 'Doha',
#     'el': 'Ντόχα',
#     'cs': 'Dauhá',
#     'it': 'Doha',
#     'zh': '多哈',
#     'tl': 'Doha',
#     'fi': 'Doha',
#     'ro': 'Doha',
#     'tk': 'Doha',
#     'no': 'Doha',
#     'os': 'Дохæ',
#     'th': 'โดฮา',
#     'hu': 'Doha',
#     'ps': 'دوحه',
#     'lt': 'Doha',
#     'yi': 'דאכא',
#     'gn': 'Doha',
#     'hy': 'Դոհա',
#     'sn': 'Doha',
#     'kk': 'Доһа',
#     'mk': 'Доха',
#     'uk': 'Доха',
#     'vi': 'Doha',
#     'az': 'Doha',
#     'mn': 'Доха',
#     'uz': 'Doʻha',
#     'gr': 'Δοχή',
#     'bo': 'དྷོ་ཧ།',
#     'br': 'Doha',
#     'am': 'ዶሃ',
#     'bs': 'Doha',
#     'pt': 'Doha',
#     'ce': 'Духьа',
#     'sh': 'Doha',
#     'af': 'Doha',
#     'ur': 'دوحہ',
#     'ne': 'दोहा',
#     'eo': 'Doho',
#     'sk': 'Dauha',
#     'is': 'Doha',
#     'sq': 'Doha',
#     'fr': 'Doha',
#     'pl': 'Doha'},
#    'lat': 25.2856329,
#    'lon': 51.5264162,
#    'country': 'QA'}],
#  [{'name': 'Majowe',
#    'local_names': {'pl': 'Majowe'},
#    'lat': 53.3759661,
#    'lon': 14.6659283,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Do',
#    'lat': 42.9000719,
#    'lon': 18.0298066,
#    'country': 'BA',
#    'state': 'Republika Srpska'}],
#  [{'name': 'Opatowiec',
#    'local_names': {'pl': 'Opatowiec', 'ru': 'Опатовец', 'uk': "Опатов'єц"},
#    'lat': 50.2425871,
#    'lon': 20.7237798,
#    'country': 'PL',
#    'state': 'Świętokrzyskie Voivodeship'}],
#  [{'name': 'Eigg',
#    'local_names': {'en': 'Eigg', 'gd': 'Eige', 'mk': 'Ег'},
#    'lat': 56.907925399999996,
#    'lon': -6.160063788529316,
#    'country': 'GB',
#    'state': 'Scotland'}],
#  [{'name': 'Err',
#    'local_names': {'ca': 'Er', 'fr': 'Err'},
#    'lat': 42.4406621,
#    'lon': 2.0328526,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Ee',
#    'local_names': {'nl': 'Ee', 'fy': 'Ie'},
#    'lat': 53.3300561,
#    'lon': 6.1040747,
#    'country': 'NL',
#    'state': 'Frisia'}],
#  [{'name': 'Eth',
#    'local_names': {'fr': 'Eth', 'ru': 'Эт'},
#    'lat': 50.3260433,
#    'lon': 3.6671281,
#    'country': 'FR',
#    'state': 'Hauts-de-France'}],
#  [{'name': 'Faux',
#    'local_names': {'kk': 'Фо',
#     'bg': 'Фо',
#     'mk': 'Фо',
#     'sr': 'Фо',
#     'ru': 'Фо',
#     'uk': 'Фо',
#     'zh': '福村',
#     'be': 'Фо',
#     'fr': 'Faux'},
#    'lat': 49.5374982,
#    'lon': 4.5001619,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'FJ Kato Village',
#    'lat': 7.0682339,
#    'lon': 125.5825322,
#    'country': 'PH'}],
#  [{'name': 'Fing',
#    'local_names': {'fr': 'Fing'},
#    'lat': 14.0685426,
#    'lon': -5.4854786,
#    'country': 'ML',
#    'state': 'Ségou Region'}],
#  [{'name': 'Schönberg/Schoenberg',
#    'local_names': {'de': 'Schönberg', 'fr': 'Schoenberg'},
#    'lat': 46.8101241,
#    'lon': 7.171828,
#    'country': 'CH',
#    'state': 'Fribourg'}],
#  [{'name': 'Town of Gates',
#    'local_names': {'en': 'Town of Gates'},
#    'lat': 43.1514226,
#    'lon': -77.7130004,
#    'country': 'US',
#    'state': 'New York'}],
#  [{'name': 'GM',
#    'lat': 37.36827785,
#    'lon': -121.88408532799455,
#    'country': 'US',
#    'state': 'California'}],
#  [{'name': 'Geapa',
#    'local_names': {'en': 'Geapa'},
#    'lat': 6.453333,
#    'lon': -8.998056,
#    'country': 'LR',
#    'state': 'Nimba County'}],
#  [{'name': 'Daix',
#    'local_names': {'fr': 'Daix', 'ja': 'デ'},
#    'lat': 47.3521149,
#    'lon': 5.0008333,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Qal`eh Gah-e Karkar',
#    'local_names': {'fa': 'قلعه گه کرکر', 'en': 'Qal`eh Gah-e Karkar'},
#    'lat': 36.159,
#    'lon': 46.6714,
#    'country': 'IR',
#    'state': 'Kurdistan Province'}],
#  [{'name': 'Graben',
#    'lat': 48.1890811,
#    'lon': 10.8220308,
#    'country': 'DE',
#    'state': 'Bavaria'}],
#  [{'name': 'Goidhoo',
#    'local_names': {'dv': 'ގޮއިދޫ', 'en': 'Goidhoo'},
#    'lat': 4.87108555,
#    'lon': 72.99771789715751,
#    'country': 'MV',
#    'state': 'Maalhosmadulu Dhekunuburi'}],
#  [{'name': 'Gat',
#    'local_names': {'he': 'גת', 'en': 'Gat', 'fr': 'Gat'},
#    'lat': 31.6268616,
#    'lon': 34.7951088,
#    'country': 'IL',
#    'state': 'South District'}],
#  [{'name': 'Baharan',
#    'local_names': {'en': 'Baharan', 'fa': 'بهاران'},
#    'lat': 25.3562859,
#    'lon': 60.8477664,
#    'country': 'IR',
#    'state': 'Sistan and Baluchestan Province'}],
#  [{'name': 'Gy',
#    'local_names': {'fr': 'Gy', 'uk': 'Жі'},
#    'lat': 47.4068,
#    'lon': 5.8146609,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Heights',
#    'lat': 37.2112612,
#    'lon': -77.4072045,
#    'country': 'US',
#    'state': 'Virginia'}],
#  [{'name': 'Əhən',
#    'local_names': {'az': 'Əhən'},
#    'lat': 40.8525767,
#    'lon': 48.4162128,
#    'country': 'AZ',
#    'state': 'Mountainous Shirvan'}],
#  [{'name': 'Hek',
#    'local_names': {'fa': 'هک', 'en': 'Hek'},
#    'lat': 31.0869054,
#    'lon': 53.3006387,
#    'country': 'IR',
#    'state': 'Yazd Province'}],
#  [{'name': 'Shanghai',
#    'local_names': {'la': 'Sciamhaevum',
#     'tg': 'Шанхай',
#     'tl': 'Shanghai',
#     'uz': 'Shanxay',
#     'cv': 'Шанхай',
#     'ce': 'Шанхай',
#     'li': 'Sjanghai',
#     'ko': '상하이',
#     'ha': 'Shanghai',
#     'hu': 'Sanghaj',
#     'ny': 'Shanghai',
#     'ascii': 'Shanghai',
#     'sv': 'Shanghai',
#     'tt': 'Şanxay',
#     'su': 'Shanghai',
#     'kw': 'Shanghai',
#     'bo': 'ཧྲང་ཧའེ་གྲོང་ཁྱེར།',
#     'lb': 'Shanghai',
#     'lo': 'ຊຽງໄຮ້',
#     'ta': 'சாங்காய்',
#     'kk': 'Шанхай',
#     'fj': 'Shaghai',
#     'et': 'Shanghai',
#     'az': 'Şanxay',
#     'ml': 'ഷാങ്ഹായ്',
#     'br': 'Shanghai',
#     'kn': 'ಶಾಂಘೈ',
#     'id': 'Shanghai',
#     'bi': 'Shanghai',
#     'pl': 'Szanghaj',
#     'as': 'ছাংহাই',
#     'cs': 'Šanghaj',
#     'he': 'שאנגחאי',
#     'fi': 'Shanghai',
#     'os': 'Шанхай',
#     'el': 'Σαγκάη',
#     'eu': 'Shanghai',
#     'my': 'ရှန်ဟိုင်းမြို့',
#     'de': 'Shanghai',
#     'bn': 'সাংহাই',
#     'lv': 'Šanhaja',
#     'da': 'Shanghai',
#     'gl': 'Shanghai',
#     'sr': 'Шангај',
#     'ru': 'Шанхай',
#     'gv': 'Shanghai',
#     'tk': 'Şanhaý',
#     'hy': 'Շանհայ',
#     'nn': 'Shanghai',
#     'ar': 'شانغهاي',
#     'fy': 'Shanghai',
#     'ie': 'Shanghai',
#     'it': 'Shanghai',
#     'es': 'Shanghái',
#     'nl': 'Shanghai',
#     'mr': 'शांघाय',
#     'tw': 'Shangai',
#     'bg': 'Шанхай',
#     'pa': 'ਸ਼ੰਘਾਈ',
#     'rm': 'Schanghai',
#     'ug': 'شاڭخەي شەھىرى',
#     'no': 'Shanghai',
#     'gn': 'Changái',
#     'ba': 'Шанхай',
#     'bm': 'Shanghai',
#     'mi': 'Hangahai',
#     'ia': 'Shanghai',
#     'ur': 'شنگھائی',
#     'io': 'Shanghai',
#     'mk': 'Шангај',
#     'mg': 'Shanghai',
#     'te': 'షాంఘై',
#     'ln': 'Shanghai',
#     'yi': 'שאנכיי',
#     'ca': 'Xangai',
#     'cy': 'Shanghai',
#     'wo': 'Shanghai',
#     'fa': 'شانگهای',
#     'qu': 'Shanghai',
#     'ka': 'შანხაი',
#     'sw': 'Shanghai',
#     'ku': 'Şanghay',
#     'zh': '上海市',
#     'en': 'Shanghai',
#     'kv': 'Шанхай',
#     'si': 'ෂැංහයි',
#     'vi': 'Thượng Hải',
#     'tn': 'Shanghai',
#     'ja': '上海市',
#     'an': 'Xangai',
#     'eo': 'Ŝanhajo',
#     'ga': 'Shang-hai',
#     'om': 'Shaangaayi',
#     'is': 'Sjanghæ',
#     'fo': 'Shanghai',
#     'sk': 'Šanghaj',
#     'kl': 'Shanghai',
#     'fr': 'Shanghai',
#     'uk': 'Шанхай',
#     'am': 'ሻንግሃይ',
#     'ro': 'Shanghai',
#     'lt': 'Šanchajus',
#     'ps': 'شانگهای',
#     'tr': 'Şanghay',
#     'jv': 'Shanghai',
#     'be': 'Шанхай',
#     'sl': 'Šanghaj',
#     'pt': 'Xangai',
#     'th': 'เซี่ยงไฮ้',
#     'ht': 'Shanghai',
#     'hi': 'शंघाई',
#     'ay': 'Shanghai',
#     'zu': 'Shanghai',
#     'oc': 'Shanghai',
#     'vo': 'Shanghai',
#     'ms': 'Shanghai',
#     'feature_name': 'Shanghai',
#     'za': 'Sanghaij',
#     'af': 'Sjanghai',
#     'gd': 'Shanghai',
#     'hr': 'Šangaj',
#     'ne': 'शाङ्घाई',
#     'bs': 'Šangaj',
#     'mn': 'Шанхай',
#     'ky': 'Шанхай',
#     'ki': 'Shanghai',
#     'kg': 'Shanghai',
#     'sq': 'Shangai'},
#    'lat': 31.2322758,
#    'lon': 121.4692071,
#    'country': 'CN'}],
#  [{'name': 'Islamabad',
#    'local_names': {'ja': 'イスラーマーバード首都圏;イスラマバード',
#     'hu': 'Iszlámábád',
#     'ru': 'Исламабад',
#     'hy': 'Իսլամաբադ',
#     'be': 'Ісламабад',
#     'cs': 'Islámábád',
#     'pt': 'Islamabade',
#     'mr': 'इस्लामाबाद',
#     'he': 'איסלמבד',
#     'os': 'Исламабад',
#     'fa': 'اسلام\u200cآباد',
#     'ar': 'إسلام آباد',
#     'bn': 'ইসলামাবাদ',
#     'yi': 'איסלאמאבאד',
#     'kn': 'ಇಸ್ಲಾಮಾಬಾದ್',
#     'es': 'Islamabad',
#     'zh': '伊斯蘭堡',
#     'am': 'ኢስላማባድ',
#     'et': 'Islāmābād',
#     'ko': '이슬라마바드',
#     'fr': 'Islamabad',
#     'tg': 'Исламабад',
#     'tr': 'İslamabad',
#     'gu': 'ઇસ્લામાબાદ',
#     'sd': 'اسلام آباد',
#     'bg': 'Исламабад',
#     'ug': 'ئىسلامئاباد',
#     'lv': 'Islāmābāda',
#     'eo': 'Islamabado',
#     'nn': 'Islamabad',
#     'dv': 'އިސްލާމްއާބާދު',
#     'sk': 'Islamabad',
#     'no': 'Islamabad',
#     'mk': 'Исламабад',
#     'la': 'Islamabada',
#     'ks': 'اِسلام آبادٖ',
#     'de': 'Islamabad',
#     'lt': 'Islamabadas',
#     'hi': 'इस्लामाबाद',
#     'oc': 'Islamabad',
#     'nl': 'Islamabad',
#     'en': 'Islamabad',
#     'th': 'อิสลามาบัด',
#     'pl': 'Islamabad',
#     'vi': 'Islamabad',
#     'is': 'Islamabad',
#     'ur': 'اسلام آباد',
#     'bo': 'ཨི་སི་ལམ་བོ།',
#     'te': 'ఇస్లామాబాద్',
#     'sq': 'Islamabadi',
#     'ta': 'இஸ்லாமாபாத்',
#     'pa': 'ਇਸਲਾਮਾਬਾਦ',
#     'mn': 'Исламабад',
#     'uk': 'Ісламабад',
#     'el': 'Ισλαμαμπάντ',
#     'az': 'İslamabad',
#     'ka': 'ისლამაბადი',
#     'ml': 'ഇസ്ലാമബാദ്',
#     'ps': 'اسلام آباد',
#     'it': 'Islamabad',
#     'sr': 'Исламабад',
#     'kk': 'Исламабад',
#     'ku': 'Îslamabad',
#     'gr': 'Ἰσλαμαβάδη',
#     'eu': 'Islamabad',
#     'sv': 'Islamabad'},
#    'lat': 33.6938118,
#    'lon': 73.0651511,
#    'country': 'PK',
#    'state': 'Islamabad Capital Territory'}],
#  [{'name': 'Innermedøya',
#    'lat': 66.8789958,
#    'lon': 13.44650821244402,
#    'country': 'NO'}],
#  [{'name': 'Narman',
#    'local_names': {'fa': 'نارمان',
#     'ku': 'Narman',
#     'hy': 'Նառիման',
#     'ka': 'ნარიმანი',
#     'tt': 'Нарман',
#     'ur': 'نارمان',
#     'ru': 'Нарман',
#     'tr': 'Narman',
#     'ce': 'Нарман'},
#    'lat': 40.3452003,
#    'lon': 41.871138,
#    'country': 'TR'}],
#  [{'name': 'Hadaiq el Qubbah',
#    'local_names': {'fr': 'Hadaiq el Qubbah',
#     'ascii': 'Ḩadā’iq al Qubbah, Hadaiq al Qubbah, Garden City, Qubba Gardens',
#     'feature_name': 'Ḩadā’iq al Qubbah, Hadaiq al Qubbah, Garden City, Qubba Gardens',
#     'ar': 'حدائق القبة',
#     'de': 'Hadaiq el Qubbah',
#     'en': 'Hadaiq el Qubbah'},
#    'lat': 30.0821784,
#    'lon': 31.2825387,
#    'country': 'EG',
#    'state': 'Cairo'}],
#  [{'name': 'Ie',
#    'local_names': {'ru': 'Иэ',
#     'fr': 'Ie',
#     'uk': 'Іє',
#     'en': 'Ie',
#     'zh': '伊江村',
#     'ja': '伊江村'},
#    'lat': 26.721715,
#    'lon': 127.786429,
#    'country': 'JP'}],
#  [{'name': 'Isle',
#    'local_names': {'uk': 'Іль', 'fr': 'Isle', 'oc': 'Isla (de Vinhana)'},
#    'lat': 45.8055591,
#    'lon': 1.2238259,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'It',
#    'lat': 45.6628887,
#    'lon': 10.118138,
#    'country': 'IT',
#    'state': 'Lombardy'}],
#  [{'name': 'Jam',
#    'local_names': {'ru': 'Джем',
#     'de': 'Dscham',
#     'en': 'Jam',
#     'fa': 'جم',
#     'fr': 'Jam',
#     'hi': 'जम',
#     'ja': 'ジャム'},
#    'lat': 27.8262811,
#    'lon': 52.3263597,
#    'country': 'IR',
#    'state': 'Bushehr Province'}],
#  [{'name': 'Tokyo',
#    'local_names': {'ru': 'Токио',
#     'oc': 'Tòquio',
#     'ar': 'طوكيو',
#     'fa': 'توکیو',
#     'he': 'טוקיו',
#     'sr': 'Токио',
#     'ia': 'Tokyo',
#     'cs': 'Tokio',
#     'ca': 'Tòquio',
#     'it': 'Tokyo',
#     'mi': 'Tōkio',
#     'eo': 'Tokio',
#     'tg': 'Токио',
#     'sv': 'Tokyo',
#     'fr': 'Tokyo',
#     'lv': 'Tokija',
#     'en': 'Tokyo',
#     'tr': 'Tokyo',
#     'zh': '东京都/東京都',
#     'kn': 'ಟೋಕ್ಯೊ',
#     'el': 'Τόκιο',
#     'da': 'Tokyo',
#     'nl': 'Tokio',
#     'ja': '東京都',
#     'hr': 'Tokio',
#     'pt': 'Tóquio',
#     'la': 'Tokium',
#     'et': 'Tōkyō',
#     'is': 'Tókýó',
#     'vi': 'Tokyo',
#     'uk': 'Токіо',
#     'pl': 'Tokio',
#     'mr': 'तोक्यो',
#     'ta': 'டோக்கியோ',
#     'io': 'Tokyo',
#     'hu': 'Tokió',
#     'lt': 'Tokijas',
#     'sl': 'Tokio',
#     'be': 'Токіа',
#     'th': 'โตเกียว',
#     'cy': 'Tokyo',
#     'sk': 'Tokio',
#     'bg': 'Токио',
#     'de': 'Tokio',
#     'es': 'Tokio',
#     'ko': '도쿄도',
#     'ku': 'Tokyo',
#     'fi': 'Tokio',
#     'lb': 'Tokio'},
#    'lat': 35.6828387,
#    'lon': 139.7594549,
#    'country': 'JP'}],
#  [{'name': 'Jo',
#    'local_names': {'en': 'Jo'},
#    'lat': 27.248611,
#    'lon': 66.630556,
#    'country': 'PK',
#    'state': 'Balochistan'}],
#  [{'name': 'Križ',
#    'local_names': {'hr': 'Križ', 'hu': 'Obedszentkereszt'},
#    'lat': 45.6632061,
#    'lon': 16.5204571,
#    'country': 'HR'}],
#  [{'name': 'Ke',
#    'lat': 4.454561,
#    'lon': 6.915462,
#    'country': 'NG',
#    'state': 'Rivers State'}],
#  [{'name': 'Acre',
#    'local_names': {'ca': 'Acre',
#     'cs': 'Akko',
#     'af': 'Akko',
#     'it': 'Acri',
#     'eu': 'Akre',
#     'he': 'עכו',
#     'hi': 'एकर',
#     'am': 'ዓኮ',
#     'ur': 'عکا',
#     'es': 'Acre',
#     'ja': 'アッコ',
#     'bg': 'Акра',
#     'da': 'Akko',
#     'lt': 'Akas',
#     'et': 'Akko',
#     'fi': 'Akko',
#     'el': 'Άκρα',
#     'ar': 'عكا',
#     'ru': 'Акко',
#     'en': 'Acre',
#     'eo': 'Akko',
#     'cy': 'Acre',
#     'de': 'Akko',
#     'ku': 'Eka',
#     'fa': 'عکا',
#     'fr': 'Acre',
#     'ml': 'ഏക്കർ'},
#    'lat': 32.9281731,
#    'lon': 35.0756378,
#    'country': 'IL',
#    'state': 'North District'}],
#  [{'name': 'Kogel',
#    'local_names': {'de': 'Kogel'},
#    'lat': 53.4672206,
#    'lon': 10.9199709,
#    'country': 'DE',
#    'state': 'Mecklenburg-Vorpommern'}],
#  [{'name': 'Riga',
#    'local_names': {'tr': 'Riga',
#     'br': 'Riga',
#     'he': 'ריגה',
#     'th': 'รีกา',
#     'cv': 'Рига',
#     'sk': 'Riga',
#     'uk': 'Рига',
#     'af': 'Riga',
#     'wo': 'Riga',
#     'da': 'Riga',
#     'sl': 'Riga',
#     'mi': 'Riga',
#     'bs': 'Riga',
#     'ru': 'Рига',
#     'yo': 'Riga',
#     'kw': 'Rīga',
#     'et': 'Riia',
#     'es': 'Riga',
#     'kl': 'Riga',
#     'yi': 'ריגע',
#     'eo': 'Rigo',
#     'fy': 'Riga',
#     'lv': 'Rīga',
#     'tg': 'Рига',
#     'fi': 'Riika',
#     'en': 'Riga',
#     'bg': 'Рига',
#     'ms': 'Riga',
#     'ht': 'Riga',
#     'ku': 'Rîga',
#     'ta': 'ரீகா',
#     'nl': 'Riga',
#     'se': 'Riga',
#     'an': 'Riga',
#     'st': 'Riga',
#     'no': 'Riga',
#     'ko': '리가',
#     'ur': 'ریگا',
#     'ro': 'Riga',
#     'it': 'Riga',
#     'kk': 'Рига',
#     'be': 'Рыга',
#     'fo': 'Riga',
#     'id': 'Riga',
#     'ca': 'Riga',
#     'ja': 'リガ',
#     'na': 'Riga',
#     'mt': 'Riga',
#     'sr': 'Рига',
#     'os': 'Ригæ',
#     'zu': 'IRiga',
#     'vo': 'Rīga',
#     'hr': 'Riga',
#     'ka': 'რიგა',
#     'my': 'ရီဂါမြို့',
#     'eu': 'Riga',
#     'ln': 'Riga',
#     'jv': 'Riga',
#     'ie': 'Riga',
#     'gd': 'Riga',
#     'qu': 'Riga',
#     'gl': 'Riga',
#     'oc': 'Riga',
#     'sw': 'Riga',
#     'mk': 'Рига',
#     'pa': 'ਰੀਗਾ',
#     'hy': 'Ռիգա',
#     'mg': 'Riga',
#     'ar': 'ريغا',
#     'io': 'Riga',
#     'cs': 'Riga',
#     'uz': 'Riga',
#     'vi': 'Riga',
#     'sq': 'Riga',
#     'fr': 'Riga',
#     'ky': 'Рига',
#     'pt': 'Riga',
#     'am': 'ሪጋ',
#     'ee': 'Riga',
#     'ga': 'Ríge',
#     'tl': 'Riga',
#     'la': 'Riga',
#     'ug': 'رىگا',
#     'pl': 'Ryga',
#     'gv': 'Rīga',
#     'lt': 'Ryga',
#     'hu': 'Riga',
#     'bn': 'রিগা',
#     'hi': 'रीगा',
#     'cy': 'Riga',
#     'zh': '里加',
#     'nn': 'Riga',
#     'cu': 'Рига',
#     'el': 'Ρίγα',
#     'fa': 'ریگا',
#     'mr': 'रिगा',
#     'kv': 'Рига',
#     'sv': 'Riga',
#     'az': 'Riqa',
#     'tt': 'Рига',
#     'ascii': 'Riga',
#     'lb': 'Rīga',
#     'de': 'Riga',
#     'feature_name': 'Riga',
#     'bo': 'རི་ག',
#     'is': 'Ríga',
#     'nv': 'Wiiga'},
#    'lat': 56.9493977,
#    'lon': 24.1051846,
#    'country': 'LV',
#    'state': 'Vidzeme'}],
#  [{'name': 'Elba',
#    'local_names': {'br': 'Elba',
#     'gd': 'Elba',
#     'id': 'Elba',
#     'co': "Isula d'Elba",
#     'vi': 'Elba',
#     'gl': 'Illa de Elba',
#     'sr': 'Елба',
#     'ka': 'ელბა',
#     'ro': 'Elba',
#     'eu': 'Elba',
#     'no': 'Elba',
#     'eo': 'Elbo',
#     'ja': 'エルバ島',
#     'bg': 'Елба',
#     'tr': 'Elba',
#     'is': 'Elba',
#     'ca': "Illa d'Elba",
#     'af': 'Elba',
#     'ko': '엘바 섬',
#     'zh': '厄尔巴岛',
#     'cs': 'Elba',
#     'el': 'Έλβα',
#     'be': 'Востраў Эльба',
#     'sv': 'Elba',
#     'mk': 'Елба',
#     'fr': "Île d'Elbe",
#     'la': 'Ilva',
#     'es': 'Isla de Elba',
#     'hr': 'Elba',
#     'sk': 'Elba',
#     'fi': 'Elba',
#     'uk': 'Ельба',
#     'ml': 'എൽബ',
#     'da': 'Elba',
#     'nn': 'Elba',
#     'hy': 'Էլբա',
#     'nl': 'Elba',
#     'ga': 'Elba',
#     'lb': 'Elba',
#     'mr': 'एल्बा',
#     'pt': 'Ilha de Elba',
#     'en': 'Elba',
#     'de': 'Elba',
#     'et': 'Elba',
#     'lv': 'Elba',
#     'ta': 'எல்பா',
#     'pl': 'Elba',
#     'cy': 'Ynys Elba',
#     'ar': 'إلبا',
#     'lt': 'Elba',
#     'yi': 'עלבע',
#     'sl': 'Elba',
#     'su': 'Elba',
#     'th': 'เกาะเอลบา',
#     'ru': 'Эльба'},
#    'lat': 42.790216599999994,
#    'lon': 10.340278678735025,
#    'country': 'IT',
#    'state': 'Tuscany'}],
#  [{'name': 'Awlus',
#    'local_names': {'ascii': '`Allas, `Allās, Awlūs',
#     'feature_name': '`Allas, `Allās, Awlūs',
#     'ar': 'علص',
#     'de': 'Awlus',
#     'en': 'Awlus',
#     'fr': 'Awlus'},
#    'lat': 35.7129221,
#    'lon': 37.3643315,
#    'country': 'SY',
#    'state': 'Aleppo Governorate'}],
#  [{'name': '`Alt',
#    'local_names': {'en': '`Alt',
#     'fr': '`Alt',
#     'ascii': '‘Alt',
#     'feature_name': '‘Alt',
#     'ar': 'علط',
#     'de': '`Alt'},
#    'lat': 15.544005,
#    'lon': 48.0239718,
#    'country': 'YE',
#    'state': 'Hadramaut Governorate'}],
#  [{'name': 'Lu',
#    'local_names': {'zh': '泸县', 'en': 'Lu', 'fr': 'Lu', 'vi': 'Lô'},
#    'lat': 29.1539219,
#    'lon': 105.3788947,
#    'country': 'CN',
#    'state': 'Sichuan'}],
#  [{'name': 'Majuro',
#    'local_names': {'be': 'Маджура',
#     'sr': 'Маџуро',
#     'th': 'มาจูโร',
#     'sw': 'Majuro',
#     'zh': '马朱罗',
#     'kk': 'Маджуро',
#     'ht': 'Majouro',
#     'hy': 'Մաջուրո',
#     'cy': 'Majuro',
#     'rw': 'Majuro',
#     'uz': 'Majuro',
#     'ty': 'Majuro',
#     'uk': 'Маджуро',
#     'ar': 'ماجورو',
#     'id': 'Majuro',
#     'ba': 'Маджуро',
#     'gd': 'Majuro',
#     'am': 'ማጁሮ',
#     'lb': 'Majuro',
#     'fa': 'ماجورو',
#     'oc': 'Majuro',
#     'et': 'Majuro atoll',
#     'pt': 'Majuro',
#     'ca': 'Majuro',
#     'sn': 'Majuro',
#     'pa': 'ਮਾਜੁਰੋ',
#     'ps': 'ماجورو',
#     'lt': 'Madžūras',
#     'en': 'Majuro',
#     'de': 'Majuro',
#     'ml': 'മാജുറോ',
#     'ur': 'ماجورو',
#     'mr': 'माजुरो',
#     'sl': 'Majuro',
#     'hu': 'Majuro',
#     'bg': 'Маджуро',
#     'el': 'Ματζούρο',
#     'pl': 'Majuro',
#     'es': 'Majuro',
#     'sk': 'Dalap-Uliga-Darrit',
#     'hr': 'Majuro',
#     'gl': 'Majuro',
#     'ascii': 'Majuro',
#     'lv': 'Madžuro',
#     'ja': 'マジュロ',
#     'bs': 'Majuro',
#     'mh': 'Mājro',
#     'bn': 'মাজুরো',
#     'la': 'Madzurum',
#     'ny': 'Majuro',
#     'it': 'Majuro',
#     'ro': 'Majuro',
#     'he': "מג'ורו",
#     'io': 'Majuro',
#     'mk': 'Маџуро',
#     'nn': 'Majuro',
#     'az': 'Macuro',
#     'no': 'Majuro',
#     'tr': 'Majuro',
#     'sc': 'Majuro',
#     'sq': 'Majuro',
#     'tg': 'Маҷуро',
#     'gn': 'Majuro',
#     'ms': 'Majuro',
#     'hi': 'माजुरो',
#     'cs': 'Majuro',
#     'ka': 'მაჯურო',
#     'eo': 'Majuro',
#     'bo': 'མ་ཇུ་རོ།',
#     'is': 'Majúró',
#     'tl': 'Majuro',
#     'feature_name': 'Majuro',
#     'af': 'Majuro',
#     'sv': 'Majuro',
#     'ko': '마주로',
#     'nl': 'Majuro',
#     'ky': 'Мажeро',
#     'vi': 'Majuro',
#     'ru': 'Маджуро',
#     'eu': 'Majuro',
#     'ie': 'Majuro',
#     'fy': 'Majuro',
#     'fi': 'Majuro',
#     'fr': 'Majuro',
#     'br': 'Majuro',
#     'ta': 'மாசூரோ',
#     'da': 'Majuro',
#     'sh': 'Majuro',
#     'os': 'Маджуро'},
#    'lat': 7.0909924,
#    'lon': 171.3816354,
#    'country': 'MH'}],
#  [{'name': 'Mei County',
#    'local_names': {'en': 'Mei County', 'zh': '眉县', 'vi': 'My'},
#    'lat': 34.130278,
#    'lon': 107.835,
#    'country': 'CN',
#    'state': 'Shaanxi'}],
#  [{'name': 'Malé',
#    'local_names': {'ta': 'மாலே',
#     'pl': 'Male',
#     'cs': 'Male',
#     'mr': 'मले',
#     'oc': 'Male',
#     'ml': 'മാലി',
#     'zh': '马累',
#     'et': 'Male',
#     'sv': 'Malé',
#     'hu': 'Malé',
#     'en': 'Malé',
#     'hi': 'माले',
#     'de': 'Malé',
#     'nl': 'Malé',
#     'fr': 'Malé',
#     'dv': 'މާލެ'},
#    'lat': 4.1779879,
#    'lon': 73.5107387,
#    'country': 'MV'}],
#  [{'name': 'Melilla',
#    'local_names': {'lt': 'Melilja',
#     'kk': 'Мелилья',
#     'la': 'Rusadir',
#     'bg': 'Мелиля',
#     'mr': 'मेलिया',
#     'mk': 'Мелилја',
#     'lv': 'Melilja',
#     'uk': 'Мелілья',
#     'he': 'מלייה',
#     'eo': 'Melilo',
#     'os': 'Мелилья',
#     'ru': 'Мелилья',
#     'ko': '멜리야',
#     'cs': 'Melilla',
#     'en': 'Melilla',
#     'sr': 'Мелиља',
#     'fa': 'ملیلیه',
#     'su': 'Mélilya',
#     'ar': 'مليلية',
#     'ja': 'メリリャ',
#     'zu': 'IMelilla',
#     'pl': 'Melilla',
#     'zh': '梅利利亚',
#     'hy': 'Մելիլյա',
#     'es': 'Melilla',
#     'el': 'Μελίγια',
#     'ta': 'மெலில்லா',
#     'ka': 'მელილია',
#     'th': 'เมลียา',
#     'sk': 'Melilla',
#     'be': 'Мелілья'},
#    'lat': 35.2918698,
#    'lon': -2.9409026,
#    'country': 'ES',
#    'state': 'Melilla'}],
#  [{'name': 'Mont',
#    'lat': 46.6260356,
#    'lon': 3.8306675,
#    'country': 'FR',
#    'state': 'Bourgogne-Franche-Comté'}],
#  [{'name': 'Aomar',
#    'local_names': {'fr': 'Aomar',
#     'ur': 'عمر',
#     'ar': 'عمر',
#     'en': 'Aomar',
#     'fa': 'عمر'},
#    'lat': 36.492393,
#    'lon': 3.7711939,
#    'country': 'DZ',
#    'state': 'Bouira'}],
#  [{'name': 'Moult',
#    'local_names': {'ru': 'Муль', 'uk': 'Му', 'fr': 'Moult'},
#    'lat': 49.115483,
#    'lon': -0.1657186,
#    'country': 'FR',
#    'state': 'Normandy'}],
#  [{'name': 'Mexico',
#    'local_names': {'ar': 'المكسيك', 'en': 'Mexico', 'es': 'México'},
#    'lat': 25.20193915,
#    'lon': 55.15419672678571,
#    'country': 'AE',
#    'state': 'Dubai'}],
#  [{'name': 'Monte-Carlo',
#    'local_names': {'da': 'Monte Carlo',
#     'et': 'Monte Carlo',
#     'fr': 'Monte-Carlo',
#     'mk': 'Монте Карло'},
#    'lat': 43.7402961,
#    'lon': 7.426559,
#    'country': 'MC'}],
#  [{'name': 'Amman',
#    'local_names': {'bo': 'ཨམ་མན།',
#     'hy': 'Ամման',
#     'ja': 'アンマン',
#     'mr': 'अम्मान',
#     'el': 'Αμμάν',
#     'lv': 'Ammāna',
#     'ml': 'അമ്മാൻ',
#     'be': 'Аман',
#     'os': 'Амман',
#     'ks': 'عمان',
#     'tr': 'Amman',
#     'no': 'Amman',
#     'is': 'Amman',
#     'ka': 'ამანი',
#     'ku': 'Amman',
#     'ur': 'عمان',
#     'sv': 'Amman',
#     'oc': 'Amman',
#     'ru': 'Амман',
#     'lt': 'Amanas',
#     'bn': 'আম্মান',
#     'tt': 'Амман',
#     'am': 'አማን',
#     'ar': 'عمان',
#     'ta': 'அம்மான்',
#     'it': 'Amman',
#     'es': 'Amán',
#     'ko': '암만',
#     'cs': 'Ammán',
#     'bs': 'Aman',
#     'hi': 'अम्मान',
#     'sl': 'Aman',
#     'he': 'רבת עמון',
#     'cv': 'Амман',
#     'ug': 'ئاممان',
#     'th': 'อัมมาน',
#     'gl': 'Amán - عمان',
#     'eo': 'Amano',
#     'ascii': 'Amman',
#     'feature_name': 'Amman',
#     'da': 'Amman',
#     'kn': 'ಅಮ್ಮಾನ್',
#     'fr': 'Amman',
#     'hu': 'Ammán',
#     'uk': 'Амман',
#     'fi': 'Amman',
#     'sr': 'Аман',
#     'nl': 'Amman',
#     'fa': 'امان',
#     'kk': 'Амман',
#     'ht': 'Amàn',
#     'en': 'Amman',
#     'yi': 'אמאן',
#     'mk': 'Аман',
#     'bg': 'Аман',
#     'tg': 'Аммон',
#     'mn': 'Амман',
#     'de': 'Amman',
#     'sk': 'Ammán',
#     'te': 'అమ్మాన్',
#     'pl': 'Amman',
#     'eu': 'Amman',
#     'et': 'Amman',
#     'hr': 'Amman',
#     'pt': 'Amã',
#     'zh': '安曼'},
#    'lat': 31.9515694,
#    'lon': 35.9239625,
#    'country': 'JO',
#    'state': 'Amman'}],
#  [{'name': 'Kiamika',
#    'lat': 46.4188742,
#    'lon': -75.3799932,
#    'country': 'CA',
#    'state': 'Quebec'}],
#  [{'name': 'Mau',
#    'local_names': {'he': 'מאו',
#     'ml': 'മൗ',
#     'ar': 'ماو',
#     'hi': 'मऊ',
#     'kn': 'ಮಾಹು',
#     'mr': 'मऊ',
#     'pa': 'ਮਊ'},
#    'lat': 25.9391096,
#    'lon': 83.5716125,
#    'country': 'IN',
#    'state': 'Uttar Pradesh'}],
#  [{'name': 'Metz',
#    'local_names': {'br': 'Metz',
#     'yi': 'מעץ',
#     'jv': 'Métz',
#     'cs': 'Mety',
#     'zh': '梅斯',
#     'lb': 'Metz',
#     'lv': 'Meca',
#     'bg': 'Мец',
#     'mk': 'Мец',
#     'ta': 'மெட்சு',
#     'ur': 'میتز',
#     'he': 'מץ',
#     'ru': 'Мец',
#     'ka': 'მეცი',
#     'am': 'መትዝ',
#     'la': 'Mettis',
#     'fa': 'متز',
#     'mr': 'मेस',
#     'kk': 'Мец',
#     'oc': 'Mètz',
#     'bo': 'མེ་ཊི་ཛི།',
#     'hu': 'Metz',
#     'el': 'Μετς',
#     'ar': 'متز',
#     'sr': 'Мец',
#     'fr': 'Metz',
#     'ko': '메스',
#     'be': 'Мец',
#     'uk': 'Мец',
#     'ja': 'メス',
#     'hy': 'Մեց',
#     'lt': 'Mecas',
#     'th': 'แม็ส'},
#    'lat': 49.1196964,
#    'lon': 6.1763552,
#    'country': 'FR',
#    'state': 'Grand Est'}],
#  [{'name': 'NA',
#    'lat': -51.3184588,
#    'lon': -59.741689897506845,
#    'country': 'FK'}],
#  [{'name': 'National Park',
#    'lat': 39.865968,
#    'lon': -75.1796351,
#    'country': 'US',
#    'state': 'New Jersey'}],
#  [{'name': 'نعل کنان',
#    'lat': 31.7428456,
#    'lon': 50.1793258,
#    'country': 'IR',
#    'state': 'Khuzestan Province'}],
#  [{'name': '`Anaz',
#    'local_names': {'feature_name': 'Aanaz, `Anaz',
#     'ar': 'عنز',
#     'de': '`Anaz',
#     'en': '`Anaz',
#     'fr': '`Anaz',
#     'ascii': 'Aanaz, `Anaz'},
#    'lat': 34.7360048,
#    'lon': 36.3011029,
#    'country': 'SY',
#    'state': 'Homs Governorate'}],
#  [{'name': 'Ni',
#    'local_names': {'en': 'Ni', 'ja': 'ニ'},
#    'lat': 35.72047,
#    'lon': 140.6298436,
#    'country': 'JP'}],
#  [{'name': 'ng',
#    'lat': -3.3669467500000003,
#    'lon': 36.67738947024446,
#    'country': 'TZ',
#    'state': 'Arusha'}],
#  [{'name': 'Nou',
#    'local_names': {'de': 'Neudorf bei Hermannstadt',
#     'ru': 'Но',
#     'hu': 'Szászújfalu',
#     'uk': 'Ноу',
#     'ro': 'Nou'},
#    'lat': 45.8299398,
#    'lon': 24.2830582,
#    'country': 'RO'}],
#  [{'name': 'Omps',
#    'local_names': {'uk': 'Ом', 'fr': 'Omps', 'oc': 'Omps'},
#    'lat': 44.8779952,
#    'lon': 2.2761709,
#    'country': 'FR',
#    'state': 'Auvergne-Rhône-Alpes'}],
#  [{'name': 'Park',
#    'lat': 39.112507,
#    'lon': -100.358747,
#    'country': 'US',
#    'state': 'Kansas'}],
#  [{'name': 'Pay',
#    'local_names': {'hi': 'पाय', 'en': 'Pay'},
#    'lat': 23.1361652,
#    'lon': 68.9346579,
#    'country': 'IN',
#    'state': 'Gujarat'}],
#  [{'name': 'Golęcino-Gocław',
#    'local_names': {'de': 'Frauendorf-Gotzlow', 'pl': 'Golęcino-Gocław'},
#    'lat': 53.4711354,
#    'lon': 14.5976516,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Py',
#    'local_names': {'ca': 'Pi de Conflent', 'fr': 'Py'},
#    'lat': 42.49576,
#    'lon': 2.3506675,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Pey',
#    'local_names': {'fr': 'Pey', 'oc': 'Pei', 'uk': 'Пе'},
#    'lat': 43.6302615,
#    'lon': -1.2015629,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [],
#  [{'name': 'Plains',
#    'lat': 33.1892387,
#    'lon': -102.827274,
#    'country': 'US',
#    'state': 'Texas'}],
#  [{'name': 'Opatów',
#    'local_names': {'pl': 'Opatów',
#     'he': 'אפטא',
#     'ru': 'Опатув',
#     'uk': 'Опатув'},
#    'lat': 50.8017661,
#    'lon': 21.4238281,
#    'country': 'PL',
#    'state': 'Świętokrzyskie Voivodeship'}],
#  [{'name': 'Prague',
#    'local_names': {'ug': 'پراگا',
#     'nn': 'Praha',
#     'ar': 'براغ',
#     'nl': 'Praag',
#     'oc': 'Praga',
#     'de': 'Hauptstadt Prag',
#     'hy': 'Պրահա',
#     'et': 'Praha',
#     'zh': '布拉格',
#     'ee': 'Prague',
#     'kn': 'ಪ್ರಾಗ',
#     'is': 'Prag',
#     'gl': 'Praga',
#     'ja': 'プラハ',
#     'ca': 'Praga',
#     'cv': 'Прага',
#     'it': 'Praga',
#     'se': 'Praha',
#     'ie': 'Praha',
#     'cy': 'Prag',
#     'ko': '프라하',
#     'yo': 'Prague',
#     'gv': 'Praag',
#     'am': 'ፕራግ',
#     'bn': 'প্রাগ',
#     'vi': 'Praha',
#     'kk': 'Прага',
#     'fy': 'Praach',
#     'mr': 'प्राग',
#     'co': 'Praga',
#     'az': 'Praqa',
#     'lt': 'Praha',
#     'sh': 'Prag',
#     'pt': 'Praga',
#     'mi': 'Prague',
#     'ku': 'Prag',
#     'es': 'Praga',
#     'be': 'Прага',
#     'kl': 'Praha',
#     'fr': 'Prague',
#     'ru': 'Столица Прага',
#     'eu': 'Praga',
#     'na': 'Praha',
#     'br': 'Praha',
#     'da': 'Prag',
#     'gd': 'Pràg',
#     'en': 'Prague',
#     'fi': 'Praha',
#     'ia': 'Praga',
#     'el': 'Πράγα',
#     'ky': 'Прага',
#     'tl': 'Praga',
#     'ak': 'Prague',
#     'qu': 'Praha',
#     'zu': 'IPraha',
#     'my': 'ပရက်ဂ်မြို့',
#     'tg': 'Прага',
#     'sq': 'Praga',
#     'an': 'Praga',
#     'jv': 'Praha',
#     'ro': 'Praga',
#     'sc': 'Praga',
#     'pl': 'Miasto Stołeczne Praga',
#     'eo': 'Ĉefurba regiono Prago',
#     'ml': 'പ്രാഗ്',
#     'id': 'Praha',
#     'tr': 'Prag',
#     'io': 'Praha',
#     'sr': 'Праг',
#     'os': 'Прагæ',
#     'ur': 'پراگ',
#     'tt': 'Прага',
#     'he': 'פראג',
#     'la': 'Praga',
#     'af': 'Praag',
#     'li': 'Praag',
#     'bg': 'Прага',
#     'ps': 'پراګ',
#     'uk': 'Прага',
#     'bs': 'Prag',
#     'fo': 'Prag',
#     'uz': 'Praga',
#     'ka': 'პრაღა',
#     'ms': 'Praha',
#     'kv': 'Прага',
#     'cs': 'Hlavní město Praha',
#     'hr': 'Prag',
#     'mk': 'Прага',
#     'hi': 'प्राग',
#     'sl': 'Praga',
#     'lb': 'Prag',
#     'th': 'ปราก',
#     'bo': 'པུ་ལ་ཁེ།',
#     'lv': 'Prāga',
#     'sw': 'Praha',
#     'ga': 'Prág',
#     'sv': 'Prag',
#     'cu': 'Прага',
#     'ta': 'பிராகா',
#     'hu': 'Prága főváros',
#     'kw': 'Praha',
#     'no': 'Praha',
#     'sk': 'Praha',
#     'mn': 'Прага',
#     'fa': 'پراگ',
#     'yi': 'פראג',
#     'mt': 'Praga'},
#    'lat': 50.0874654,
#    'lon': 14.4212535,
#    'country': 'CZ',
#    'state': 'Prague'}],
#  [{'name': 'Doha',
#    'local_names': {'sw': 'Doha',
#     'hi': 'दोहा, क़तर',
#     'io': 'Doha',
#     'gu': 'દોહા',
#     'ms': 'Doha',
#     'nn': 'Doha',
#     'km': 'ដូហា',
#     'is': 'Doha',
#     'jv': 'Doha',
#     'yo': 'Doha',
#     'eo': 'Doho',
#     'tg': 'Дуҳа',
#     'ia': 'Doha',
#     'nl': 'Doha',
#     'fy': 'Doha',
#     'sr': 'Доха',
#     'mg': 'Doha',
#     'ru': 'Доха',
#     'uz': 'Doʻha',
#     'ga': 'Doha',
#     'be': 'Доха',
#     'es': 'Doha',
#     'uk': 'Доха',
#     'kl': 'Doha',
#     'mr': 'दोहा',
#     'oc': 'Doha',
#     'pt': 'Doha',
#     'kn': 'ದೊಹಾ',
#     'yi': 'דאכא',
#     'eu': 'Doha',
#     'gn': 'Doha',
#     'lb': 'Doha',
#     'ce': 'Духьа',
#     'gr': 'Δοχή',
#     'vo': 'Däuha',
#     'sv': 'Doha',
#     'az': 'Doha',
#     'sq': 'Doha',
#     'ba': 'Доһа',
#     'id': 'Doha',
#     'bn': 'দোহা',
#     'no': 'Doha',
#     'mk': 'Доха',
#     'ha': 'Doha',
#     'so': 'Dooxa',
#     'os': 'Дохæ',
#     'kk': 'Доһа',
#     'an': 'Doha',
#     'ka': 'დოჰა',
#     'af': 'Doha',
#     'fi': 'Doha',
#     'da': 'Doha',
#     'sk': 'Dauha',
#     'mn': 'Доха',
#     'lt': 'Doha',
#     'ku': 'Doha',
#     'cy': 'Doha',
#     'ie': 'Doha',
#     'ja': 'ドーハ',
#     'bo': 'དྷོ་ཧ།',
#     'it': 'Doha',
#     'lv': 'Doha',
#     'hy': 'Դոհա',
#     'ml': 'ദോഹ',
#     'hr': 'Doha',
#     'ky': 'Доха',
#     'he': 'דוחה',
#     'th': 'โดฮา',
#     'sl': 'Doha',
#     'my': 'ဒိုဟာမြို့',
#     'rw': 'Doha',
#     'zh': '多哈',
#     'sc': 'Doha',
#     'et': 'Doha',
#     'sn': 'Doha',
#     'bg': 'Доха',
#     'vi': 'Doha',
#     'cs': 'Dauhá',
#     'tl': 'Doha',
#     'hu': 'Doha',
#     'ug': 'دوھا',
#     'tt': 'Doha',
#     'ar': 'الدوحة',
#     'pa': 'ਦੋਹਾ',
#     'pl': 'Doha',
#     'de': 'Doha',
#     'ko': '도하',
#     'sh': 'Doha',
#     'ne': 'दोहा',
#     'gl': 'Doha',
#     'ht': 'Doha',
#     'el': 'Ντόχα',
#     'la': 'Doha',
#     'tk': 'Doha',
#     'en': 'Doha',
#     'ro': 'Doha',
#     'ur': 'دوحہ',
#     'gd': 'Doha',
#     'ca': 'Doha',
#     'fa': 'دوحه',
#     'am': 'ዶሃ',
#     'bs': 'Doha',
#     'ps': 'دوحه',
#     'sd': 'دوحہ',
#     'br': 'Doha',
#     'ta': 'தோகா',
#     'fr': 'Doha',
#     'tr': 'Doha'},
#    'lat': 25.2856329,
#    'lon': 51.5264162,
#    'country': 'QA'}],
#  [{'name': 'Ro',
#    'lat': 44.9466518,
#    'lon': 11.7626169,
#    'country': 'IT',
#    'state': 'Emilia-Romagna'}],
#  [],
#  [{'name': 'Aachen',
#    'local_names': {'no': 'Aachen',
#     'kk': 'Ахен',
#     'ku': 'Aachen',
#     'ur': 'آخن',
#     'it': 'Aquisgrana',
#     'eo': 'Aachen',
#     'sw': 'Aachen',
#     'ar': 'آخن',
#     'la': 'Aquisgranum',
#     'sh': 'Aachen',
#     'tl': 'Aachen',
#     'hr': 'Aachen',
#     'en': 'Aachen',
#     'pt': 'Aquisgrão',
#     'mn': 'Аахен',
#     'wa': 'Åxhe',
#     'nb': 'Aachen',
#     'sr': 'Ахен',
#     'hu': 'Aachen',
#     'nl': 'Aken',
#     'lb': 'Oochen',
#     'sl': 'Aachen',
#     'hy': 'Աախեն',
#     'ga': 'Aachen',
#     'tg': 'А́хен',
#     'cy': 'Aachen',
#     'eu': 'Akisgran',
#     'th': 'อาเคิน',
#     'ta': 'ஆஃகன்',
#     'ps': 'آخن',
#     'vo': 'Aachen',
#     'hi': 'आखन',
#     'ce': 'Ахен',
#     'uz': 'Axen',
#     'cs': 'Cáchy',
#     'ro': 'Aachen',
#     'ml': 'ആഹ്ഹൻ',
#     'an': 'Aquisgrán',
#     'oc': 'Aquisgran',
#     'zh': '亚琛',
#     'fi': 'Aachen',
#     'da': 'Aachen',
#     'vi': 'Aachen',
#     'et': 'Aachen',
#     'ca': 'Aquisgrà',
#     'de': 'Aachen',
#     'mr': 'आखन',
#     'ia': 'Aquisgrano',
#     'tr': 'Aachen',
#     'lt': 'Achenas',
#     'az': 'Aaxen',
#     'af': 'Aken',
#     'gd': 'Aachen',
#     'ie': 'Aachen',
#     'he': 'אַאכֶן',
#     'be': 'А́хен',
#     'nn': 'Aachen',
#     'id': 'Aachen',
#     'io': 'Aachen',
#     'am': 'አኽን',
#     'el': 'Άαχεν',
#     'bs': 'Aachen',
#     'is': 'Aachen',
#     'ru': 'Ахен',
#     'ja': 'アーヘン',
#     'fa': 'آخن',
#     'ky': 'Ахен',
#     'ka': 'აახენი',
#     'br': 'Aachen',
#     'mk': 'Ахен',
#     'sk': 'Aachen',
#     'uk': 'Аа́хен',
#     'bg': 'А̀хен',
#     'gl': 'Aquisgrán',
#     'ko': '아헨',
#     'pl': 'Akwizgran',
#     'tt': 'Ахен',
#     'ms': 'Aachen',
#     'fy': 'Aken',
#     'co': 'Aquisgrana',
#     'sv': 'Aachen',
#     'li': 'Aoke',
#     'fr': 'Aix-la-Chapelle',
#     'lv': 'Āhene',
#     'qu': 'Aachen',
#     'es': 'Aquisgrán'},
#    'lat': 50.776351,
#    'lon': 6.083862,
#    'country': 'DE',
#    'state': 'North Rhine-Westphalia'}],
#  [{'name': 'Lac',
#    'local_names': {'bg': 'Лак',
#     'eu': 'Lac',
#     'ja': 'ラク州',
#     'ur': 'لاک علاقہ',
#     'en': 'Lac',
#     'de': 'Region See',
#     'lt': 'Ežero regionas',
#     'uk': 'Лак',
#     'no': 'Lac',
#     'ro': 'Regiunea Lac',
#     'nl': 'Lac',
#     'fi': 'Lac',
#     'ko': '라크주',
#     'zh': '湖區',
#     'ar': 'البحيرة',
#     'da': 'Lac',
#     'et': 'Laci piirkond',
#     'it': 'Regione del Lago',
#     'id': 'Region Lac',
#     'tr': 'Lac',
#     'hi': 'लाक',
#     'fr': 'Lac',
#     'ka': 'ლაკის რეგიონი',
#     'pl': 'Lac',
#     'ru': 'Лак',
#     'fa': 'بخش بحیره',
#     'es': 'Lac'},
#    'lat': 13.5820827,
#    'lon': 14.3788329,
#    'country': 'TD'}],
#  [{'name': 'Chancelade',
#    'local_names': {'fr': 'Chancelade', 'oc': 'Chancelada'},
#    'lat': 45.2063889,
#    'lon': 0.6661111,
#    'country': 'FR',
#    'state': 'Nouvelle-Aquitaine'}],
#  [{'name': 'Auch',
#    'local_names': {'ja': 'オーシュ',
#     'la': 'Augusta-Auscorum',
#     'he': 'אוש',
#     'zh': '欧什',
#     'an': 'Aush',
#     'uk': 'Ош',
#     'sr': 'Ош',
#     'ru': 'Ош',
#     'bg': 'Ош',
#     'fr': 'Auch',
#     'oc': 'Aush',
#     'br': 'Aush',
#     'ca': 'Aush'},
#    'lat': 43.6463558,
#    'lon': 0.5850507,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Street',
#    'lat': 51.1267494,
#    'lon': -2.7397217,
#    'country': 'GB',
#    'state': 'England'}],
#  [{'name': 'Shah Alam',
#    'local_names': {'ms': 'Shah Alam',
#     'th': 'ชะฮ์อาลัม',
#     'ta': 'ஷா ஆலாம்',
#     'zh': '莎亚南',
#     'my': 'ရှားအလမ်မြို့',
#     'ja': 'シャー・アラム',
#     'ar': 'شاه عالم',
#     'ru': 'Шах-Алам',
#     'en': 'Shah Alam',
#     'ko': '샤알람'},
#    'lat': 3.0733644,
#    'lon': 101.5195149,
#    'country': 'MY',
#    'state': 'Selangor'}],
#  [{'name': 'Essen',
#    'local_names': {'sr': 'Есен',
#     'cs': 'Essen',
#     'kk': 'Эссен',
#     'hu': 'Essen',
#     'li': 'Esse',
#     'ko': '에센',
#     'lv': 'Esene',
#     'th': 'เอสเซิน',
#     'fa': 'اسن',
#     'zh': '埃森',
#     'he': 'אסן',
#     'ka': 'ესენი',
#     'de': 'Essen',
#     'ja': 'エッセン',
#     'uk': 'Ессен',
#     'mr': 'एसेन',
#     'ru': 'Эссен',
#     'el': 'Έσση',
#     'bg': 'Есен',
#     'lt': 'Esenas',
#     'la': 'Assindia',
#     'ar': 'إسن',
#     'ur': 'ایسن',
#     'ug': 'Ésén'},
#    'lat': 51.4582235,
#    'lon': 7.0158171,
#    'country': 'DE',
#    'state': 'North Rhine-Westphalia'}],
#  [{'name': 'Seoul',
#    'local_names': {'ta': 'சியோல்',
#     'bs': 'Seul',
#     'ko': '서울',
#     'ku': 'Sêûl',
#     'os': 'Сеул',
#     'pl': 'Seul',
#     'el': 'Σεούλ',
#     'de': 'Seoul',
#     'mr': 'सोल',
#     'mn': 'Сөүл',
#     'ka': 'სეული',
#     'hy': 'Սեուլ',
#     'sv': 'Seoul',
#     'mk': 'Сеул',
#     'eo': 'Seulo',
#     'fr': 'Séoul',
#     'en': 'Seoul',
#     'af': 'Seoel',
#     'sk': 'Soul',
#     'cs': 'Soul',
#     'fi': 'Soul',
#     'nl': 'Seoel',
#     'he': 'סיאול',
#     'gl': 'Seúl',
#     'bh': 'सियोल',
#     'th': 'โซล',
#     'vo': 'Söul',
#     'vi': 'Seoul',
#     'uk': 'Сеул',
#     'ru': 'Сеул',
#     'ro': 'Seul',
#     'hi': 'सियोल',
#     'uz': 'Seul',
#     'az': 'Seul',
#     'tk': 'Seul',
#     'km': 'សេអ៊ូល',
#     'zh': '首尔市 / 首爾',
#     'be': 'Сеул',
#     'tr': 'Seul',
#     'yi': 'סעאל',
#     'my': 'ဆိုးလ်မြို့',
#     'eu': 'Seul',
#     'cv': 'Сеул',
#     'ja': 'ソウル',
#     'bg': 'Сеул',
#     'ky': 'Сеул',
#     'la': 'Seulum',
#     'lv': 'Seula',
#     'fa': 'سئول',
#     'bn': 'সিওল',
#     'es': 'Seúl',
#     'is': 'Seúl',
#     'pt': 'Seul',
#     'oc': 'Seol',
#     'ur': 'سؤل',
#     'hr': 'Seul',
#     'sr': 'Сеул',
#     'it': 'Seul',
#     'bo': 'སེ་ཨུལ།',
#     'lt': 'Seulas',
#     'kk': 'Сеул',
#     'et': 'Sŏul',
#     'ml': 'സോൾ',
#     'hu': 'Szöul',
#     'qu': 'Siul',
#     'kn': 'ಸೌಲ್',
#     'am': 'ሶል',
#     'an': 'Seúl',
#     'ar': 'سول',
#     'tg': 'Сеул',
#     'ba': 'Сеул',
#     'ca': 'Seül',
#     'sl': 'Seul'},
#    'lat': 37.5666791,
#    'lon': 126.9782914,
#    'country': 'KR'}],
#  [{'name': 'Sandgrube',
#    'lat': 48.8658607,
#    'lon': 12.9046953,
#    'country': 'DE',
#    'state': 'Bavaria'}],
#  [{'name': 'SK',
#    'lat': 3.02872295,
#    'lon': 101.69964770488389,
#    'country': 'MY',
#    'state': 'Selangor'}],
#  [{'name': 'Si',
#    'local_names': {'th': 'สิ', 'en': 'Si'},
#    'lat': 14.6248479,
#    'lon': 104.4510392,
#    'country': 'TH',
#    'state': 'Si Sa Ket Province'}],
#  [{'name': 'Tuzla',
#    'local_names': {'bs': 'Tuzla',
#     'de': 'Tuzla',
#     'es': 'Tuzla',
#     'hu': 'Tuzla',
#     'tr': 'Tuzla',
#     'sr': 'Тузла',
#     'ar': 'توزلا',
#     'fr': 'Tuzla',
#     'hr': 'Tuzla',
#     'en': 'Tuzla',
#     'sq': 'Tuzlla',
#     'ru': 'Тузла'},
#    'lat': 44.5391105,
#    'lon': 18.675193,
#    'country': 'BA',
#    'state': 'Federation of Bosnia and Herzegovina'}],
#  [{'name': 'Arkońskie-Niemierzyn',
#    'local_names': {'pl': 'Arkońskie-Niemierzyn'},
#    'lat': 53.4553042,
#    'lon': 14.5298919,
#    'country': 'PL',
#    'state': 'West Pomeranian Voivodeship'}],
#  [{'name': 'Hèches',
#    'local_names': {'uk': 'Еш', 'fr': 'Hèches', 'oc': 'Hèishas'},
#    'lat': 43.0174862,
#    'lon': 0.3737441,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Lak',
#    'local_names': {'en': 'Lak', 'fa': 'لک'},
#    'lat': 37.6981704,
#    'lon': 45.0223151,
#    'country': 'IR',
#    'state': 'West Azerbaijan Province'}],
#  [{'name': 'Isdhoo',
#    'local_names': {'dv': 'އިސްދޫ', 'en': 'Isdhoo'},
#    'lat': 2.1189323,
#    'lon': 73.56443470496887,
#    'country': 'MV',
#    'state': 'Haddhunmathi'}],
#  [{'name': 'Steyr',
#    'local_names': {'de': 'Steyr', 'ru': 'Штайр'},
#    'lat': 48.0390046,
#    'lon': 14.4191276,
#    'country': 'AT',
#    'state': 'Upper Austria'}],
#  [{'name': 'Cheux',
#    'local_names': {'uk': 'Ше', 'fr': 'Cheux', 'ru': 'Шё'},
#    'lat': 49.1660575,
#    'lon': -0.5243876,
#    'country': 'FR',
#    'state': 'Normandy'}],
#  [{'name': 'Chandigarh',
#    'local_names': {'pa': 'ਚੰਡੀਗੜ੍ਹ',
#     'cs': 'Čandígarh',
#     'he': "צ'אנדיגאר",
#     'ta': 'சண்டிகர்',
#     'kn': 'ಚಂಡೀಗಡ',
#     'eo': 'Ĉandigaro',
#     'ml': 'ചണ്ഡീഗഢ്',
#     'hi': 'चण्डीगढ़',
#     'zh': '昌迪加尔中央直辖区',
#     'te': 'చండీగఢ్',
#     'de': 'Chandigarh',
#     'ur': 'چندی گڑھ',
#     'es': 'Chandigarh',
#     'fr': 'Chandigarh',
#     'ar': 'شانديغار',
#     'ja': 'チャンディーガル',
#     'ku': 'Çandîgar',
#     'ru': 'Чандигарх',
#     'en': 'Chandigarh',
#     'ko': '찬디가르',
#     'uk': 'Чандігарх'},
#    'lat': 30.7334421,
#    'lon': 76.7797143,
#    'country': 'IN'}],
#  [{'name': 'Dushanbe',
#    'local_names': {'am': 'ዱሻንቤ',
#     'he': 'דושנבה',
#     'it': 'Dušanbe',
#     'th': 'ดูชานเบ',
#     'cy': 'Dushanbe',
#     'uz': 'Dushanbe',
#     'gl': 'Dushanbe',
#     'cs': 'Dušanbe',
#     'ascii': 'Dushanbe',
#     'bs': 'Dušanbe',
#     'ky': 'Душанбе',
#     'bn': 'দুশান্\u200cবে',
#     'sh': 'Dušanbe',
#     'no': 'Dusjanbe',
#     'br': 'Douchanbe',
#     'hi': 'दुशान्बे',
#     'kn': 'ದುಶಾಂಬೆ',
#     'hy': 'Դուշանբե',
#     'fr': 'Douchanbé',
#     'mr': 'दुशांबे',
#     'bg': 'Душанбе',
#     'ur': 'دوشنبہ',
#     'mn': 'Душанбе',
#     'de': 'Duschanbe',
#     'ca': 'Duixanbe',
#     'gd': 'Dushanbe',
#     'eo': 'Duŝanbeo',
#     'ml': 'ദുഷാൻബെ',
#     'af': 'Doesjanbe',
#     'ar': 'دوشنبه',
#     'yo': 'Dushanbe',
#     'kv': 'Душанбе',
#     'ru': 'Душанбе',
#     'nn': 'Dusjanbe',
#     'tl': 'Dushanbe',
#     'eu': 'Dushanbe',
#     'lt': 'Dušanbė',
#     'tt': 'Дүшәнбе',
#     'yi': 'דושאנבע',
#     'sq': 'Dushanbe',
#     'feature_name': 'Dushanbe',
#     'az': 'Düşənbə',
#     'sl': 'Dušanbej',
#     'tr': 'Duşanbe',
#     'en': 'Dushanbe',
#     'hu': 'Dusanbe',
#     'sr': 'Душанбе',
#     'hr': 'Dušanbe',
#     'fa': 'دوشنبه',
#     'is': 'Dúshanbe',
#     'sw': 'Dushanbe',
#     'mk': 'Душанбе',
#     'ka': 'დუშანბე',
#     'ps': 'دوشنبه',
#     'ug': 'Düshenbe',
#     'da': 'Dusjanbe',
#     'fi': 'Dušanbe',
#     'tg': 'Душанбе',
#     'ie': 'Dushanbe',
#     'sv': 'Dusjanbe',
#     'ja': 'ドゥシャンベ',
#     'ro': 'Dușanbe',
#     'os': 'Душанбе',
#     'fy': 'Doesjanbe',
#     'ko': '두샨베',
#     'bo': 'དུ་ཤང་པེ།',
#     'kk': 'Душанбе',
#     'vi': 'Dushanbe',
#     'el': 'Ντουσαμπέ',
#     'zh': '杜尚别',
#     'oc': 'Doshambe',
#     'ku': 'Duşenbe',
#     'id': 'Dushanbe',
#     'es': 'Dusambé',
#     'sk': 'Dušanbe',
#     'pl': 'Duszanbe',
#     'uk': 'Душанбе',
#     'be': 'Душанбэ',
#     'ht': 'Douchanbe',
#     'ga': 'Dushanbe',
#     'ta': 'துசான்பே',
#     'lv': 'Dušanbe',
#     'io': 'Dushanbe',
#     'nl': 'Doesjanbe',
#     'pt': 'Duchambe',
#     'et': 'Dušanbe'},
#    'lat': 38.5762709,
#    'lon': 68.7863573,
#    'country': 'TJ'}],
#  [{'name': 'Tienhaara',
#    'local_names': {'feature_name': 'Tienhaara',
#     'en': 'Tienhaara',
#     'fi': 'Tienhaara',
#     'ru': 'Калинино',
#     'ascii': 'Tienhaara'},
#    'lat': 60.7547446,
#    'lon': 28.6486315,
#    'country': 'RU',
#    'state': 'Leningrad oblast'}],
#  [{'name': 'TT',
#    'lat': 18.3449742,
#    'lon': 97.0033054204086,
#    'country': 'MM',
#    'state': 'Bago Region'}],
#  [{'name': 'Athens',
#    'local_names': {'ml': 'ഏതൻസ്\u200c',
#     'cy': 'Athen',
#     'feature_name': 'Athina',
#     'ht': 'Atèn',
#     'fa': 'آتن',
#     'eo': 'Ateno',
#     'cv': 'Афин',
#     'sh': 'Atena',
#     'nn': 'Aten',
#     'yo': 'Áténì',
#     'mt': 'Ateni',
#     'uz': 'Afina',
#     'ca': 'Atenes',
#     'my': 'အေသင်မြို့',
#     'mi': 'Ātene',
#     'cs': 'Athény',
#     'gn': 'Atena',
#     'br': 'Aten',
#     'wo': 'Aten',
#     'hr': 'Atena',
#     'mn': 'Афин',
#     'sk': 'Atény',
#     'gv': 'Yn Atheen',
#     'lt': 'Atėnai',
#     'yi': 'אטען',
#     'it': 'Atene',
#     'vo': 'Atina',
#     'li': 'Athene',
#     'tl': 'Atenas',
#     'uk': 'Афіни',
#     'oc': 'Atenas',
#     'vi': 'Athena',
#     'cu': 'Аѳинꙑ',
#     'sl': 'Atene',
#     'en': 'Athens',
#     'sq': 'Athina',
#     'la': 'Athenae',
#     'ug': 'ئافېنا',
#     'qu': 'Athina',
#     'sc': 'Atene',
#     'zu': 'I-Athene',
#     'kv': 'Афинъяс',
#     'ta': 'ஏதென்ஸ்',
#     'ascii': 'Athina',
#     'kw': 'Athína',
#     'et': 'Ateena',
#     'lv': 'Atēnas',
#     'hy': 'Աթենք',
#     'tw': 'Athens',
#     'hu': 'Athén',
#     'th': 'เอเธนส์',
#     'an': 'Atenas',
#     'ka': 'ათენი',
#     'se': 'Athena',
#     'am': 'አቴና',
#     'ar': 'أثينا',
#     'be': 'Афіны',
#     'ku': 'Atîna',
#     'kk': 'Афина',
#     'eu': 'Atenas',
#     'zh': '雅典',
#     'af': 'Athene',
#     'pt': 'Atenas',
#     'bg': 'Атина',
#     'fi': 'Ateena',
#     'el': 'Αθήνα',
#     'mk': 'Атина',
#     'os': 'Афинæтæ',
#     'gd': 'An Àithne',
#     'ja': 'アテネ',
#     'bo': 'ཨ་ཐེན།',
#     'tr': 'Atina',
#     'id': 'Athena',
#     'sw': 'Athens',
#     'ms': 'Athens',
#     'fy': 'Atene',
#     'hi': 'एथेंस',
#     'io': 'Athina',
#     'he': 'אתונה',
#     'az': 'Afina',
#     'tk': 'Afiny',
#     'ru': 'Афины',
#     'ia': 'Athenas',
#     'ga': 'An Aithin',
#     'fr': 'Athènes',
#     'co': 'Atene',
#     'bn': 'অ্যাথেন্স',
#     'kn': 'ಅಥೆನ್ಸ್',
#     'ur': 'ایتھنز',
#     'ba': 'Афина',
#     'sr': 'Атина',
#     'es': 'Atenas',
#     'jv': 'Aténa',
#     'sv': 'Aten',
#     'ie': 'Athina',
#     'ko': '아테네',
#     'lb': 'Athen',
#     'nl': 'Athene',
#     'ln': 'Atenis',
#     'is': 'Aþena',
#     'tt': 'Афиннар',
#     'wa': 'Atene',
#     'no': 'Aten',
#     'bs': 'Atina',
#     'te': 'ఏథెన్స్',
#     'gl': 'Atenas',
#     'ro': 'Atena',
#     'mr': 'अथेन्स',
#     'de': 'Athen',
#     'pl': 'Ateny'},
#    'lat': 37.9839412,
#    'lon': 23.7283052,
#    'country': 'GR',
#    'state': 'Attica'}],
#  [{'name': 'Torre', 'lat': 39.9634843, 'lon': -6.9406539, 'country': 'PT'}],
#  [{'name': 'Ua',
#    'lat': -8.8613303,
#    'lon': 121.2037997,
#    'country': 'ID',
#    'state': 'East Nusa Tenggara'}],
#  [{'name': 'Ae',
#    'lat': -0.6858283,
#    'lon': -48.04675,
#    'country': 'BR',
#    'state': 'Pará'}],
#  [{'name': 'Geva',
#    'local_names': {'en': 'Geva', 'fr': 'Geva', 'he': 'גבע'},
#    'lat': 32.5663362,
#    'lon': 35.3715486,
#    'country': 'IL',
#    'state': 'North District'}],
#  [{'name': 'Us',
#    'lat': 49.1009451,
#    'lon': 1.9672466,
#    'country': 'FR',
#    'state': 'Ile-de-France'}],
#  [{'name': 'Wei County',
#    'local_names': {'fr': 'Wei', 'en': 'Wei County', 'zh': '威县', 'vi': 'Uy'},
#    'lat': 36.9820674,
#    'lon': 115.2666089,
#    'country': 'CN',
#    'state': 'Hebei'}],
#  [{'name': 'Uz',
#    'local_names': {'ca': 'Us', 'fr': 'Uz', 'oc': 'Us', 'uk': 'Юз'},
#    'lat': 42.9663688,
#    'lon': -0.0852324,
#    'country': 'FR',
#    'state': 'Occitania'}],
#  [{'name': 'Ye County',
#    'local_names': {'zh': '叶县', 'vi': 'Diệp', 'en': 'Ye County'},
#    'lat': 33.54912,
#    'lon': 113.361272,
#    'country': 'CN',
#    'state': 'Henan'}],
#  [{'name': '`Azm',
#    'local_names': {'ascii': '‘Az̧m',
#     'feature_name': '‘Az̧m',
#     'ar': 'عظم',
#     'en': '`Azm'},
#    'lat': 14.893993,
#    'lon': 43.749254,
#    'country': 'YE',
#    'state': "Sana'a Governorate"}],
#  [{'name': 'زو',
#    'lat': 37.735917,
#    'lon': 57.77137,
#    'country': 'IR',
#    'state': 'North Khorasan Province'}]]

# %%
#Loading the co-ordinate data into lists
for r in response_api:
    if len(r)>=1:
        latitude.append(r[0]['lat'])
        longitude.append(r[0]['lon'])
    else:
        latitude.append('')
        longitude.append((''))

# %%
#Creating new dataframe with country codes, latitude and longitude
country_info_df=pd.DataFrame({'country':country_codes, 'Lat':latitude,'Long':longitude})

# %%
country_info_df.head()
# Out:
#   country        Lat        Long
# 0      AF  54.235921   -4.514767
# 1      AL  36.717202   59.666131
# 2      DZ  36.392117 -107.834908
# 3      AD  47.292376   23.020988
# 4      AO  34.626275  135.605845
